# %% [markdown]
# ## M3 dan M6 - Model Prediksi Titik Panas di Sumatera Selatan 2001 - 2023

# %% [markdown]
# - Jika dipengaruhi oleh enso

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

import random as rm
import time as tm

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# Setting seed
rm.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# # Setting Algorithm
algorithm = "LSTM-RNN"

# %%
# Setting Algorithm
# algorithm = "GRU-RNN"

# %%
# set parameter
activation = "relu"
dropout_rate = 0.20
optimizer = "rmsprop"
batch_size = 32
epochs=1500

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
# !gdown "1TMdNpuz0nyx5uAQ12477VpgOtJqfmxcI"
# !gdown "1a9EJFq3gej1LzJK86p6qEIdQ_VsOrsbl"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1TMdNpuz0nyx5uAQ12477VpgOtJqfmxcI
# From (redirected): https://drive.google.com/uc?id=1TMdNpuz0nyx5uAQ12477VpgOtJqfmxcI&confirm=t&uuid=f297a251-d38c-4a51-b929-ff76992db9af
# To: /content/class_base_model.py
# 100% 3.50k/3.50k [00:00<00:00, 9.45MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1a9EJFq3gej1LzJK86p6qEIdQ_VsOrsbl
# To: /content/dataset_enso.csv
# 100% 12.8k/12.8k [00:00<00:00, 26.4MB/s]

# %%
from google.colab import drive

drive.mount('/content/drive')
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/M3 M6 Anom/dataset_enso.csv", parse_dates=["acq_date"])

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
#  2   sst_std   276 non-null    float64
#  3   sst_anom  276 non-null    float64
#  4   oni_std   276 non-null    float64
#  5   oni_anom  276 non-null    float64
#  6   soi_std   276 non-null    float64
#  7   soi_anom  276 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
print(dataset.head())
# Out:
#     acq_date  hotspot  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom
# 0 2001-01-31        3    25.81     -0.76    25.88     -0.68      1.0       1.6
# 1 2001-02-28        5    26.18     -0.56    26.26     -0.52      1.7       2.8
# 2 2001-03-31       10    26.86     -0.37    26.76     -0.44      0.9       1.5
# 3 2001-04-30       20    27.24     -0.56    27.25     -0.34      0.2       0.3
# 4 2001-05-31       39    27.42     -0.46    27.49     -0.25     -0.5      -0.8

# %% [markdown]
# ### 2. Praproses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# jika hotspot dipengaruhi oleh enso
# data = dataset[["hotspot", "sst_std", "sst_anom", "oni_std", "oni_anom", "soi_std", "soi_anom"]]
# data = data.values

# # jika hotspot dipengaruhi oleh enso
data = dataset[["hotspot", "sst_anom", "oni_anom", "soi_anom"]]
data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3.  , -0.76, -0.68,  1.6 ],
#        [ 5.  , -0.56, -0.52,  2.8 ],
#        [10.  , -0.37, -0.44,  1.5 ],
#        [20.  , -0.56, -0.34,  0.3 ],
#        [39.  , -0.46, -0.25, -0.8 ]])

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 4)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],4)
# Out:
# array([[-1.    , -0.6148, -0.5514,  0.36  ],
#        [-0.9997, -0.522 , -0.4766,  0.6   ],
#        [-0.999 , -0.4339, -0.4393,  0.34  ],
#        [-0.9976, -0.522 , -0.3925,  0.1   ],
#        [-0.995 , -0.4756, -0.3505, -0.12  ]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 4)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled[:,:1]), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],4)
# Out:
# array([[-1.    , -0.6148, -0.5514,  0.36  ],
#        [-0.9997, -0.522 , -0.4766,  0.6   ],
#        [-0.999 , -0.4339, -0.4393,  0.34  ],
#        [-0.9976, -0.522 , -0.3925,  0.1   ],
#        [-0.995 , -0.4756, -0.3505, -0.12  ]])

# %%
train_data.shape
# Out:
# (216, 4)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],4)
# Out:
# array([[-0.999 ,  0.0487,  0.1168,  0.02  ],
#        [-0.9993,  0.0673,  0.1028, -0.42  ],
#        [-0.9979,  0.1879,  0.0981, -0.06  ],
#        [-0.9975,  0.0719,  0.0748,  0.08  ],
#        [-0.99  ,  0.0858,  0.0187, -0.1   ]])

# %%
test_data.shape
# Out:
# (60, 4)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data[:,:1], color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data[:,:1], color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    # return value
    return agg

# %% [markdown]
# - hasil supervised learning data train

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train_data, 1, 1)

# %%
reframed_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723 -0.522042 -0.476636
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030 -0.433875 -0.439252
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644 -0.522042 -0.392523
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012 -0.475638 -0.350467
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307 -0.336427 -0.289720
#
#    var4(t)
# 1     0.60
# 2     0.34
# 3     0.10
# 4    -0.12
# 5     0.14

# %%
# Jika menggunakan anom sst, oni, dan soi.
# # drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[5,6,7]], axis=1, inplace=True)

# Jika menggunakan semua parameter
# drop columns we don't want to predict
# reframed_train.drop(reframed_train.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_train.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (215, 4) (215,)

# %% [markdown]
# - hasil supervised learning data test

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test_data, 1, 1)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307  0.067285  0.102804
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922  0.187935  0.098131
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506  0.071926  0.074766
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024  0.085847  0.018692
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319  0.016241 -0.023364
#
#    var4(t)
# 1    -0.42
# 2    -0.06
# 3     0.08
# 4    -0.10
# 5    -0.10

# %%
# Jika menggunakan semua parameter
# drop columns we don't want to predict
# reframed_test.drop(reframed_test.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

reframed_test.drop(reframed_test.columns[[5,6,7]], axis=1, inplace=True)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (59, 4) (59,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  215 non-null    float64
#  1   var2(t-1)  215 non-null    float64
#  2   var3(t-1)  215 non-null    float64
#  3   var4(t-1)  215 non-null    float64
#  4   var1(t)    215 non-null    float64
# dtypes: float64(5)
# memory usage: 10.1 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  59 non-null     float64
#  1   var2(t-1)  59 non-null     float64
#  2   var3(t-1)  59 non-null     float64
#  3   var4(t-1)  59 non-null     float64
#  4   var1(t)    59 non-null     float64
# dtypes: float64(5)
# memory usage: 2.8 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (215, 1, 4) (215,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (59, 1, 4) (59,)

# %% [markdown]
# ### 5. Model Prediksi Titik Panas

# %%
# call function
from class_base_model import lstm_algorithm
from class_base_model import gru_algorithm

# check algorithm
if algorithm == "LSTM-RNN":
    # call model LSTM-RNN
    model = lstm_algorithm(trainX, activation, dropout_rate, optimizer)
else:
    # call model GRU-RNN
    model = gru_algorithm(trainX, activation, dropout_rate, optimizer)

# fit network
history = model.fit(
    trainX, trainY, batch_size=batch_size, epochs=epochs,
    validation_data=(testX, testY), verbose=1, shuffle=False, use_multiprocessing=True
)
# Out:
# Epoch 1/1500
# 7/7 [==============================] - 9s 176ms/step - loss: 0.9173 - mean_absolute_error: 0.9173 - mean_squared_error: 0.8660 - val_loss: 0.9330 - val_mean_absolute_error: 0.9330 - val_mean_squared_error: 0.8857
# Epoch 2/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.8990 - mean_absolute_error: 0.8990 - mean_squared_error: 0.8321 - val_loss: 0.9171 - val_mean_absolute_error: 0.9171 - val_mean_squared_error: 0.8561
# Epoch 3/1500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8844 - mean_absolute_error: 0.8844 - mean_squared_error: 0.8057 - val_loss: 0.9020 - val_mean_absolute_error: 0.9020 - val_mean_squared_error: 0.8288
# Epoch 4/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.8698 - mean_absolute_error: 0.8698 - mean_squared_error: 0.7800 - val_loss: 0.8867 - val_mean_absolute_error: 0.8867 - val_mean_squared_error: 0.8012
# Epoch 5/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.8546 - mean_absolute_error: 0.8546 - mean_squared_error: 0.7534 - val_loss: 0.8706 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 0.7729
# Epoch 6/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.8392 - mean_absolute_error: 0.8392 - mean_squared_error: 0.7271 - val_loss: 0.8536 - val_mean_absolute_error: 0.8536 - val_mean_squared_error: 0.7435
# Epoch 7/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.8226 - mean_absolute_error: 0.8226 - mean_squared_error: 0.6989 - val_loss: 0.8351 - val_mean_absolute_error: 0.8351 - val_mean_squared_error: 0.7122
# Epoch 8/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.8039 - mean_absolute_error: 0.8039 - mean_squared_error: 0.6689 - val_loss: 0.8148 - val_mean_absolute_error: 0.8148 - val_mean_squared_error: 0.6786
# Epoch 9/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.7841 - mean_absolute_error: 0.7841 - mean_squared_error: 0.6366 - val_loss: 0.7925 - val_mean_absolute_error: 0.7925 - val_mean_squared_error: 0.6425
# Epoch 10/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.7629 - mean_absolute_error: 0.7629 - mean_squared_error: 0.6038 - val_loss: 0.7676 - val_mean_absolute_error: 0.7676 - val_mean_squared_error: 0.6036
# Epoch 11/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.7372 - mean_absolute_error: 0.7372 - mean_squared_error: 0.5656 - val_loss: 0.7398 - val_mean_absolute_error: 0.7398 - val_mean_squared_error: 0.5614
# Epoch 12/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.7077 - mean_absolute_error: 0.7077 - mean_squared_error: 0.5223 - val_loss: 0.7081 - val_mean_absolute_error: 0.7081 - val_mean_squared_error: 0.5151
# Epoch 13/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6768 - mean_absolute_error: 0.6768 - mean_squared_error: 0.4799 - val_loss: 0.6719 - val_mean_absolute_error: 0.6719 - val_mean_squared_error: 0.4648
# Epoch 14/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6458 - mean_absolute_error: 0.6458 - mean_squared_error: 0.4397 - val_loss: 0.6309 - val_mean_absolute_error: 0.6309 - val_mean_squared_error: 0.4109
# Epoch 15/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6063 - mean_absolute_error: 0.6063 - mean_squared_error: 0.3906 - val_loss: 0.5822 - val_mean_absolute_error: 0.5822 - val_mean_squared_error: 0.3514
# Epoch 16/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.5480 - mean_absolute_error: 0.5480 - mean_squared_error: 0.3212 - val_loss: 0.5235 - val_mean_absolute_error: 0.5235 - val_mean_squared_error: 0.2863
# Epoch 17/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4970 - mean_absolute_error: 0.4970 - mean_squared_error: 0.2709 - val_loss: 0.4563 - val_mean_absolute_error: 0.4563 - val_mean_squared_error: 0.2195
# Epoch 18/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.4367 - mean_absolute_error: 0.4367 - mean_squared_error: 0.2177 - val_loss: 0.3757 - val_mean_absolute_error: 0.3757 - val_mean_squared_error: 0.1525
# Epoch 19/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3662 - mean_absolute_error: 0.3662 - mean_squared_error: 0.1673 - val_loss: 0.2814 - val_mean_absolute_error: 0.2814 - val_mean_squared_error: 0.0929
# Epoch 20/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2893 - mean_absolute_error: 0.2893 - mean_squared_error: 0.1221 - val_loss: 0.1858 - val_mean_absolute_error: 0.1858 - val_mean_squared_error: 0.0542
# Epoch 21/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2403 - mean_absolute_error: 0.2403 - mean_squared_error: 0.0921 - val_loss: 0.1540 - val_mean_absolute_error: 0.1540 - val_mean_squared_error: 0.0394
# Epoch 22/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2335 - mean_absolute_error: 0.2335 - mean_squared_error: 0.0893 - val_loss: 0.1443 - val_mean_absolute_error: 0.1443 - val_mean_squared_error: 0.0325
# Epoch 23/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2018 - mean_absolute_error: 0.2018 - mean_squared_error: 0.0743 - val_loss: 0.1387 - val_mean_absolute_error: 0.1387 - val_mean_squared_error: 0.0289
# Epoch 24/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2138 - mean_absolute_error: 0.2138 - mean_squared_error: 0.0828 - val_loss: 0.1295 - val_mean_absolute_error: 0.1295 - val_mean_squared_error: 0.0258
# Epoch 25/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1889 - mean_absolute_error: 0.1889 - mean_squared_error: 0.0715 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216 - val_mean_squared_error: 0.0231
# Epoch 26/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1949 - mean_absolute_error: 0.1949 - mean_squared_error: 0.0781 - val_loss: 0.1144 - val_mean_absolute_error: 0.1144 - val_mean_squared_error: 0.0205
# Epoch 27/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1910 - mean_absolute_error: 0.1910 - mean_squared_error: 0.0733 - val_loss: 0.1066 - val_mean_absolute_error: 0.1066 - val_mean_squared_error: 0.0184
# Epoch 28/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1853 - mean_absolute_error: 0.1853 - mean_squared_error: 0.0705 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974 - val_mean_squared_error: 0.0174
# Epoch 29/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1833 - mean_absolute_error: 0.1833 - mean_squared_error: 0.0732 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919 - val_mean_squared_error: 0.0152
# Epoch 30/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1766 - mean_absolute_error: 0.1766 - mean_squared_error: 0.0697 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861 - val_mean_squared_error: 0.0136
# Epoch 31/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1765 - mean_absolute_error: 0.1765 - mean_squared_error: 0.0718 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814 - val_mean_squared_error: 0.0137
# Epoch 32/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0658 - val_loss: 0.0756 - val_mean_absolute_error: 0.0756 - val_mean_squared_error: 0.0123
# Epoch 33/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1743 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0696 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710 - val_mean_squared_error: 0.0116
# Epoch 34/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1549 - mean_absolute_error: 0.1549 - mean_squared_error: 0.0597 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0108
# Epoch 35/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1665 - mean_absolute_error: 0.1665 - mean_squared_error: 0.0642 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - val_mean_squared_error: 0.0101
# Epoch 36/1500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1774 - mean_absolute_error: 0.1774 - mean_squared_error: 0.0721 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0098
# Epoch 37/1500
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0717 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - val_mean_squared_error: 0.0103
# Epoch 38/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1619 - mean_absolute_error: 0.1619 - mean_squared_error: 0.0612 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0104
# Epoch 39/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - mean_squared_error: 0.0624 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - val_mean_squared_error: 0.0099
# Epoch 40/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1568 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0651 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923 - val_mean_squared_error: 0.0127
# Epoch 41/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - mean_squared_error: 0.0605 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - val_mean_squared_error: 0.0097
# Epoch 42/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - mean_squared_error: 0.0588 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111 - val_mean_squared_error: 0.0156
# Epoch 43/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1419 - mean_absolute_error: 0.1419 - mean_squared_error: 0.0536 - val_loss: 0.0772 - val_mean_absolute_error: 0.0772 - val_mean_squared_error: 0.0111
# Epoch 44/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1495 - mean_absolute_error: 0.1495 - mean_squared_error: 0.0594 - val_loss: 0.0785 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0112
# Epoch 45/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1587 - mean_absolute_error: 0.1587 - mean_squared_error: 0.0686 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - val_mean_squared_error: 0.0102
# Epoch 46/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0618 - val_loss: 0.0675 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0104
# Epoch 47/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - mean_squared_error: 0.0610 - val_loss: 0.0901 - val_mean_absolute_error: 0.0901 - val_mean_squared_error: 0.0124
# Epoch 48/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - mean_squared_error: 0.0643 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - val_mean_squared_error: 0.0102
# Epoch 49/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1423 - mean_absolute_error: 0.1423 - mean_squared_error: 0.0574 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0107
# Epoch 50/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1485 - mean_absolute_error: 0.1485 - mean_squared_error: 0.0604 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - val_mean_squared_error: 0.0100
# Epoch 51/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1453 - mean_absolute_error: 0.1453 - mean_squared_error: 0.0557 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691 - val_mean_squared_error: 0.0105
# Epoch 52/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1410 - mean_absolute_error: 0.1410 - mean_squared_error: 0.0601 - val_loss: 0.0674 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0105
# Epoch 53/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1394 - mean_absolute_error: 0.1394 - mean_squared_error: 0.0578 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0104
# Epoch 54/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1523 - mean_absolute_error: 0.1523 - mean_squared_error: 0.0669 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0108
# Epoch 55/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1440 - mean_absolute_error: 0.1440 - mean_squared_error: 0.0593 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0104
# Epoch 56/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1404 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0601 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652 - val_mean_squared_error: 0.0103
# Epoch 57/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1588 - mean_absolute_error: 0.1588 - mean_squared_error: 0.0609 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0103
# Epoch 58/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - mean_squared_error: 0.0604 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0105
# Epoch 59/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - mean_squared_error: 0.0601 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - val_mean_squared_error: 0.0101
# Epoch 60/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1423 - mean_absolute_error: 0.1423 - mean_squared_error: 0.0611 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0107
# Epoch 61/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1322 - mean_absolute_error: 0.1322 - mean_squared_error: 0.0548 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664 - val_mean_squared_error: 0.0104
# Epoch 62/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - mean_squared_error: 0.0657 - val_loss: 0.0777 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0112
# Epoch 63/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0560 - val_loss: 0.0668 - val_mean_absolute_error: 0.0668 - val_mean_squared_error: 0.0105
# Epoch 64/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1430 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0604 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603 - val_mean_squared_error: 0.0102
# Epoch 65/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1407 - mean_absolute_error: 0.1407 - mean_squared_error: 0.0600 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697 - val_mean_squared_error: 0.0107
# Epoch 66/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0632 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - val_mean_squared_error: 0.0100
# Epoch 67/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - mean_squared_error: 0.0567 - val_loss: 0.0862 - val_mean_absolute_error: 0.0862 - val_mean_squared_error: 0.0121
# Epoch 68/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1349 - mean_absolute_error: 0.1349 - mean_squared_error: 0.0571 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - val_mean_squared_error: 0.0099
# Epoch 69/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1441 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0602 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0108
# Epoch 70/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1361 - mean_absolute_error: 0.1361 - mean_squared_error: 0.0557 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0107
# Epoch 71/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1376 - mean_absolute_error: 0.1376 - mean_squared_error: 0.0591 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - val_mean_squared_error: 0.0104
# Epoch 72/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1455 - mean_absolute_error: 0.1455 - mean_squared_error: 0.0589 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607 - val_mean_squared_error: 0.0103
# Epoch 73/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1450 - mean_absolute_error: 0.1450 - mean_squared_error: 0.0604 - val_loss: 0.0653 - val_mean_absolute_error: 0.0653 - val_mean_squared_error: 0.0106
# Epoch 74/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1369 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0598 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - val_mean_squared_error: 0.0107
# Epoch 75/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1412 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0616 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0109
# Epoch 76/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1326 - mean_absolute_error: 0.1326 - mean_squared_error: 0.0574 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832 - val_mean_squared_error: 0.0120
# Epoch 77/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0602 - val_loss: 0.0660 - val_mean_absolute_error: 0.0660 - val_mean_squared_error: 0.0107
# Epoch 78/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0610 - val_loss: 0.0777 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0116
# Epoch 79/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0599 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - val_mean_squared_error: 0.0105
# Epoch 80/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1441 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0620 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0107
# Epoch 81/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - mean_squared_error: 0.0609 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739 - val_mean_squared_error: 0.0112
# Epoch 82/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0568 - val_loss: 0.0785 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0116
# Epoch 83/1500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - mean_squared_error: 0.0602 - val_loss: 0.0777 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0115
# Epoch 84/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1438 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0618 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - val_mean_squared_error: 0.0105
# Epoch 85/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - mean_squared_error: 0.0597 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_mean_squared_error: 0.0105
# Epoch 86/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0561 - val_loss: 0.0841 - val_mean_absolute_error: 0.0841 - val_mean_squared_error: 0.0121
# Epoch 87/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0596 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637 - val_mean_squared_error: 0.0104
# Epoch 88/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1364 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0605 - val_loss: 0.0680 - val_mean_absolute_error: 0.0680 - val_mean_squared_error: 0.0107
# Epoch 89/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - mean_squared_error: 0.0585 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730 - val_mean_squared_error: 0.0111
# Epoch 90/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1278 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0581 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - val_mean_squared_error: 0.0105
# Epoch 91/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1369 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0579 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0113
# Epoch 92/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1321 - mean_absolute_error: 0.1321 - mean_squared_error: 0.0568 - val_loss: 0.0669 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0107
# Epoch 93/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1350 - mean_absolute_error: 0.1350 - mean_squared_error: 0.0573 - val_loss: 0.0822 - val_mean_absolute_error: 0.0822 - val_mean_squared_error: 0.0120
# Epoch 94/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0631 - val_loss: 0.0675 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0108
# Epoch 95/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1371 - mean_absolute_error: 0.1371 - mean_squared_error: 0.0589 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835 - val_mean_squared_error: 0.0122
# Epoch 96/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0613 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0104
# Epoch 97/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1377 - mean_absolute_error: 0.1377 - mean_squared_error: 0.0604 - val_loss: 0.0754 - val_mean_absolute_error: 0.0754 - val_mean_squared_error: 0.0115
# Epoch 98/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0573 - val_loss: 0.0751 - val_mean_absolute_error: 0.0751 - val_mean_squared_error: 0.0114
# Epoch 99/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1382 - mean_absolute_error: 0.1382 - mean_squared_error: 0.0646 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0106
# Epoch 100/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - mean_squared_error: 0.0602 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699 - val_mean_squared_error: 0.0110
# Epoch 101/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1324 - mean_absolute_error: 0.1324 - mean_squared_error: 0.0582 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - val_mean_squared_error: 0.0105
# Epoch 102/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1221 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0560 - val_loss: 0.0635 - val_mean_absolute_error: 0.0635 - val_mean_squared_error: 0.0107
# Epoch 103/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1293 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0606 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0105
# Epoch 104/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1277 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0588 - val_loss: 0.0806 - val_mean_absolute_error: 0.0806 - val_mean_squared_error: 0.0118
# Epoch 105/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1215 - mean_absolute_error: 0.1215 - mean_squared_error: 0.0589 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0104
# Epoch 106/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0624 - val_loss: 0.0743 - val_mean_absolute_error: 0.0743 - val_mean_squared_error: 0.0115
# Epoch 107/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1359 - mean_absolute_error: 0.1359 - mean_squared_error: 0.0577 - val_loss: 0.0665 - val_mean_absolute_error: 0.0665 - val_mean_squared_error: 0.0111
# Epoch 108/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1441 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0651 - val_loss: 0.0662 - val_mean_absolute_error: 0.0662 - val_mean_squared_error: 0.0110
# Epoch 109/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0609 - val_loss: 0.0639 - val_mean_absolute_error: 0.0639 - val_mean_squared_error: 0.0111
# Epoch 110/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1239 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0591 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0108
# Epoch 111/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - mean_squared_error: 0.0602 - val_loss: 0.0718 - val_mean_absolute_error: 0.0718 - val_mean_squared_error: 0.0113
# Epoch 112/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1384 - mean_absolute_error: 0.1384 - mean_squared_error: 0.0627 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713 - val_mean_squared_error: 0.0113
# Epoch 113/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1303 - mean_absolute_error: 0.1303 - mean_squared_error: 0.0605 - val_loss: 0.0774 - val_mean_absolute_error: 0.0774 - val_mean_squared_error: 0.0117
# Epoch 114/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1284 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0612 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - val_mean_squared_error: 0.0106
# Epoch 115/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1272 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0601 - val_loss: 0.0747 - val_mean_absolute_error: 0.0747 - val_mean_squared_error: 0.0115
# Epoch 116/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1214 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0574 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - val_mean_squared_error: 0.0108
# Epoch 117/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1289 - mean_absolute_error: 0.1289 - mean_squared_error: 0.0584 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - val_mean_squared_error: 0.0109
# Epoch 118/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0573 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - val_mean_squared_error: 0.0109
# Epoch 119/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1308 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0586 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_mean_squared_error: 0.0109
# Epoch 120/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1237 - mean_absolute_error: 0.1237 - mean_squared_error: 0.0558 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0111
# Epoch 121/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1282 - mean_absolute_error: 0.1282 - mean_squared_error: 0.0589 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0115
# Epoch 122/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1341 - mean_absolute_error: 0.1341 - mean_squared_error: 0.0643 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0113
# Epoch 123/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1259 - mean_absolute_error: 0.1259 - mean_squared_error: 0.0593 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738 - val_mean_squared_error: 0.0116
# Epoch 124/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0596 - val_loss: 0.0766 - val_mean_absolute_error: 0.0766 - val_mean_squared_error: 0.0118
# Epoch 125/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1323 - mean_absolute_error: 0.1323 - mean_squared_error: 0.0591 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - val_mean_squared_error: 0.0109
# Epoch 126/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1286 - mean_absolute_error: 0.1286 - mean_squared_error: 0.0586 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - val_mean_squared_error: 0.0107
# Epoch 127/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1329 - mean_absolute_error: 0.1329 - mean_squared_error: 0.0616 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_mean_squared_error: 0.0106
# Epoch 128/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1306 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0617 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664 - val_mean_squared_error: 0.0110
# Epoch 129/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1162 - mean_absolute_error: 0.1162 - mean_squared_error: 0.0557 - val_loss: 0.0780 - val_mean_absolute_error: 0.0780 - val_mean_squared_error: 0.0118
# Epoch 130/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1296 - mean_absolute_error: 0.1296 - mean_squared_error: 0.0600 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - val_mean_squared_error: 0.0106
# Epoch 131/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1332 - mean_absolute_error: 0.1332 - mean_squared_error: 0.0621 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652 - val_mean_squared_error: 0.0111
# Epoch 132/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1285 - mean_absolute_error: 0.1285 - mean_squared_error: 0.0598 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0107
# Epoch 133/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1195 - mean_absolute_error: 0.1195 - mean_squared_error: 0.0550 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - val_mean_squared_error: 0.0106
# Epoch 134/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1162 - mean_absolute_error: 0.1162 - mean_squared_error: 0.0539 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - val_mean_squared_error: 0.0108
# Epoch 135/1500
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1244 - mean_absolute_error: 0.1244 - mean_squared_error: 0.0585 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - val_mean_squared_error: 0.0108
# Epoch 136/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0575 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637 - val_mean_squared_error: 0.0110
# Epoch 137/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1271 - mean_absolute_error: 0.1271 - mean_squared_error: 0.0581 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - val_mean_squared_error: 0.0110
# Epoch 138/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1203 - mean_absolute_error: 0.1203 - mean_squared_error: 0.0572 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0110
# Epoch 139/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1265 - mean_absolute_error: 0.1265 - mean_squared_error: 0.0600 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_mean_squared_error: 0.0108
# Epoch 140/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1252 - mean_absolute_error: 0.1252 - mean_squared_error: 0.0552 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - val_mean_squared_error: 0.0107
# Epoch 141/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1263 - mean_absolute_error: 0.1263 - mean_squared_error: 0.0616 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595 - val_mean_squared_error: 0.0110
# Epoch 142/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1265 - mean_absolute_error: 0.1265 - mean_squared_error: 0.0581 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596 - val_mean_squared_error: 0.0111
# Epoch 143/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1255 - mean_absolute_error: 0.1255 - mean_squared_error: 0.0602 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686 - val_mean_squared_error: 0.0115
# Epoch 144/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0630 - val_loss: 0.0626 - val_mean_absolute_error: 0.0626 - val_mean_squared_error: 0.0111
# Epoch 145/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1233 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0610 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604 - val_mean_squared_error: 0.0111
# Epoch 146/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1250 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0592 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - val_mean_squared_error: 0.0110
# Epoch 147/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1231 - mean_absolute_error: 0.1231 - mean_squared_error: 0.0575 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686 - val_mean_squared_error: 0.0114
# Epoch 148/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1165 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0561 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0111
# Epoch 149/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1222 - mean_absolute_error: 0.1222 - mean_squared_error: 0.0625 - val_loss: 0.0661 - val_mean_absolute_error: 0.0661 - val_mean_squared_error: 0.0115
# Epoch 150/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1260 - mean_absolute_error: 0.1260 - mean_squared_error: 0.0600 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - val_mean_squared_error: 0.0114
# Epoch 151/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0612 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - val_mean_squared_error: 0.0112
# Epoch 152/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1167 - mean_absolute_error: 0.1167 - mean_squared_error: 0.0563 - val_loss: 0.0760 - val_mean_absolute_error: 0.0760 - val_mean_squared_error: 0.0120
# Epoch 153/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1253 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0594 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0111
# Epoch 154/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1165 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0574 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0111
# Epoch 155/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1202 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0598 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - val_mean_squared_error: 0.0113
# Epoch 156/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - mean_squared_error: 0.0577 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - val_mean_squared_error: 0.0111
# Epoch 157/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0633 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0111
# Epoch 158/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1268 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0589 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696 - val_mean_squared_error: 0.0116
# Epoch 159/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1136 - mean_absolute_error: 0.1136 - mean_squared_error: 0.0570 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0115
# Epoch 160/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1161 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0542 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - val_mean_squared_error: 0.0112
# Epoch 161/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1203 - mean_absolute_error: 0.1203 - mean_squared_error: 0.0586 - val_loss: 0.0804 - val_mean_absolute_error: 0.0804 - val_mean_squared_error: 0.0124
# Epoch 162/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1246 - mean_absolute_error: 0.1246 - mean_squared_error: 0.0580 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0112
# Epoch 163/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1236 - mean_absolute_error: 0.1236 - mean_squared_error: 0.0610 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - val_mean_squared_error: 0.0112
# Epoch 164/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0577 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - val_mean_squared_error: 0.0114
# Epoch 165/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - mean_squared_error: 0.0579 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_mean_squared_error: 0.0112
# Epoch 166/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1122 - mean_absolute_error: 0.1122 - mean_squared_error: 0.0564 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0111
# Epoch 167/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1183 - mean_absolute_error: 0.1183 - mean_squared_error: 0.0603 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - val_mean_squared_error: 0.0112
# Epoch 168/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1115 - mean_absolute_error: 0.1115 - mean_squared_error: 0.0544 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643 - val_mean_squared_error: 0.0114
# Epoch 169/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1120 - mean_absolute_error: 0.1120 - mean_squared_error: 0.0556 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0113
# Epoch 170/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - mean_squared_error: 0.0595 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - val_mean_squared_error: 0.0112
# Epoch 171/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0584 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_mean_squared_error: 0.0114
# Epoch 172/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1090 - mean_absolute_error: 0.1090 - mean_squared_error: 0.0551 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0115
# Epoch 173/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1177 - mean_absolute_error: 0.1177 - mean_squared_error: 0.0581 - val_loss: 0.0750 - val_mean_absolute_error: 0.0750 - val_mean_squared_error: 0.0121
# Epoch 174/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1194 - mean_absolute_error: 0.1194 - mean_squared_error: 0.0568 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_mean_squared_error: 0.0113
# Epoch 175/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1142 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0592 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - val_mean_squared_error: 0.0116
# Epoch 176/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0590 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - val_mean_squared_error: 0.0114
# Epoch 177/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1125 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0591 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0115
# Epoch 178/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0584 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - val_mean_squared_error: 0.0114
# Epoch 179/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1204 - mean_absolute_error: 0.1204 - mean_squared_error: 0.0592 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0111
# Epoch 180/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1161 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0596 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0115
# Epoch 181/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1177 - mean_absolute_error: 0.1177 - mean_squared_error: 0.0569 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - val_mean_squared_error: 0.0113
# Epoch 182/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1102 - mean_absolute_error: 0.1102 - mean_squared_error: 0.0563 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - val_mean_squared_error: 0.0112
# Epoch 183/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1141 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0582 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - val_mean_squared_error: 0.0114
# Epoch 184/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0575 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - val_mean_squared_error: 0.0114
# Epoch 185/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1097 - mean_absolute_error: 0.1097 - mean_squared_error: 0.0546 - val_loss: 0.0624 - val_mean_absolute_error: 0.0624 - val_mean_squared_error: 0.0115
# Epoch 186/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1130 - mean_absolute_error: 0.1130 - mean_squared_error: 0.0606 - val_loss: 0.0626 - val_mean_absolute_error: 0.0626 - val_mean_squared_error: 0.0116
# Epoch 187/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1141 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0570 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0113
# Epoch 188/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1163 - mean_absolute_error: 0.1163 - mean_squared_error: 0.0581 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0115
# Epoch 189/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1110 - mean_absolute_error: 0.1110 - mean_squared_error: 0.0575 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - val_mean_squared_error: 0.0113
# Epoch 190/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1096 - mean_absolute_error: 0.1096 - mean_squared_error: 0.0576 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685 - val_mean_squared_error: 0.0118
# Epoch 191/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1116 - mean_absolute_error: 0.1116 - mean_squared_error: 0.0592 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0113
# Epoch 192/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1110 - mean_absolute_error: 0.1110 - mean_squared_error: 0.0568 - val_loss: 0.0674 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0118
# Epoch 193/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1109 - mean_absolute_error: 0.1109 - mean_squared_error: 0.0581 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - val_mean_squared_error: 0.0115
# Epoch 194/1500
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1069 - mean_absolute_error: 0.1069 - mean_squared_error: 0.0570 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - val_mean_squared_error: 0.0115
# Epoch 195/1500
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1121 - mean_absolute_error: 0.1121 - mean_squared_error: 0.0582 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - val_mean_squared_error: 0.0116
# Epoch 196/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1058 - mean_absolute_error: 0.1058 - mean_squared_error: 0.0566 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - val_mean_squared_error: 0.0116
# Epoch 197/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1106 - mean_absolute_error: 0.1106 - mean_squared_error: 0.0549 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - val_mean_squared_error: 0.0117
# Epoch 198/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1141 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0582 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603 - val_mean_squared_error: 0.0117
# Epoch 199/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1047 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0541 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0117
# Epoch 200/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1135 - mean_absolute_error: 0.1135 - mean_squared_error: 0.0594 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0118
# Epoch 201/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1101 - mean_absolute_error: 0.1101 - mean_squared_error: 0.0572 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0117
# Epoch 202/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1070 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0584 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - val_mean_squared_error: 0.0117
# Epoch 203/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1128 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0554 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - val_mean_squared_error: 0.0116
# Epoch 204/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1101 - mean_absolute_error: 0.1101 - mean_squared_error: 0.0581 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0118
# Epoch 205/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1105 - mean_absolute_error: 0.1105 - mean_squared_error: 0.0562 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0116
# Epoch 206/1500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1089 - mean_absolute_error: 0.1089 - mean_squared_error: 0.0575 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - val_mean_squared_error: 0.0115
# Epoch 207/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1065 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0586 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - val_mean_squared_error: 0.0115
# Epoch 208/1500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1105 - mean_absolute_error: 0.1105 - mean_squared_error: 0.0585 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0115
# Epoch 209/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1134 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0597 - val_loss: 0.0452 - val_mean_absolute_error: 0.0452 - val_mean_squared_error: 0.0114
# Epoch 210/1500
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1105 - mean_absolute_error: 0.1105 - mean_squared_error: 0.0571 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0114
# Epoch 211/1500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1059 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0585 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0115
# Epoch 212/1500
# ...
# Epoch 1431/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0638 - mean_absolute_error: 0.0638 - mean_squared_error: 0.0337 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0073
# Epoch 1432/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0608 - mean_absolute_error: 0.0608 - mean_squared_error: 0.0315 - val_loss: 0.0294 - val_mean_absolute_error: 0.0294 - val_mean_squared_error: 0.0072
# Epoch 1433/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0636 - mean_absolute_error: 0.0636 - mean_squared_error: 0.0325 - val_loss: 0.0294 - val_mean_absolute_error: 0.0294 - val_mean_squared_error: 0.0075
# Epoch 1434/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0610 - mean_absolute_error: 0.0610 - mean_squared_error: 0.0311 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0071
# Epoch 1435/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0629 - mean_absolute_error: 0.0629 - mean_squared_error: 0.0314 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0073
# Epoch 1436/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0286 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0073
# Epoch 1437/1500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - mean_squared_error: 0.0392 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0072
# Epoch 1438/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0634 - mean_absolute_error: 0.0634 - mean_squared_error: 0.0316 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0073
# Epoch 1439/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0387 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0074
# Epoch 1440/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0259 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0072
# Epoch 1441/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0627 - mean_absolute_error: 0.0627 - mean_squared_error: 0.0293 - val_loss: 0.0300 - val_mean_absolute_error: 0.0300 - val_mean_squared_error: 0.0072
# Epoch 1442/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0635 - mean_absolute_error: 0.0635 - mean_squared_error: 0.0360 - val_loss: 0.0355 - val_mean_absolute_error: 0.0355 - val_mean_squared_error: 0.0071
# Epoch 1443/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0646 - mean_absolute_error: 0.0646 - mean_squared_error: 0.0310 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0071
# Epoch 1444/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0293 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0074
# Epoch 1445/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0300 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0072
# Epoch 1446/1500
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - mean_squared_error: 0.0314 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0075
# Epoch 1447/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0594 - mean_absolute_error: 0.0594 - mean_squared_error: 0.0273 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0077
# Epoch 1448/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0343 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0073
# Epoch 1449/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0591 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0273 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0074
# Epoch 1450/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0365 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0073
# Epoch 1451/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0635 - mean_absolute_error: 0.0635 - mean_squared_error: 0.0319 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 0.0074
# Epoch 1452/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0636 - mean_absolute_error: 0.0636 - mean_squared_error: 0.0324 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 0.0073
# Epoch 1453/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0274 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0074
# Epoch 1454/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0639 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0344 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0073
# Epoch 1455/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - mean_squared_error: 0.0364 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0072
# Epoch 1456/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0622 - mean_absolute_error: 0.0622 - mean_squared_error: 0.0318 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0074
# Epoch 1457/1500
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0652 - mean_absolute_error: 0.0652 - mean_squared_error: 0.0367 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0072
# Epoch 1458/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - mean_squared_error: 0.0310 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0075
# Epoch 1459/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0597 - mean_absolute_error: 0.0597 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0073
# Epoch 1460/1500
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0648 - mean_absolute_error: 0.0648 - mean_squared_error: 0.0334 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0075
# Epoch 1461/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0644 - mean_absolute_error: 0.0644 - mean_squared_error: 0.0385 - val_loss: 0.0344 - val_mean_absolute_error: 0.0344 - val_mean_squared_error: 0.0072
# Epoch 1462/1500
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - mean_squared_error: 0.0315 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0076
# Epoch 1463/1500
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0337 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0076
# Epoch 1464/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0621 - mean_absolute_error: 0.0621 - mean_squared_error: 0.0345 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0076
# Epoch 1465/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0305 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0075
# Epoch 1466/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - mean_squared_error: 0.0279 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0076
# Epoch 1467/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0590 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0278 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0074
# Epoch 1468/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0320 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0075
# Epoch 1469/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0630 - mean_absolute_error: 0.0630 - mean_squared_error: 0.0309 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0076
# Epoch 1470/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0654 - mean_absolute_error: 0.0654 - mean_squared_error: 0.0359 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0076
# Epoch 1471/1500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - mean_squared_error: 0.0283 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0074
# Epoch 1472/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0399 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0075
# Epoch 1473/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0641 - mean_absolute_error: 0.0641 - mean_squared_error: 0.0342 - val_loss: 0.0294 - val_mean_absolute_error: 0.0294 - val_mean_squared_error: 0.0073
# Epoch 1474/1500
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0668 - mean_absolute_error: 0.0668 - mean_squared_error: 0.0354 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0073
# Epoch 1475/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0644 - mean_absolute_error: 0.0644 - mean_squared_error: 0.0327 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0074
# Epoch 1476/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0329 - val_loss: 0.0315 - val_mean_absolute_error: 0.0315 - val_mean_squared_error: 0.0072
# Epoch 1477/1500
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0654 - mean_absolute_error: 0.0654 - mean_squared_error: 0.0345 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0075
# Epoch 1478/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - mean_squared_error: 0.0318 - val_loss: 0.0326 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0072
# Epoch 1479/1500
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0613 - mean_absolute_error: 0.0613 - mean_squared_error: 0.0265 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0075
# Epoch 1480/1500
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0614 - mean_absolute_error: 0.0614 - mean_squared_error: 0.0285 - val_loss: 0.0305 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0073
# Epoch 1481/1500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0343 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0073
# Epoch 1482/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0602 - mean_absolute_error: 0.0602 - mean_squared_error: 0.0275 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0072
# Epoch 1483/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0625 - mean_absolute_error: 0.0625 - mean_squared_error: 0.0302 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 0.0075
# Epoch 1484/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0702 - mean_absolute_error: 0.0702 - mean_squared_error: 0.0453 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0073
# Epoch 1485/1500
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - mean_squared_error: 0.0299 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0072
# Epoch 1486/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0266 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0073
# Epoch 1487/1500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0339 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0074
# Epoch 1488/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0370 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0071
# Epoch 1489/1500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0703 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0414 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0073
# Epoch 1490/1500
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0607 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0270 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0072
# Epoch 1491/1500
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0591 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0283 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0072
# Epoch 1492/1500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0325 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0074
# Epoch 1493/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0600 - mean_absolute_error: 0.0600 - mean_squared_error: 0.0287 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0072
# Epoch 1494/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0657 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0380 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0076
# Epoch 1495/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0636 - mean_absolute_error: 0.0636 - mean_squared_error: 0.0314 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0074
# Epoch 1496/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0620 - mean_absolute_error: 0.0620 - mean_squared_error: 0.0352 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0072
# Epoch 1497/1500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - mean_squared_error: 0.0312 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0072
# Epoch 1498/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0280 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0075
# Epoch 1499/1500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - mean_squared_error: 0.0292 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0075
# Epoch 1500/1500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0605 - mean_absolute_error: 0.0605 - mean_squared_error: 0.0299 - val_loss: 0.0300 - val_mean_absolute_error: 0.0300 - val_mean_squared_error: 0.0073

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 20)             1200
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 1, 20)             2480
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 20)                2480
#  onal)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 6181 (24.14 KB)
# Trainable params: 6181 (24.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=1.5)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=1.5)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.9979449  -0.99972767 -0.9944415  -0.99861324 -0.98908764 -0.9968549
#  -0.9915939  -0.83717144 -0.3753748  -0.52928203 -0.676296   -0.99507815
#  -0.9977625  -0.9807463  -0.9854622  -0.9884485  -0.9963405  -0.9956112
#  -0.99661446 -0.9965114  -0.99643165 -0.9977622  -0.99772036 -0.9972453
#  -0.99794275 -0.9968813  -0.9966688  -0.9960524  -0.99636286 -0.99655694
#  -0.99792475 -0.99630857 -0.9965105  -0.99604577 -0.99623454 -0.9963539
#  -0.99689484 -0.9965141  -0.99740833 -0.99709165 -0.9962292  -0.99796927
#  -0.9962305  -0.9958544  -0.99690515 -0.9974217  -0.9973687  -0.9978552
#  -0.99720085 -0.99805754 -0.9963843  -0.9895395  -0.9980319  -0.9993766
#  -0.9990814  -0.9489004  -0.43716753 -0.9794721  -0.99930465]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0602 - mean_absolute_error: 0.0602 - mean_squared_error: 0.0288
# [0.06019604206085205, 0.06019604206085205, 0.02878396585583687]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0300 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0073
# [0.029992904514074326, 0.029992904514074326, 0.0073457458056509495]

# %% [markdown]
# - MAE

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE: %.4f' % mae)
# Out:
# Test MAE: 0.0300

# %% [markdown]
# - MSE

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0073

# %% [markdown]
# - MAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions) * 100
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 4.6762

# %% [markdown]
# - korelasi dan signifikansi

# %%
hasil = np.stack((testY,predictions.reshape(-1)),axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999307 -0.997945
# 1    -0.997922 -0.999728
# 2    -0.997506 -0.994442
# 3    -0.990024 -0.998613
# 4    -0.994319 -0.989088

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.7684 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:04:37.49

# %% [markdown]
# ### 8. Visualisasi Hasil Prediksi

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], testY, color="tab:blue", label="data aktual", linewidth=2)
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], predictions, color="tab:red", label="hasil prediksi", linewidth=2)

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper right")
ax.grid(True)
plt.show()

# %% [markdown]
# ### 8. Hasil Prediksi Titik Panas

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(dataset[["hotspot"]]))

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(np.array(testY).reshape(-1, 1))

# %%
x = pd.DataFrame(np.array(dataset.iloc[train_size+1:len(dataset),0]), columns=['Date'])
y = pd.DataFrame(testActual, columns=['Data Aktual'])
z = pd.DataFrame(testPredictions, columns=['Data Prediksi'])

# %%
hasil_prediksi = pd.concat([x, y, z], axis=1)

# %%
hasil_prediksi = np.round(hasil_prediksi, 0)

# %%
# if algorithm == "LSTM-RNN":
#     hasil_prediksi.to_csv("hasil_prediksi_m1.csv", index=False)
# else:
#     hasil_prediksi.to_csv("hasil_prediksi_m4.csv", index=False)

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
fix, ax = plt.subplots(figsize=(10,5))

ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Aktual"], color="tab:blue", label="Data aktual", linewidth=2.5)
ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Prediksi"], color="tab:red", label="Hasil prediksi", linewidth=2.5)

# Mengatur format tanggal ke format tahun
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper right")
ax.grid(True)
plt.show()
