# %% [markdown]
# ## M3 dan M6 - Model Prediksi Titik Panas di Sumatera Selatan 2001 - 2023

# %% [markdown]
# - Jika dipengaruhi oleh enso

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

import random as rm
import time as tm

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# Setting seed
rm.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# # Setting Algorithm
# algorithm = "LSTM-RNN"

# %%
# Setting Algorithm
algorithm = "GRU-RNN"

# %%
# set parameter
activation = "relu"
dropout_rate = 0.20
optimizer = "adam"
batch_size = 2
epochs=1500

# %%
print(tf.__version__)
# Out:
# 2.14.0

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
# !gdown "1TMdNpuz0nyx5uAQ12477VpgOtJqfmxcI"
# !gdown "1a9EJFq3gej1LzJK86p6qEIdQ_VsOrsbl"

# %%
# from google.colab import drive

# drive.mount('/content/drive')
# dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/M3 M6 Anom/dataset_enso.csv", parse_dates=["acq_date"])

dataset = pd.read_csv("dataset/dataset_enso.csv", parse_dates=["acq_date"])

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
#  2   sst_std   276 non-null    float64
#  3   sst_anom  276 non-null    float64
#  4   oni_std   276 non-null    float64
#  5   oni_anom  276 non-null    float64
#  6   soi_std   276 non-null    float64
#  7   soi_anom  276 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
print(dataset.head())
# Out:
#     acq_date  hotspot  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom
# 0 2001-01-31        3    25.81     -0.76    25.88     -0.68      1.0       1.6
# 1 2001-02-28        5    26.18     -0.56    26.26     -0.52      1.7       2.8
# 2 2001-03-31       10    26.86     -0.37    26.76     -0.44      0.9       1.5
# 3 2001-04-30       20    27.24     -0.56    27.25     -0.34      0.2       0.3
# 4 2001-05-31       39    27.42     -0.46    27.49     -0.25     -0.5      -0.8

# %% [markdown]
# ### 2. Praproses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# jika hotspot dipengaruhi oleh enso
# data = dataset[["hotspot", "sst_std", "sst_anom", "oni_std", "oni_anom", "soi_std", "soi_anom"]]
# data = data.values

# # jika hotspot dipengaruhi oleh enso
data = dataset[["hotspot", "sst_anom", "oni_anom", "soi_anom"]]
data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3.  , -0.76, -0.68,  1.6 ],
#        [ 5.  , -0.56, -0.52,  2.8 ],
#        [10.  , -0.37, -0.44,  1.5 ],
#        [20.  , -0.56, -0.34,  0.3 ],
#        [39.  , -0.46, -0.25, -0.8 ]])

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 4)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],4)
# Out:
# array([[-1.    , -0.6148, -0.5514,  0.36  ],
#        [-0.9997, -0.522 , -0.4766,  0.6   ],
#        [-0.999 , -0.4339, -0.4393,  0.34  ],
#        [-0.9976, -0.522 , -0.3925,  0.1   ],
#        [-0.995 , -0.4756, -0.3505, -0.12  ]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 4)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled[:,:1]), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],4)
# Out:
# array([[-1.    , -0.6148, -0.5514,  0.36  ],
#        [-0.9997, -0.522 , -0.4766,  0.6   ],
#        [-0.999 , -0.4339, -0.4393,  0.34  ],
#        [-0.9976, -0.522 , -0.3925,  0.1   ],
#        [-0.995 , -0.4756, -0.3505, -0.12  ]])

# %%
train_data.shape
# Out:
# (216, 4)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],4)
# Out:
# array([[-0.999 ,  0.0487,  0.1168,  0.02  ],
#        [-0.9993,  0.0673,  0.1028, -0.42  ],
#        [-0.9979,  0.1879,  0.0981, -0.06  ],
#        [-0.9975,  0.0719,  0.0748,  0.08  ],
#        [-0.99  ,  0.0858,  0.0187, -0.1   ]])

# %%
test_data.shape
# Out:
# (60, 4)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data[:,:1], color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data[:,:1], color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    # return value
    return agg

# %% [markdown]
# - hasil supervised learning data train

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train_data, 1, 1)

# %%
reframed_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723 -0.522042 -0.476636
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030 -0.433875 -0.439252
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644 -0.522042 -0.392523
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012 -0.475638 -0.350467
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307 -0.336427 -0.289720
#
#    var4(t)
# 1     0.60
# 2     0.34
# 3     0.10
# 4    -0.12
# 5     0.14

# %%
# Jika menggunakan anom sst, oni, dan soi.
# # drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[5,6,7]], axis=1, inplace=True)

# Jika menggunakan semua parameter
# drop columns we don't want to predict
# reframed_train.drop(reframed_train.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_train.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (215, 4) (215,)

# %% [markdown]
# - hasil supervised learning data test

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test_data, 1, 1)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307  0.067285  0.102804
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922  0.187935  0.098131
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506  0.071926  0.074766
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024  0.085847  0.018692
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319  0.016241 -0.023364
#
#    var4(t)
# 1    -0.42
# 2    -0.06
# 3     0.08
# 4    -0.10
# 5    -0.10

# %%
# Jika menggunakan semua parameter
# drop columns we don't want to predict
# reframed_test.drop(reframed_test.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

reframed_test.drop(reframed_test.columns[[5,6,7]], axis=1, inplace=True)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (59, 4) (59,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  215 non-null    float64
#  1   var2(t-1)  215 non-null    float64
#  2   var3(t-1)  215 non-null    float64
#  3   var4(t-1)  215 non-null    float64
#  4   var1(t)    215 non-null    float64
# dtypes: float64(5)
# memory usage: 10.1 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -1.000000  -0.614849  -0.551402       0.36 -0.999723
# 2  -0.999723  -0.522042  -0.476636       0.60 -0.999030
# 3  -0.999030  -0.433875  -0.439252       0.34 -0.997644
# 4  -0.997644  -0.522042  -0.392523       0.10 -0.995012
# 5  -0.995012  -0.475638  -0.350467      -0.12 -0.999307

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  59 non-null     float64
#  1   var2(t-1)  59 non-null     float64
#  2   var3(t-1)  59 non-null     float64
#  3   var4(t-1)  59 non-null     float64
#  4   var1(t)    59 non-null     float64
# dtypes: float64(5)
# memory usage: 2.8 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1  -0.999030   0.048724   0.116822       0.02 -0.999307
# 2  -0.999307   0.067285   0.102804      -0.42 -0.997922
# 3  -0.997922   0.187935   0.098131      -0.06 -0.997506
# 4  -0.997506   0.071926   0.074766       0.08 -0.990024
# 5  -0.990024   0.085847   0.018692      -0.10 -0.994319

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (215, 1, 4) (215,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (59, 1, 4) (59,)

# %% [markdown]
# ### 5. Model Prediksi Titik Panas

# %%
# call function
from class_base_model import lstm_algorithm
from class_base_model import gru_algorithm

# check algorithm
if algorithm == "LSTM-RNN":
    # call model LSTM-RNN
    model = lstm_algorithm(trainX, activation, dropout_rate, optimizer)
else:
    # call model GRU-RNN
    model = gru_algorithm(trainX, activation, dropout_rate, optimizer)

# fit network
history = model.fit(
    trainX, trainY, batch_size=batch_size, epochs=epochs,
    validation_data=(testX, testY), verbose=1, shuffle=False, use_multiprocessing=True
)
# Out:
# Epoch 1/1500
# 108/108 [==============================] - 12s 14ms/step - loss: 0.5369 - mean_absolute_error: 0.5369 - mean_squared_error: 0.3851 - mean_absolute_percentage_error: 60.1193 - val_loss: 0.1110 - val_mean_absolute_error: 0.1110 - val_mean_squared_error: 0.0216 - val_mean_absolute_percentage_error: 12.5889
# Epoch 2/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1900 - mean_absolute_error: 0.1900 - mean_squared_error: 0.0775 - mean_absolute_percentage_error: 29.5896 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 11.1020
# Epoch 3/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - mean_squared_error: 0.0736 - mean_absolute_percentage_error: 29.1339 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 6.6720
# Epoch 4/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1725 - mean_absolute_error: 0.1725 - mean_squared_error: 0.0657 - mean_absolute_percentage_error: 27.7310 - val_loss: 0.0891 - val_mean_absolute_error: 0.0891 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 11.1617
# Epoch 5/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1761 - mean_absolute_error: 0.1761 - mean_squared_error: 0.0760 - mean_absolute_percentage_error: 28.0599 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 8.0017
# Epoch 6/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1637 - mean_absolute_error: 0.1637 - mean_squared_error: 0.0642 - mean_absolute_percentage_error: 26.3785 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 8.6344
# Epoch 7/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1574 - mean_absolute_error: 0.1574 - mean_squared_error: 0.0649 - mean_absolute_percentage_error: 25.3324 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.7837
# Epoch 8/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1545 - mean_absolute_error: 0.1545 - mean_squared_error: 0.0650 - mean_absolute_percentage_error: 27.3677 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 8.2815
# Epoch 9/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1615 - mean_absolute_error: 0.1615 - mean_squared_error: 0.0658 - mean_absolute_percentage_error: 26.5503 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 7.7358
# Epoch 10/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1450 - mean_absolute_error: 0.1450 - mean_squared_error: 0.0617 - mean_absolute_percentage_error: 25.7795 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 7.7947
# Epoch 11/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - mean_squared_error: 0.0608 - mean_absolute_percentage_error: 26.1868 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.8051
# Epoch 12/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1430 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0575 - mean_absolute_percentage_error: 25.6795 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019 - val_mean_squared_error: 0.0139 - val_mean_absolute_percentage_error: 12.3187
# Epoch 13/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - mean_squared_error: 0.0632 - mean_absolute_percentage_error: 25.4094 - val_loss: 0.0485 - val_mean_absolute_error: 0.0485 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 7.3049
# Epoch 14/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1537 - mean_absolute_error: 0.1537 - mean_squared_error: 0.0619 - mean_absolute_percentage_error: 26.3486 - val_loss: 0.0803 - val_mean_absolute_error: 0.0803 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.4013
# Epoch 15/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - mean_squared_error: 0.0628 - mean_absolute_percentage_error: 26.2740 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 10.4153
# Epoch 16/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 25.3312 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.4767
# Epoch 17/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1427 - mean_absolute_error: 0.1427 - mean_squared_error: 0.0590 - mean_absolute_percentage_error: 26.3139 - val_loss: 0.0789 - val_mean_absolute_error: 0.0789 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 10.2408
# Epoch 18/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1417 - mean_absolute_error: 0.1417 - mean_squared_error: 0.0629 - mean_absolute_percentage_error: 25.6548 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 10.2394
# Epoch 19/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0558 - mean_absolute_percentage_error: 24.9939 - val_loss: 0.0750 - val_mean_absolute_error: 0.0750 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.7845
# Epoch 20/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1455 - mean_absolute_error: 0.1455 - mean_squared_error: 0.0610 - mean_absolute_percentage_error: 27.2508 - val_loss: 0.0833 - val_mean_absolute_error: 0.0833 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.6687
# Epoch 21/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1410 - mean_absolute_error: 0.1410 - mean_squared_error: 0.0632 - mean_absolute_percentage_error: 25.8426 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.7336
# Epoch 22/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1359 - mean_absolute_error: 0.1359 - mean_squared_error: 0.0605 - mean_absolute_percentage_error: 26.0038 - val_loss: 0.0806 - val_mean_absolute_error: 0.0806 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.4313
# Epoch 23/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1283 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 24.0687 - val_loss: 0.0439 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 6.9737
# Epoch 24/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1330 - mean_absolute_error: 0.1330 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 24.3859 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.8280
# Epoch 25/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1268 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 24.5637 - val_loss: 0.0424 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 6.9560
# Epoch 26/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - mean_squared_error: 0.0599 - mean_absolute_percentage_error: 25.6536 - val_loss: 0.0671 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.1968
# Epoch 27/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1325 - mean_absolute_error: 0.1325 - mean_squared_error: 0.0590 - mean_absolute_percentage_error: 25.1936 - val_loss: 0.0376 - val_mean_absolute_error: 0.0376 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 6.4924
# Epoch 28/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1279 - mean_absolute_error: 0.1279 - mean_squared_error: 0.0573 - mean_absolute_percentage_error: 24.1296 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 6.8750
# Epoch 29/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1250 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0562 - mean_absolute_percentage_error: 24.5121 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.1800
# Epoch 30/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 24.1789 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 8.6755
# Epoch 31/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1317 - mean_absolute_error: 0.1317 - mean_squared_error: 0.0586 - mean_absolute_percentage_error: 25.9559 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.8468
# Epoch 32/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1324 - mean_absolute_error: 0.1324 - mean_squared_error: 0.0584 - mean_absolute_percentage_error: 25.5723 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 6.5020
# Epoch 33/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - mean_squared_error: 0.0537 - mean_absolute_percentage_error: 23.5045 - val_loss: 0.0376 - val_mean_absolute_error: 0.0376 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 6.5564
# Epoch 34/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1121 - mean_absolute_error: 0.1121 - mean_squared_error: 0.0545 - mean_absolute_percentage_error: 23.9304 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 6.9211
# Epoch 35/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1101 - mean_absolute_error: 0.1101 - mean_squared_error: 0.0511 - mean_absolute_percentage_error: 22.4706 - val_loss: 0.0364 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 6.4570
# Epoch 36/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 24.3651 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 8.0601
# Epoch 37/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1112 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0572 - mean_absolute_percentage_error: 23.5622 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.3522
# Epoch 38/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1106 - mean_absolute_error: 0.1106 - mean_squared_error: 0.0538 - mean_absolute_percentage_error: 23.1847 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 8.5410
# Epoch 39/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1074 - mean_absolute_error: 0.1074 - mean_squared_error: 0.0560 - mean_absolute_percentage_error: 23.1754 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.1248
# Epoch 40/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1054 - mean_absolute_error: 0.1054 - mean_squared_error: 0.0537 - mean_absolute_percentage_error: 22.6655 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0121 - val_mean_absolute_percentage_error: 7.4619
# Epoch 41/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1066 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0553 - mean_absolute_percentage_error: 23.0552 - val_loss: 0.0395 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 6.7208
# Epoch 42/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1125 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0556 - mean_absolute_percentage_error: 23.7605 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 8.8471
# Epoch 43/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1099 - mean_absolute_error: 0.1099 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 24.1050 - val_loss: 0.0453 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0131 - val_mean_absolute_percentage_error: 7.5665
# Epoch 44/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1059 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0562 - mean_absolute_percentage_error: 23.2243 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 6.7635
# Epoch 45/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1022 - mean_absolute_error: 0.1022 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 22.7167 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 6.8052
# Epoch 46/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0992 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0543 - mean_absolute_percentage_error: 22.2543 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 7.2517
# Epoch 47/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1014 - mean_absolute_error: 0.1014 - mean_squared_error: 0.0561 - mean_absolute_percentage_error: 23.2824 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.8874
# Epoch 48/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1012 - mean_absolute_error: 0.1012 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 23.0107 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 7.2679
# Epoch 49/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1054 - mean_absolute_error: 0.1054 - mean_squared_error: 0.0554 - mean_absolute_percentage_error: 22.6970 - val_loss: 0.0421 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 7.0003
# Epoch 50/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0969 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0553 - mean_absolute_percentage_error: 22.7420 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0122 - val_mean_absolute_percentage_error: 6.9634
# Epoch 51/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 22.8229 - val_loss: 0.0421 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 6.9894
# Epoch 52/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - mean_squared_error: 0.0555 - mean_absolute_percentage_error: 22.1905 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 7.2755
# Epoch 53/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.1008 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0555 - mean_absolute_percentage_error: 22.8583 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 8.0564
# Epoch 54/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0957 - mean_absolute_error: 0.0957 - mean_squared_error: 0.0564 - mean_absolute_percentage_error: 22.6227 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0122 - val_mean_absolute_percentage_error: 6.9799
# Epoch 55/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 22.1139 - val_loss: 0.0433 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 7.0847
# Epoch 56/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0957 - mean_absolute_error: 0.0957 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 22.3986 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 7.1469
# Epoch 57/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0975 - mean_absolute_error: 0.0975 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 22.6766 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 6.9409
# Epoch 58/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 22.4663 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 8.0161
# Epoch 59/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0928 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0561 - mean_absolute_percentage_error: 22.1565 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 6.8040
# Epoch 60/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0556 - mean_absolute_percentage_error: 22.2950 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 6.6495
# Epoch 61/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0576 - mean_absolute_percentage_error: 22.5789 - val_loss: 0.0434 - val_mean_absolute_error: 0.0434 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 7.2000
# Epoch 62/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0900 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0560 - mean_absolute_percentage_error: 22.0836 - val_loss: 0.0381 - val_mean_absolute_error: 0.0381 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 6.6980
# Epoch 63/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0556 - mean_absolute_percentage_error: 21.9392 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 6.9133
# Epoch 64/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 21.9016 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463 - val_mean_squared_error: 0.0126 - val_mean_absolute_percentage_error: 7.6162
# Epoch 65/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0570 - mean_absolute_percentage_error: 22.4754 - val_loss: 0.0436 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 7.3270
# Epoch 66/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 21.8809 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 7.0917
# Epoch 67/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0876 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0561 - mean_absolute_percentage_error: 21.8075 - val_loss: 0.0403 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 6.9496
# Epoch 68/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0572 - mean_absolute_percentage_error: 22.0589 - val_loss: 0.0422 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 7.0918
# Epoch 69/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 21.8554 - val_loss: 0.0382 - val_mean_absolute_error: 0.0382 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 6.6774
# Epoch 70/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0904 - mean_absolute_error: 0.0904 - mean_squared_error: 0.0572 - mean_absolute_percentage_error: 22.2273 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 6.7509
# Epoch 71/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0567 - mean_absolute_percentage_error: 21.8694 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 6.8347
# Epoch 72/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0571 - mean_absolute_percentage_error: 21.8493 - val_loss: 0.0367 - val_mean_absolute_error: 0.0367 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 6.5870
# Epoch 73/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0578 - mean_absolute_percentage_error: 22.0989 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 7.0134
# Epoch 74/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 22.0248 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 7.0495
# Epoch 75/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 22.0750 - val_loss: 0.0373 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 6.6524
# Epoch 76/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0580 - mean_absolute_percentage_error: 22.1579 - val_loss: 0.0388 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 6.7833
# Epoch 77/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0584 - mean_absolute_percentage_error: 22.2286 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 7.2022
# Epoch 78/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0839 - mean_absolute_error: 0.0839 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 21.8906 - val_loss: 0.0384 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0122 - val_mean_absolute_percentage_error: 6.8089
# Epoch 79/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 22.1035 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0121 - val_mean_absolute_percentage_error: 7.2526
# Epoch 80/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0588 - mean_absolute_percentage_error: 22.1896 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 6.9036
# Epoch 81/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0588 - mean_absolute_percentage_error: 22.1779 - val_loss: 0.0369 - val_mean_absolute_error: 0.0369 - val_mean_squared_error: 0.0125 - val_mean_absolute_percentage_error: 6.6933
# Epoch 82/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0592 - mean_absolute_percentage_error: 22.3839 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 6.9149
# Epoch 83/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0851 - mean_absolute_error: 0.0851 - mean_squared_error: 0.0589 - mean_absolute_percentage_error: 22.1408 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0127 - val_mean_absolute_percentage_error: 6.9655
# Epoch 84/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0596 - mean_absolute_percentage_error: 22.3553 - val_loss: 0.0426 - val_mean_absolute_error: 0.0426 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 7.1945
# Epoch 85/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0595 - mean_absolute_percentage_error: 22.4269 - val_loss: 0.0368 - val_mean_absolute_error: 0.0368 - val_mean_squared_error: 0.0125 - val_mean_absolute_percentage_error: 6.6964
# Epoch 86/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 22.3376 - val_loss: 0.0450 - val_mean_absolute_error: 0.0450 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 7.5509
# Epoch 87/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0848 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0596 - mean_absolute_percentage_error: 22.2313 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0122 - val_mean_absolute_percentage_error: 7.0445
# Epoch 88/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0603 - mean_absolute_percentage_error: 22.4687 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0126 - val_mean_absolute_percentage_error: 7.0030
# Epoch 89/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0606 - mean_absolute_percentage_error: 22.5409 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 7.3388
# Epoch 90/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0606 - mean_absolute_percentage_error: 22.5311 - val_loss: 0.0399 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0128 - val_mean_absolute_percentage_error: 7.0374
# Epoch 91/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0606 - mean_absolute_percentage_error: 22.4527 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0129 - val_mean_absolute_percentage_error: 6.8106
# Epoch 92/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0609 - mean_absolute_percentage_error: 22.5942 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 6.8850
# Epoch 93/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0611 - mean_absolute_percentage_error: 22.5412 - val_loss: 0.0397 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 7.0610
# Epoch 94/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0611 - mean_absolute_percentage_error: 22.4937 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 6.9831
# Epoch 95/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0619 - mean_absolute_percentage_error: 22.7542 - val_loss: 0.0377 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0131 - val_mean_absolute_percentage_error: 6.8549
# Epoch 96/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0843 - mean_absolute_error: 0.0843 - mean_squared_error: 0.0615 - mean_absolute_percentage_error: 22.5118 - val_loss: 0.0405 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0131 - val_mean_absolute_percentage_error: 7.1360
# Epoch 97/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0617 - mean_absolute_percentage_error: 22.6992 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 7.3671
# Epoch 98/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0618 - mean_absolute_percentage_error: 22.6553 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0138 - val_mean_absolute_percentage_error: 7.6632
# Epoch 99/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0619 - mean_absolute_percentage_error: 22.7475 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 7.0556
# Epoch 100/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0848 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0618 - mean_absolute_percentage_error: 22.5955 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0134 - val_mean_absolute_percentage_error: 6.9877
# Epoch 101/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.7239 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442 - val_mean_squared_error: 0.0139 - val_mean_absolute_percentage_error: 7.5889
# Epoch 102/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.7383 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0134 - val_mean_absolute_percentage_error: 7.4280
# Epoch 103/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.7648 - val_loss: 0.0382 - val_mean_absolute_error: 0.0382 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 6.9305
# Epoch 104/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0622 - mean_absolute_percentage_error: 22.7483 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415 - val_mean_squared_error: 0.0135 - val_mean_absolute_percentage_error: 7.2792
# Epoch 105/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0849 - mean_absolute_error: 0.0849 - mean_squared_error: 0.0618 - mean_absolute_percentage_error: 22.6266 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0135 - val_mean_absolute_percentage_error: 6.9973
# Epoch 106/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.7483 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 7.4862
# Epoch 107/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0624 - mean_absolute_percentage_error: 22.9567 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 6.9069
# Epoch 108/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0622 - mean_absolute_percentage_error: 22.7864 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0134 - val_mean_absolute_percentage_error: 7.2436
# Epoch 109/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0622 - mean_absolute_percentage_error: 22.7305 - val_loss: 0.0388 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0136 - val_mean_absolute_percentage_error: 7.0260
# Epoch 110/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0623 - mean_absolute_percentage_error: 22.7029 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0139 - val_mean_absolute_percentage_error: 7.6682
# Epoch 111/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0623 - mean_absolute_percentage_error: 22.8328 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0134 - val_mean_absolute_percentage_error: 7.1270
# Epoch 112/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0858 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0625 - mean_absolute_percentage_error: 22.7969 - val_loss: 0.0384 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 6.9358
# Epoch 113/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0853 - mean_absolute_error: 0.0853 - mean_squared_error: 0.0622 - mean_absolute_percentage_error: 22.7051 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0136 - val_mean_absolute_percentage_error: 6.9966
# Epoch 114/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0840 - mean_absolute_error: 0.0840 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.5637 - val_loss: 0.0441 - val_mean_absolute_error: 0.0441 - val_mean_squared_error: 0.0137 - val_mean_absolute_percentage_error: 7.5561
# Epoch 115/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0852 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 22.6771 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 7.0082
# Epoch 116/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0619 - mean_absolute_percentage_error: 22.6843 - val_loss: 0.0399 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0133 - val_mean_absolute_percentage_error: 7.0953
# Epoch 117/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0608 - mean_absolute_percentage_error: 22.4025 - val_loss: 0.0409 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0123 - val_mean_absolute_percentage_error: 7.0741
# Epoch 118/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0605 - mean_absolute_percentage_error: 22.5478 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 6.8681
# Epoch 119/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0584 - mean_absolute_percentage_error: 22.1138 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 6.7477
# Epoch 120/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0811 - mean_absolute_error: 0.0811 - mean_squared_error: 0.0558 - mean_absolute_percentage_error: 21.6659 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 6.9609
# Epoch 121/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0815 - mean_absolute_error: 0.0815 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 21.4244 - val_loss: 0.0384 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 6.7157
# Epoch 122/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0570 - mean_absolute_percentage_error: 21.4411 - val_loss: 0.0439 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 7.2283
# Epoch 123/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0817 - mean_absolute_error: 0.0817 - mean_squared_error: 0.0528 - mean_absolute_percentage_error: 21.1513 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 6.3960
# Epoch 124/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0800 - mean_absolute_error: 0.0800 - mean_squared_error: 0.0494 - mean_absolute_percentage_error: 20.6908 - val_loss: 0.0376 - val_mean_absolute_error: 0.0376 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 6.3710
# Epoch 125/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0791 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0457 - mean_absolute_percentage_error: 19.9577 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.4274
# Epoch 126/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0790 - mean_absolute_error: 0.0790 - mean_squared_error: 0.0468 - mean_absolute_percentage_error: 19.8425 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 6.3245
# Epoch 127/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0782 - mean_absolute_error: 0.0782 - mean_squared_error: 0.0482 - mean_absolute_percentage_error: 19.7670 - val_loss: 0.0359 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 6.0477
# Epoch 128/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0732 - mean_absolute_error: 0.0732 - mean_squared_error: 0.0440 - mean_absolute_percentage_error: 18.4219 - val_loss: 0.0361 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0088 - val_mean_absolute_percentage_error: 5.9245
# Epoch 129/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0773 - mean_absolute_error: 0.0773 - mean_squared_error: 0.0440 - mean_absolute_percentage_error: 18.5919 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0090 - val_mean_absolute_percentage_error: 5.5986
# Epoch 130/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0781 - mean_absolute_error: 0.0781 - mean_squared_error: 0.0459 - mean_absolute_percentage_error: 19.3871 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0088 - val_mean_absolute_percentage_error: 5.5255
# Epoch 131/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0789 - mean_absolute_error: 0.0789 - mean_squared_error: 0.0501 - mean_absolute_percentage_error: 20.1530 - val_loss: 0.0332 - val_mean_absolute_error: 0.0332 - val_mean_squared_error: 0.0086 - val_mean_absolute_percentage_error: 5.6284
# Epoch 132/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0769 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0472 - mean_absolute_percentage_error: 20.9311 - val_loss: 0.0344 - val_mean_absolute_error: 0.0344 - val_mean_squared_error: 0.0085 - val_mean_absolute_percentage_error: 5.6778
# Epoch 133/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0765 - mean_absolute_error: 0.0765 - mean_squared_error: 0.0409 - mean_absolute_percentage_error: 18.5604 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0085 - val_mean_absolute_percentage_error: 5.6132
# Epoch 134/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0756 - mean_absolute_error: 0.0756 - mean_squared_error: 0.0437 - mean_absolute_percentage_error: 19.8343 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0087 - val_mean_absolute_percentage_error: 5.5321
# Epoch 135/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0725 - mean_absolute_error: 0.0725 - mean_squared_error: 0.0397 - mean_absolute_percentage_error: 19.4340 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0080 - val_mean_absolute_percentage_error: 5.3602
# Epoch 136/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0756 - mean_absolute_error: 0.0756 - mean_squared_error: 0.0439 - mean_absolute_percentage_error: 17.6134 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0083 - val_mean_absolute_percentage_error: 5.3804
# Epoch 137/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0769 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0450 - mean_absolute_percentage_error: 18.5500 - val_loss: 0.0315 - val_mean_absolute_error: 0.0315 - val_mean_squared_error: 0.0079 - val_mean_absolute_percentage_error: 5.2507
# Epoch 138/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0757 - mean_absolute_error: 0.0757 - mean_squared_error: 0.0394 - mean_absolute_percentage_error: 17.6412 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0082 - val_mean_absolute_percentage_error: 5.3196
# Epoch 139/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0741 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0408 - mean_absolute_percentage_error: 18.1168 - val_loss: 0.0313 - val_mean_absolute_error: 0.0313 - val_mean_squared_error: 0.0082 - val_mean_absolute_percentage_error: 5.3055
# Epoch 140/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0810 - mean_absolute_error: 0.0810 - mean_squared_error: 0.0603 - mean_absolute_percentage_error: 21.4752 - val_loss: 0.0312 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0087 - val_mean_absolute_percentage_error: 5.4515
# Epoch 141/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0754 - mean_absolute_error: 0.0754 - mean_squared_error: 0.0455 - mean_absolute_percentage_error: 17.8060 - val_loss: 0.0315 - val_mean_absolute_error: 0.0315 - val_mean_squared_error: 0.0078 - val_mean_absolute_percentage_error: 5.2415
# Epoch 142/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0728 - mean_absolute_error: 0.0728 - mean_squared_error: 0.0392 - mean_absolute_percentage_error: 17.1870 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0076 - val_mean_absolute_percentage_error: 5.2763
# Epoch 143/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0775 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0448 - mean_absolute_percentage_error: 20.6478 - val_loss: 0.0311 - val_mean_absolute_error: 0.0311 - val_mean_squared_error: 0.0077 - val_mean_absolute_percentage_error: 5.1481
# Epoch 144/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0762 - mean_absolute_error: 0.0762 - mean_squared_error: 0.0442 - mean_absolute_percentage_error: 20.3327 - val_loss: 0.0309 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0076 - val_mean_absolute_percentage_error: 5.1221
# Epoch 145/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0754 - mean_absolute_error: 0.0754 - mean_squared_error: 0.0450 - mean_absolute_percentage_error: 17.1441 - val_loss: 0.0305 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0080 - val_mean_absolute_percentage_error: 5.1851
# Epoch 146/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0711 - mean_absolute_error: 0.0711 - mean_squared_error: 0.0389 - mean_absolute_percentage_error: 16.4626 - val_loss: 0.0312 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0078 - val_mean_absolute_percentage_error: 5.1530
# Epoch 147/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0768 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0473 - mean_absolute_percentage_error: 17.8461 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0076 - val_mean_absolute_percentage_error: 5.0541
# Epoch 148/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0738 - mean_absolute_error: 0.0738 - mean_squared_error: 0.0431 - mean_absolute_percentage_error: 16.5903 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0074 - val_mean_absolute_percentage_error: 4.9622
# Epoch 149/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0773 - mean_absolute_error: 0.0773 - mean_squared_error: 0.0448 - mean_absolute_percentage_error: 17.0735 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0074 - val_mean_absolute_percentage_error: 5.0604
# Epoch 150/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0418 - mean_absolute_percentage_error: 17.0189 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0073 - val_mean_absolute_percentage_error: 4.9009
# Epoch 151/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0768 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0437 - mean_absolute_percentage_error: 18.2618 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0077 - val_mean_absolute_percentage_error: 5.0612
# Epoch 152/1500
# ...
# Epoch 1451/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0339 - mean_absolute_error: 0.0339 - mean_squared_error: 0.0054 - mean_absolute_percentage_error: 8.2112 - val_loss: 0.0325 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 5.5415
# Epoch 1452/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 10.6045 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 5.9413
# Epoch 1453/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0318 - mean_absolute_error: 0.0318 - mean_squared_error: 0.0052 - mean_absolute_percentage_error: 5.8921 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0126 - val_mean_absolute_percentage_error: 5.8340
# Epoch 1454/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0273 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0029 - mean_absolute_percentage_error: 5.3605 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - val_mean_squared_error: 0.0161 - val_mean_absolute_percentage_error: 7.6355
# Epoch 1455/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0328 - mean_absolute_error: 0.0328 - mean_squared_error: 0.0056 - mean_absolute_percentage_error: 6.3192 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0083 - val_mean_absolute_percentage_error: 5.6384
# Epoch 1456/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0269 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0037 - mean_absolute_percentage_error: 4.6602 - val_loss: 0.0436 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0148 - val_mean_absolute_percentage_error: 7.3091
# Epoch 1457/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0325 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0071 - mean_absolute_percentage_error: 6.9523 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0126 - val_mean_absolute_percentage_error: 6.4109
# Epoch 1458/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0287 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0035 - mean_absolute_percentage_error: 4.7822 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.0757
# Epoch 1459/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0275 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0034 - mean_absolute_percentage_error: 5.7698 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - val_mean_squared_error: 0.0190 - val_mean_absolute_percentage_error: 8.0498
# Epoch 1460/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0060 - mean_absolute_percentage_error: 5.1311 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0229 - val_mean_absolute_percentage_error: 8.7251
# Epoch 1461/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0280 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0040 - mean_absolute_percentage_error: 4.9293 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.0702
# Epoch 1462/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0283 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0045 - mean_absolute_percentage_error: 5.9360 - val_loss: 0.0388 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0127 - val_mean_absolute_percentage_error: 6.1944
# Epoch 1463/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0330 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0051 - mean_absolute_percentage_error: 7.8993 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0210 - val_mean_absolute_percentage_error: 7.5939
# Epoch 1464/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0337 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0051 - mean_absolute_percentage_error: 6.1272 - val_loss: 0.0353 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 5.8626
# Epoch 1465/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0045 - mean_absolute_percentage_error: 7.7214 - val_loss: 0.0440 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0160 - val_mean_absolute_percentage_error: 7.3287
# Epoch 1466/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0355 - mean_absolute_error: 0.0355 - mean_squared_error: 0.0071 - mean_absolute_percentage_error: 6.5038 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0138 - val_mean_absolute_percentage_error: 6.6308
# Epoch 1467/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0322 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0087 - mean_absolute_percentage_error: 7.1993 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - val_mean_squared_error: 0.0208 - val_mean_absolute_percentage_error: 7.9121
# Epoch 1468/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 8.5320 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0121 - val_mean_absolute_percentage_error: 6.0869
# Epoch 1469/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0372 - mean_absolute_error: 0.0372 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 9.5373 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_mean_squared_error: 0.0251 - val_mean_absolute_percentage_error: 9.0051
# Epoch 1470/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0392 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0131 - mean_absolute_percentage_error: 13.4235 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0248 - val_mean_absolute_percentage_error: 8.5666
# Epoch 1471/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0282 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0034 - mean_absolute_percentage_error: 5.3657 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0188 - val_mean_absolute_percentage_error: 7.0668
# Epoch 1472/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0309 - mean_absolute_error: 0.0309 - mean_squared_error: 0.0054 - mean_absolute_percentage_error: 6.2348 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0147 - val_mean_absolute_percentage_error: 6.8580
# Epoch 1473/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0344 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0061 - mean_absolute_percentage_error: 6.2547 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0145 - val_mean_absolute_percentage_error: 6.8057
# Epoch 1474/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0279 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0033 - mean_absolute_percentage_error: 4.4887 - val_loss: 0.0429 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0143 - val_mean_absolute_percentage_error: 7.1433
# Epoch 1475/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0398 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0169 - mean_absolute_percentage_error: 7.1211 - val_loss: 0.0449 - val_mean_absolute_error: 0.0449 - val_mean_squared_error: 0.0170 - val_mean_absolute_percentage_error: 7.4614
# Epoch 1476/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0346 - mean_absolute_error: 0.0346 - mean_squared_error: 0.0072 - mean_absolute_percentage_error: 6.1762 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0135 - val_mean_absolute_percentage_error: 7.0533
# Epoch 1477/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0262 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0031 - mean_absolute_percentage_error: 4.5359 - val_loss: 0.0462 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0206 - val_mean_absolute_percentage_error: 7.8376
# Epoch 1478/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0333 - mean_absolute_error: 0.0333 - mean_squared_error: 0.0055 - mean_absolute_percentage_error: 7.6771 - val_loss: 0.0326 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0080 - val_mean_absolute_percentage_error: 5.3421
# Epoch 1479/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0334 - mean_absolute_error: 0.0334 - mean_squared_error: 0.0098 - mean_absolute_percentage_error: 5.9330 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 6.0635
# Epoch 1480/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0256 - mean_absolute_error: 0.0256 - mean_squared_error: 0.0046 - mean_absolute_percentage_error: 4.1319 - val_loss: 0.0362 - val_mean_absolute_error: 0.0362 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.9059
# Epoch 1481/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0363 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 7.7315 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0083 - val_mean_absolute_percentage_error: 5.3743
# Epoch 1482/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0330 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0057 - mean_absolute_percentage_error: 7.5571 - val_loss: 0.0472 - val_mean_absolute_error: 0.0472 - val_mean_squared_error: 0.0219 - val_mean_absolute_percentage_error: 7.9169
# Epoch 1483/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0296 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0048 - mean_absolute_percentage_error: 5.4621 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0341 - val_mean_absolute_percentage_error: 9.8498
# Epoch 1484/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0033 - mean_absolute_percentage_error: 3.7202 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_mean_squared_error: 0.0374 - val_mean_absolute_percentage_error: 9.4790
# Epoch 1485/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0337 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0067 - mean_absolute_percentage_error: 7.0163 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - val_mean_squared_error: 0.0313 - val_mean_absolute_percentage_error: 9.1733
# Epoch 1486/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0322 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 6.8412 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0147 - val_mean_absolute_percentage_error: 7.0060
# Epoch 1487/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0314 - mean_absolute_error: 0.0314 - mean_squared_error: 0.0056 - mean_absolute_percentage_error: 6.5228 - val_loss: 0.0405 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0176 - val_mean_absolute_percentage_error: 6.6079
# Epoch 1488/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0341 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0101 - mean_absolute_percentage_error: 9.8276 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0308 - val_mean_absolute_percentage_error: 9.1314
# Epoch 1489/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0376 - mean_absolute_error: 0.0376 - mean_squared_error: 0.0160 - mean_absolute_percentage_error: 6.4456 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0235 - val_mean_absolute_percentage_error: 7.9406
# Epoch 1490/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0281 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0035 - mean_absolute_percentage_error: 5.3326 - val_loss: 0.0448 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0182 - val_mean_absolute_percentage_error: 7.6693
# Epoch 1491/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0065 - mean_absolute_percentage_error: 7.7294 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.5436
# Epoch 1492/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0394 - mean_absolute_error: 0.0394 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 7.6675 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0187 - val_mean_absolute_percentage_error: 7.4242
# Epoch 1493/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0301 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0059 - mean_absolute_percentage_error: 6.6868 - val_loss: 0.0476 - val_mean_absolute_error: 0.0476 - val_mean_squared_error: 0.0256 - val_mean_absolute_percentage_error: 7.9524
# Epoch 1494/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0291 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0041 - mean_absolute_percentage_error: 5.2145 - val_loss: 0.0418 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0175 - val_mean_absolute_percentage_error: 7.1402
# Epoch 1495/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0302 - mean_absolute_error: 0.0302 - mean_squared_error: 0.0062 - mean_absolute_percentage_error: 4.7719 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0086 - val_mean_absolute_percentage_error: 5.4789
# Epoch 1496/1500
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0363 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0080 - mean_absolute_percentage_error: 7.6657 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 6.0377
# Epoch 1497/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0354 - mean_absolute_error: 0.0354 - mean_squared_error: 0.0100 - mean_absolute_percentage_error: 9.1465 - val_loss: 0.0447 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0215 - val_mean_absolute_percentage_error: 7.5206
# Epoch 1498/1500
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0063 - mean_absolute_percentage_error: 7.1014 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0211 - val_mean_absolute_percentage_error: 7.9731
# Epoch 1499/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0249 - mean_absolute_error: 0.0249 - mean_squared_error: 0.0025 - mean_absolute_percentage_error: 5.0843 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0297 - val_mean_absolute_percentage_error: 8.1750
# Epoch 1500/1500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0327 - mean_absolute_error: 0.0327 - mean_squared_error: 0.0095 - mean_absolute_percentage_error: 7.8509 - val_loss: 0.0450 - val_mean_absolute_error: 0.0450 - val_mean_squared_error: 0.0175 - val_mean_absolute_percentage_error: 7.4951

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 20)             960
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 1, 20)             1920
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 20)                1920
#  onal)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 4821 (18.83 KB)
# Trainable params: 4821 (18.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=1.5)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=1.5)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.99445754 -0.9980019  -0.99768245 -0.9948324  -0.9951963  -0.9931312
#  -0.9901137  -0.8136236  -0.15866691 -0.3511619  -0.8894384  -0.9582002
#  -0.9933703  -0.9817564  -0.99155533 -0.9908123  -0.9924863  -0.9900976
#  -0.9857729  -0.99105066 -0.99381727 -0.98879224 -0.9903528  -0.98701966
#  -0.9887254  -0.9933584  -0.9861874  -0.98700035 -0.98721385 -0.9857359
#  -0.9864917  -0.9874756  -0.986877   -0.9935026  -0.99750143 -0.9971135
#  -0.9866033  -0.9985056  -0.98966545 -0.9897925  -0.99734324 -0.98772436
#  -0.9929405  -0.9986351  -0.9907629  -0.98889023 -0.9886313  -0.99159366
#  -0.99411416 -0.99382794 -0.9879097  -0.9907052  -0.9923891  -0.9953422
#  -0.99645823 -0.99725384  0.15220922 -0.97142595 -0.9987068 ]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - mean_squared_error: 0.0017 - mean_absolute_percentage_error: 3.3358
# [0.019628699868917465,
#  0.019628699868917465,
#  0.0016516917385160923,
#  3.3357584476470947]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0175 - mean_absolute_percentage_error: 7.4951
# [0.04501509293913841,
#  0.04501509293913841,
#  0.017529090866446495,
#  7.49505615234375]

# %% [markdown]
# - MAE

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE: %.4f' % mae)
# Out:
# Test MAE: 0.0450

# %% [markdown]
# - MSE

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0175

# %% [markdown]
# - MAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions) * 100
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 7.4951

# %% [markdown]
# - korelasi dan signifikansi

# %%
hasil = np.stack((testY,predictions.reshape(-1)),axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999307 -0.994458
# 1    -0.997922 -0.998002
# 2    -0.997506 -0.997682
# 3    -0.990024 -0.994832
# 4    -0.994319 -0.995196

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.7587 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:13:05.46

# %% [markdown]
# ### 8. Visualisasi Hasil Prediksi

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], testY, color="tab:blue", label="data aktual", linewidth=2)
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], predictions, color="tab:red", label="hasil prediksi", linewidth=2)

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper right")
ax.grid(True)
plt.show()

# %% [markdown]
# ### 8. Hasil Prediksi Titik Panas

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(dataset[["hotspot"]]))

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(np.array(testY).reshape(-1, 1))

# %%
x = pd.DataFrame(np.array(dataset.iloc[train_size+1:len(dataset),0]), columns=['Date'])
y = pd.DataFrame(testActual, columns=['Data Aktual'])
z = pd.DataFrame(testPredictions, columns=['Data Prediksi'])

# %%
hasil_prediksi = pd.concat([x, y, z], axis=1)

# %%
hasil_prediksi = np.round(hasil_prediksi, 0)

# %%
# if algorithm == "LSTM-RNN":
#     hasil_prediksi.to_csv("hasil_prediksi_m1.csv", index=False)
# else:
#     hasil_prediksi.to_csv("hasil_prediksi_m4.csv", index=False)

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
fix, ax = plt.subplots(figsize=(10,5))

ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Aktual"], color="tab:blue", label="Data aktual", linewidth=2.5)
ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Prediksi"], color="tab:red", label="Hasil prediksi", linewidth=2.5)

# Mengatur format tanggal ke format tahun
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper right")
ax.grid(True)
plt.show()
