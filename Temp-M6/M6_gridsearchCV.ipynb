# %% [markdown]
# ## M6 - SB-GRU-RNN with Hyperparameter GridSearch

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# #!pip install scikit-learn==1.2.2
# #!pip install tensoflow==2.14.0
# #!pip install keras==2.14.0
# !pip install scikeras==0.12.0
# !pip install joblib==1.4.2
# !pip install statsmodels

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

import random as rm
import time as tm

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# # Setting seed
# rm.seed(1234)
# np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# # Setting Algorithm
# algorithm = "LSTM-RNN"

# %%
# Setting Algorithm
algorithm = "GRU-RNN"

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
#dataset = pd.read_csv("/content/drive/MyDrive/BOPTN_2024/dataset_enso.csv", parse_dates=["acq_date"])
dataset = pd.read_csv("dataset_enso.csv", parse_dates=["acq_date"])

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
#  2   sst_std   276 non-null    float64
#  3   sst_anom  276 non-null    float64
#  4   oni_std   276 non-null    float64
#  5   oni_anom  276 non-null    float64
#  6   soi_std   276 non-null    float64
#  7   soi_anom  276 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
print(dataset.head())
# Out:
#     acq_date  hotspot  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom
# 0 2001-01-31        3    25.81     -0.76    25.88     -0.68      1.0       1.6
# 1 2001-02-28        5    26.18     -0.56    26.26     -0.52      1.7       2.8
# 2 2001-03-31       10    26.86     -0.37    26.76     -0.44      0.9       1.5
# 3 2001-04-30       20    27.24     -0.56    27.25     -0.34      0.2       0.3
# 4 2001-05-31       39    27.42     -0.46    27.49     -0.25     -0.5      -0.8

# %% [markdown]
# ### 2. Praproses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# jika hotspot dipengaruhi oleh enso
data = dataset[["hotspot", "sst_std", "sst_anom", "oni_std", "oni_anom", "soi_std", "soi_anom"]]
data = data.values

# # jika hotspot dipengaruhi oleh enso
# data = dataset[["hotspot", "sst_anom", "oni_anom", "soi_anom"]]
# data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3.  , 25.81, -0.76, 25.88, -0.68,  1.  ,  1.6 ],
#        [ 5.  , 26.18, -0.56, 26.26, -0.52,  1.7 ,  2.8 ],
#        [10.  , 26.86, -0.37, 26.76, -0.44,  0.9 ,  1.5 ],
#        [20.  , 27.24, -0.56, 27.25, -0.34,  0.2 ,  0.3 ],
#        [39.  , 27.42, -0.46, 27.49, -0.25, -0.5 , -0.8 ]])

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 7)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 7)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled[:,:1]), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
train_data.shape
# Out:
# (216, 7)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],4)
# Out:
# array([[-0.999 , -0.0066,  0.0487,  0.1221,  0.1168,  0.0333,  0.02  ],
#        [-0.9993,  0.081 ,  0.0673,  0.216 ,  0.1028, -0.4333, -0.42  ],
#        [-0.9979,  0.4179,  0.1879,  0.4131,  0.0981, -0.0667, -0.06  ],
#        [-0.9975,  0.558 ,  0.0719,  0.5681,  0.0748,  0.0667,  0.08  ],
#        [-0.99  ,  0.6018,  0.0858,  0.5822,  0.0187, -0.1   , -0.1   ]])

# %%
test_data.shape
# Out:
# (60, 7)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data[:,:1], color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data[:,:1], color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    # return value
    return agg

# %% [markdown]
# - hasil supervised learning data train

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train_data, 1, 1)

# %%
reframed_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 1       0.36 -0.999723 -0.470460 -0.522042 -0.408451 -0.476636  0.600000
# 2       0.60 -0.999030 -0.172867 -0.433875 -0.173709 -0.439252  0.333333
# 3       0.34 -0.997644 -0.006565 -0.522042  0.056338 -0.392523  0.100000
# 4       0.10 -0.995012  0.072210 -0.475638  0.169014 -0.350467 -0.133333
# 5      -0.12 -0.999307  0.129103 -0.336427  0.159624 -0.289720  0.133333
#
#    var7(t)
# 1     0.60
# 2     0.34
# 3     0.10
# 4    -0.12
# 5     0.14

# %%
# Jika menggunakan anom sst, oni, dan soi.
# # drop columns we don't want to predict
# reframed_train.drop(reframed_train.columns[[5,6,7]], axis=1, inplace=True)

# Jika menggunakan semua parameter
# drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_train.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (215, 7) (215,)

# %% [markdown]
# - hasil supervised learning data test

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test_data, 1, 1)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 1       0.02 -0.999307  0.080963  0.067285  0.215962  0.102804 -0.433333
# 2      -0.42 -0.997922  0.417943  0.187935  0.413146  0.098131 -0.066667
# 3      -0.06 -0.997506  0.557987  0.071926  0.568075  0.074766  0.066667
# 4       0.08 -0.990024  0.601751  0.085847  0.582160  0.018692 -0.100000
# 5      -0.10 -0.994319  0.461707  0.016241  0.455399 -0.023364 -0.133333
#
#    var7(t)
# 1    -0.42
# 2    -0.06
# 3     0.08
# 4    -0.10
# 5    -0.10

# %%
# Jika menggunakan semua parameter
# drop columns we don't want to predict
reframed_test.drop(reframed_test.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (59, 7) (59,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  215 non-null    float64
#  1   var2(t-1)  215 non-null    float64
#  2   var3(t-1)  215 non-null    float64
#  3   var4(t-1)  215 non-null    float64
#  4   var5(t-1)  215 non-null    float64
#  5   var6(t-1)  215 non-null    float64
#  6   var7(t-1)  215 non-null    float64
#  7   var1(t)    215 non-null    float64
# dtypes: float64(8)
# memory usage: 15.1 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  59 non-null     float64
#  1   var2(t-1)  59 non-null     float64
#  2   var3(t-1)  59 non-null     float64
#  3   var4(t-1)  59 non-null     float64
#  4   var5(t-1)  59 non-null     float64
#  5   var6(t-1)  59 non-null     float64
#  6   var7(t-1)  59 non-null     float64
#  7   var1(t)    59 non-null     float64
# dtypes: float64(8)
# memory usage: 4.1 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (215, 1, 7) (215,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (59, 1, 7) (59,)

# %% [markdown]
# ### 5. Hyperparameter GridSearchCV GRU-RNN

# %%
from itertools import product
from scikeras.wrappers import KerasRegressor
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
# function models
def get_model(activation='selu', optimizer='sgd', dropout_rate=0.15):

    # reset of session model
    tf.keras.backend.clear_session()

    # design network
    model = Sequential()

    # # Jika menggunakan SB-GRU-RNN
    model.add(Bidirectional(GRU(10, activation=activation, return_sequences=True), input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Bidirectional(GRU(10, activation=activation, return_sequences=True)))
    model.add(Bidirectional(GRU(10, activation=activation, return_sequences=False)))
    model.add(Dropout(dropout_rate))

    # the output layer
    model.add(Dense(1))

    # compiling model
    model.compile(
        optimizer=optimizer,
        loss="mae",
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.MeanAbsolutePercentageError(),
        ]
    )

    # return value
    return model

# %%
# Creating KerasRegressor wrapper for GridSearchCV
grid_model = KerasRegressor(model=get_model, verbose=1)

# %%
# Set param for GridSearch [1]
param_grid = {
    'model__activation': ['relu', 'selu', 'elu', 'softplus'],
    'model__optimizer': ['adam', 'adamax', 'rmsprop', 'sgd'],
    'model__dropout_rate': [0.05, 0.1, 0.15, 0.2, 0.25],
    'batch_size': [2, 4, 8, 16, 32],
    'epochs': [1500],
}

# %%
param_grid
# Out:
# {'model__activation': ['relu', 'selu', 'elu', 'softplus'],
#  'model__optimizer': ['adam', 'adamax', 'rmsprop', 'sgd'],
#  'model__dropout_rate': [0.05, 0.1, 0.15, 0.2, 0.25],
#  'batch_size': [2, 4, 8, 16, 32],
#  'epochs': [1500]}

# %%
# Menghitung jumlah kombinasi
total_combinations = len(list(product(*param_grid.values())))
print("Total kombinasi:", total_combinations)
# Out:
# Total kombinasi: 400

# %%
# process a gridsearchCV
grid_search = GridSearchCV(estimator=grid_model, param_grid=param_grid, n_jobs=-1, cv=2, scoring='neg_root_mean_squared_error')

# %%
grid_result = grid_search.fit(trainX, trainY)
# Out:
# c:\USERS\LUNOX\ANACONDA3\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/1500
# 27/27 [==============================] - 11s 4ms/step - loss: 0.7725 - mean_absolute_error: 0.7725 - mean_squared_error: 0.6255 - mean_absolute_percentage_error: 83.3414
# Epoch 2/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4522 - mean_absolute_error: 0.4522 - mean_squared_error: 0.2434 - mean_absolute_percentage_error: 51.8477
# Epoch 3/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2038 - mean_absolute_error: 0.2038 - mean_squared_error: 0.0770 - mean_absolute_percentage_error: 30.4474
# Epoch 4/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0603 - mean_absolute_percentage_error: 27.9754
# Epoch 5/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 26.4079
# Epoch 6/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1451 - mean_absolute_error: 0.1451 - mean_squared_error: 0.0574 - mean_absolute_percentage_error: 26.1825
# Epoch 7/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - mean_squared_error: 0.0561 - mean_absolute_percentage_error: 24.5364
# Epoch 8/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0538 - mean_absolute_percentage_error: 24.9379
# Epoch 9/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1247 - mean_absolute_error: 0.1247 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 24.5409
# Epoch 10/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0539 - mean_absolute_percentage_error: 25.4190
# Epoch 11/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1241 - mean_absolute_error: 0.1241 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 24.2826
# Epoch 12/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0547 - mean_absolute_percentage_error: 25.2791
# Epoch 13/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1261 - mean_absolute_error: 0.1261 - mean_squared_error: 0.0525 - mean_absolute_percentage_error: 23.8031
# Epoch 14/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1424 - mean_absolute_error: 0.1424 - mean_squared_error: 0.0578 - mean_absolute_percentage_error: 27.3566
# Epoch 15/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1236 - mean_absolute_error: 0.1236 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 23.8113
# Epoch 16/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1263 - mean_absolute_error: 0.1263 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 24.7834
# Epoch 17/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0576 - mean_absolute_percentage_error: 25.2145
# Epoch 18/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1258 - mean_absolute_error: 0.1258 - mean_squared_error: 0.0531 - mean_absolute_percentage_error: 24.2857
# Epoch 19/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1295 - mean_absolute_error: 0.1295 - mean_squared_error: 0.0531 - mean_absolute_percentage_error: 24.8677
# Epoch 20/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0509 - mean_absolute_percentage_error: 25.2131
# Epoch 21/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1191 - mean_absolute_error: 0.1191 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 23.9346
# Epoch 22/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1239 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0538 - mean_absolute_percentage_error: 24.8314
# Epoch 23/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1254 - mean_absolute_error: 0.1254 - mean_squared_error: 0.0543 - mean_absolute_percentage_error: 24.9618
# Epoch 24/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1247 - mean_absolute_error: 0.1247 - mean_squared_error: 0.0516 - mean_absolute_percentage_error: 23.8160
# Epoch 25/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0537 - mean_absolute_percentage_error: 24.4736
# Epoch 26/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1249 - mean_absolute_error: 0.1249 - mean_squared_error: 0.0539 - mean_absolute_percentage_error: 24.8640
# Epoch 27/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1349 - mean_absolute_error: 0.1349 - mean_squared_error: 0.0563 - mean_absolute_percentage_error: 25.9894
# Epoch 28/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0503 - mean_absolute_percentage_error: 24.0721
# Epoch 29/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1188 - mean_absolute_error: 0.1188 - mean_squared_error: 0.0507 - mean_absolute_percentage_error: 24.1504
# Epoch 30/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1236 - mean_absolute_error: 0.1236 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 24.6834
# Epoch 31/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1228 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 25.3711
# Epoch 32/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 25.1622
# Epoch 33/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 25.1300
# Epoch 34/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0499 - mean_absolute_percentage_error: 23.6629
# Epoch 35/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1231 - mean_absolute_error: 0.1231 - mean_squared_error: 0.0538 - mean_absolute_percentage_error: 24.7532
# Epoch 36/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0578 - mean_absolute_percentage_error: 26.4848
# Epoch 37/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1152 - mean_absolute_error: 0.1152 - mean_squared_error: 0.0515 - mean_absolute_percentage_error: 24.1631
# Epoch 38/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1226 - mean_absolute_error: 0.1226 - mean_squared_error: 0.0495 - mean_absolute_percentage_error: 24.1811
# Epoch 39/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1198 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0523 - mean_absolute_percentage_error: 24.7856
# Epoch 40/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1225 - mean_absolute_error: 0.1225 - mean_squared_error: 0.0511 - mean_absolute_percentage_error: 23.4240
# Epoch 41/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1181 - mean_absolute_error: 0.1181 - mean_squared_error: 0.0520 - mean_absolute_percentage_error: 23.7313
# Epoch 42/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1212 - mean_absolute_error: 0.1212 - mean_squared_error: 0.0518 - mean_absolute_percentage_error: 24.1467
# Epoch 43/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1287 - mean_absolute_error: 0.1287 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 25.3443
# Epoch 44/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1211 - mean_absolute_error: 0.1211 - mean_squared_error: 0.0489 - mean_absolute_percentage_error: 23.4134
# Epoch 45/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1192 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0528 - mean_absolute_percentage_error: 23.6671
# Epoch 46/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1152 - mean_absolute_error: 0.1152 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 23.3548
# Epoch 47/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0507 - mean_absolute_percentage_error: 23.9660
# Epoch 48/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1125 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0512 - mean_absolute_percentage_error: 23.9489
# Epoch 49/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1129 - mean_absolute_error: 0.1129 - mean_squared_error: 0.0498 - mean_absolute_percentage_error: 23.0678
# Epoch 50/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1195 - mean_absolute_error: 0.1195 - mean_squared_error: 0.0520 - mean_absolute_percentage_error: 23.1352
# Epoch 51/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1193 - mean_absolute_error: 0.1193 - mean_squared_error: 0.0497 - mean_absolute_percentage_error: 24.4357
# Epoch 52/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0471 - mean_absolute_percentage_error: 23.7133
# Epoch 53/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1240 - mean_absolute_error: 0.1240 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 24.8819
# Epoch 54/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1222 - mean_absolute_error: 0.1222 - mean_squared_error: 0.0536 - mean_absolute_percentage_error: 24.0450
# Epoch 55/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1211 - mean_absolute_error: 0.1211 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 25.2019
# Epoch 56/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1227 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0543 - mean_absolute_percentage_error: 25.0116
# Epoch 57/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1233 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 24.1464
# Epoch 58/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1166 - mean_absolute_error: 0.1166 - mean_squared_error: 0.0492 - mean_absolute_percentage_error: 24.3261
# Epoch 59/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1196 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 23.8455
# Epoch 60/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1187 - mean_absolute_error: 0.1187 - mean_squared_error: 0.0531 - mean_absolute_percentage_error: 24.2066
# Epoch 61/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1155 - mean_absolute_error: 0.1155 - mean_squared_error: 0.0486 - mean_absolute_percentage_error: 23.4136
# Epoch 62/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1138 - mean_absolute_error: 0.1138 - mean_squared_error: 0.0496 - mean_absolute_percentage_error: 23.3704
# Epoch 63/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1173 - mean_absolute_error: 0.1173 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 24.7779
# Epoch 64/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - mean_squared_error: 0.0518 - mean_absolute_percentage_error: 23.4824
# Epoch 65/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1121 - mean_absolute_error: 0.1121 - mean_squared_error: 0.0484 - mean_absolute_percentage_error: 22.7158
# Epoch 66/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0525 - mean_absolute_percentage_error: 24.5299
# Epoch 67/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1164 - mean_absolute_error: 0.1164 - mean_squared_error: 0.0501 - mean_absolute_percentage_error: 24.0276
# Epoch 68/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1267 - mean_absolute_error: 0.1267 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 24.7743
# Epoch 69/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1182 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0479 - mean_absolute_percentage_error: 24.0255
# Epoch 70/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - mean_squared_error: 0.0487 - mean_absolute_percentage_error: 22.7792
# Epoch 71/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1100 - mean_absolute_error: 0.1100 - mean_squared_error: 0.0500 - mean_absolute_percentage_error: 22.5044
# Epoch 72/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1210 - mean_absolute_error: 0.1210 - mean_squared_error: 0.0493 - mean_absolute_percentage_error: 24.1570
# Epoch 73/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1206 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0514 - mean_absolute_percentage_error: 24.1967
# Epoch 74/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1193 - mean_absolute_error: 0.1193 - mean_squared_error: 0.0519 - mean_absolute_percentage_error: 24.0898
# Epoch 75/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 24.1401
# Epoch 76/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1157 - mean_absolute_error: 0.1157 - mean_squared_error: 0.0499 - mean_absolute_percentage_error: 23.4442
# Epoch 77/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 23.6173
# Epoch 78/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - mean_squared_error: 0.0504 - mean_absolute_percentage_error: 23.7630
# Epoch 79/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1179 - mean_absolute_error: 0.1179 - mean_squared_error: 0.0521 - mean_absolute_percentage_error: 24.5209
# Epoch 80/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1151 - mean_absolute_error: 0.1151 - mean_squared_error: 0.0475 - mean_absolute_percentage_error: 23.2250
# Epoch 81/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1140 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0495 - mean_absolute_percentage_error: 23.4811
# Epoch 82/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1178 - mean_absolute_error: 0.1178 - mean_squared_error: 0.0508 - mean_absolute_percentage_error: 23.7891
# Epoch 83/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1206 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0530 - mean_absolute_percentage_error: 24.4720
# Epoch 84/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1119 - mean_absolute_error: 0.1119 - mean_squared_error: 0.0515 - mean_absolute_percentage_error: 22.4636
# Epoch 85/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1113 - mean_absolute_error: 0.1113 - mean_squared_error: 0.0515 - mean_absolute_percentage_error: 23.6449
# Epoch 86/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1107 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0494 - mean_absolute_percentage_error: 22.3748
# Epoch 87/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1126 - mean_absolute_error: 0.1126 - mean_squared_error: 0.0505 - mean_absolute_percentage_error: 23.6018
# Epoch 88/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1109 - mean_absolute_error: 0.1109 - mean_squared_error: 0.0476 - mean_absolute_percentage_error: 22.6738
# Epoch 89/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0501 - mean_absolute_percentage_error: 23.8559
# Epoch 90/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1182 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0507 - mean_absolute_percentage_error: 23.4601
# Epoch 91/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1143 - mean_absolute_error: 0.1143 - mean_squared_error: 0.0534 - mean_absolute_percentage_error: 24.0790
# Epoch 92/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0494 - mean_absolute_percentage_error: 22.7151
# Epoch 93/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0509 - mean_absolute_percentage_error: 23.3177
# Epoch 94/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - mean_squared_error: 0.0546 - mean_absolute_percentage_error: 24.9424
# Epoch 95/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1077 - mean_absolute_error: 0.1077 - mean_squared_error: 0.0476 - mean_absolute_percentage_error: 22.5187
# Epoch 96/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - mean_squared_error: 0.0511 - mean_absolute_percentage_error: 22.5540
# Epoch 97/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1128 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0511 - mean_absolute_percentage_error: 23.0174
# Epoch 98/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1086 - mean_absolute_error: 0.1086 - mean_squared_error: 0.0488 - mean_absolute_percentage_error: 22.8741
# Epoch 99/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1100 - mean_absolute_error: 0.1100 - mean_squared_error: 0.0463 - mean_absolute_percentage_error: 22.5476
# Epoch 100/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1089 - mean_absolute_error: 0.1089 - mean_squared_error: 0.0484 - mean_absolute_percentage_error: 22.7153
# Epoch 101/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1095 - mean_absolute_error: 0.1095 - mean_squared_error: 0.0456 - mean_absolute_percentage_error: 22.2236
# Epoch 102/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1127 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0490 - mean_absolute_percentage_error: 22.5691
# Epoch 103/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - mean_squared_error: 0.0471 - mean_absolute_percentage_error: 23.0486
# Epoch 104/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1130 - mean_absolute_error: 0.1130 - mean_squared_error: 0.0487 - mean_absolute_percentage_error: 23.1861
# Epoch 105/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1081 - mean_absolute_error: 0.1081 - mean_squared_error: 0.0492 - mean_absolute_percentage_error: 23.4027
# Epoch 106/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1118 - mean_absolute_error: 0.1118 - mean_squared_error: 0.0483 - mean_absolute_percentage_error: 23.3548
# Epoch 107/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0514 - mean_absolute_percentage_error: 23.3152
# Epoch 108/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1156 - mean_absolute_error: 0.1156 - mean_squared_error: 0.0505 - mean_absolute_percentage_error: 23.5998
# Epoch 109/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1123 - mean_absolute_error: 0.1123 - mean_squared_error: 0.0476 - mean_absolute_percentage_error: 23.3400
# Epoch 110/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1058 - mean_absolute_error: 0.1058 - mean_squared_error: 0.0490 - mean_absolute_percentage_error: 22.2105
# Epoch 111/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1104 - mean_absolute_error: 0.1104 - mean_squared_error: 0.0498 - mean_absolute_percentage_error: 23.1676
# Epoch 112/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1149 - mean_absolute_error: 0.1149 - mean_squared_error: 0.0524 - mean_absolute_percentage_error: 24.1981
# Epoch 113/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1142 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0500 - mean_absolute_percentage_error: 23.1530
# Epoch 114/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1114 - mean_absolute_error: 0.1114 - mean_squared_error: 0.0499 - mean_absolute_percentage_error: 23.3011
# Epoch 115/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1141 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0492 - mean_absolute_percentage_error: 23.2040
# Epoch 116/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1086 - mean_absolute_error: 0.1086 - mean_squared_error: 0.0482 - mean_absolute_percentage_error: 22.8180
# Epoch 117/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1220 - mean_absolute_error: 0.1220 - mean_squared_error: 0.0509 - mean_absolute_percentage_error: 23.7553
# Epoch 118/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1167 - mean_absolute_error: 0.1167 - mean_squared_error: 0.0482 - mean_absolute_percentage_error: 23.1644
# Epoch 119/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.
1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1055 - mean_absolute_error: 0.1055 - mean_squared_error: 0.0465 - mean_absolute_percentage_error: 22.1253
# Epoch 194/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1053 - mean_absolute_error: 0.1053 - mean_squared_error: 0.0480 - mean_absolute_percentage_error: 22.9425
# Epoch 195/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1017 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0456 - mean_absolute_percentage_error: 21.8500
# Epoch 196/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1010 - mean_absolute_error: 0.1010 - mean_squared_error: 0.0470 - mean_absolute_percentage_error: 21.8633
# Epoch 197/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1092 - mean_absolute_error: 0.1092 - mean_squared_error: 0.0464 - mean_absolute_percentage_error: 22.4791
# Epoch 198/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - mean_squared_error: 0.0465 - mean_absolute_percentage_error: 21.7097
# Epoch 199/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1027 - mean_absolute_error: 0.1027 - mean_squared_error: 0.0477 - mean_absolute_percentage_error: 22.1294
# Epoch 200/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1032 - mean_absolute_error: 0.1032 - mean_squared_error: 0.0457 - mean_absolute_percentage_error: 21.7788
# Epoch 201/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1038 - mean_absolute_error: 0.1038 - mean_squared_error: 0.0482 - mean_absolute_percentage_error: 22.4672
# Epoch 202/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1014 - mean_absolute_error: 0.1014 - mean_squared_error: 0.0468 - mean_absolute_percentage_error: 21.4944
# Epoch 203/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1056 - mean_absolute_error: 0.1056 - mean_squared_error: 0.0473 - mean_absolute_percentage_error: 22.1681
# Epoch 204/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1013 - mean_absolute_error: 0.1013 - mean_squared_error: 0.0453 - mean_absolute_percentage_error: 21.2844
# Epoch 205/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1025 - mean_absolute_error: 0.1025 - mean_squared_error: 0.0462 - mean_absolute_percentage_error: 21.8744
# Epoch 206/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1038 - mean_absolute_error: 0.1038 - mean_squared_error: 0.0472 - mean_absolute_percentage_error: 22.2473
# Epoch 207/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1049 - mean_absolute_error: 0.1049 - mean_squared_error: 0.0467 - mean_absolute_percentage_error: 22.1406
# Epoch 208/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1047 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0467 - mean_absolute_percentage_error: 22.1022
# Epoch 209/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1056 - mean_absolute_error: 0.1056 - mean_squared_error: 0.0446 - mean_absolute_percentage_error: 21.6908
# Epoch 210/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1019 - mean_absolute_error: 0.1019 - mean_squared_error: 0.0475 - mean_absolute_percentage_error: 22.1140
# Epoch 211/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1047 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0457 - mean_absolute_percentage_error: 21.7195
# Epoch 212/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1012 - mean_absolute_error: 0.1012 - mean_squared_error: 0.0470 - mean_absolute_percentage_error: 22.0414
# Epoch 213/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1017 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0464 - mean_absolute_percentage_error: 22.1877
# Epoch 214/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1046 - mean_absolute_error: 0.1046 - mean_squared_error: 0.0476 - mean_absolute_percentage_error: 22.1549
# Epoch 215/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - mean_squared_error: 0.0449 - mean_absolute_percentage_error: 21.8562
# Epoch 216/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1036 - mean_absolute_error: 0.1036 - mean_squared_error: 0.0468 - mean_absolute_percentage_error: 21.9751
# Epoch 217/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - mean_squared_error: 0.0468 - mean_absolute_percentage_error: 21.9972
# Epoch 218/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1018 - mean_absolute_error: 0.1018 - mean_squared_error: 0.0462 - mean_absolute_percentage_error: 22.0694
# Epoch 219/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1014 - mean_absolute_error: 0.1014 - mean_squared_error: 0.0461 - mean_absolute_percentage_error: 22.3976
# Epoch 220/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0997 - mean_absolute_error: 0.0997 - mean_squared_error: 0.0465 - mean_absolute_percentage_error: 21.9412
# Epoch 221/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1034 - mean_absolute_error: 0.1034 - mean_squared_error: 0.0453 - mean_absolute_percentage_error: 21.7280
# Epoch 222/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1003 - mean_absolute_error: 0.1003 - mean_squared_error: 0.0438 - mean_absolute_percentage_error: 21.1766
# Epoch 223/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1007 - mean_absolute_error: 0.1007 - mean_squared_error: 0.0444 - mean_absolute_percentage_error: 20.9881
# Epoch 224/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0988 - mean_absolute_error: 0.0988 - mean_squared_error: 0.0444 - mean_absolute_percentage_error: 21.3267
# Epoch 225/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0991 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0460 - mean_absolute_percentage_error: 21.5502
# Epoch 226/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1071 - mean_absolute_error: 0.1071 - mean_squared_error: 0.0482 - mean_absolute_percentage_error: 22.7331
# Epoch 227/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1041 - mean_absolute_error: 0.1041 - mean_squared_error: 0.0473 - mean_absolute_percentage_error: 22.1428
# Epoch 228/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1013 - mean_absolute_error: 0.1013 - mean_squared_error: 0.0453 - mean_absolute_percentage_error: 21.5575
# Epoch 229/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - mean_squared_error: 0.0466 - mean_absolute_percentage_error: 21.6383
# Epoch 230/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1011 - mean_absolute_error: 0.1011 - mean_squared_error: 0.0458 - mean_absolute_percentage_error: 21.8793
# Epoch 231/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0446 - mean_absolute_percentage_error: 21.5948
# Epoch 232/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0982 - mean_absolute_error: 0.0982 - mean_squared_error: 0.0435 - mean_absolute_percentage_error: 21.0514
# Epoch 233/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0443 - mean_absolute_percentage_error: 21.2369
# Epoch 234/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0991 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0455 - mean_absolute_percentage_error: 21.6060
# Epoch 235/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0992 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0465 - mean_absolute_percentage_error: 21.6499
# Epoch 236/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1008 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0440 - mean_absolute_percentage_error: 21.0595
# Epoch 237/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1019 - mean_absolute_error: 0.1019 - mean_squared_error: 0.0455 - mean_absolute_percentage_error: 21.8013
# Epoch 238/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1029 - mean_absolute_error: 0.1029 - mean_squared_error: 0.0445 - mean_absolute_percentage_error: 21.3321
# Epoch 239/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1000 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0439 - mean_absolute_percentage_error: 21.1333
# Epoch 240/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1002 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0456 - mean_absolute_percentage_error: 21.7860
# Epoch 241/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0982 - mean_absolute_error: 0.0982 - mean_squared_error: 0.0458 - mean_absolute_percentage_error: 21.1569
# Epoch 242/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - mean_squared_error: 0.0442 - mean_absolute_percentage_error: 21.5620
# Epoch 243/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0990 - mean_absolute_error: 0.0990 - mean_squared_error: 0.0450 - mean_absolute_percentage_error: 21.7404
# Epoch 244/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0441 - mean_absolute_percentage_error: 20.4958
# Epoch 245/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0992 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0459 - mean_absolute_percentage_error: 21.8409
# Epoch 246/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1002 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0447 - mean_absolute_percentage_error: 20.9433
# Epoch 247/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0998 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0458 - mean_absolute_percentage_error: 21.6824
# Epoch 248/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0443 - mean_absolute_percentage_error: 21.0093
# Epoch 249/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0978 - mean_absolute_error: 0.0978 - mean_squared_error: 0.0435 - mean_absolute_percentage_error: 21.1424
# Epoch 250/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1005 - mean_absolute_error: 0.1005 - mean_squared_error: 0.0444 - mean_absolute_percentage_error: 21.2473
# Epoch 251/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - mean_squared_error: 0.0451 - mean_absolute_percentage_error: 21.1447
# Epoch 252/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0963 - mean_absolute_error: 0.0963 - mean_squared_error: 0.0450 - mean_absolute_percentage_error: 21.0978
# Epoch 253/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0451 - mean_absolute_percentage_error: 21.5985
# Epoch 254/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1008 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0471 - mean_absolute_percentage_error: 21.8584
# Epoch 255/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0422 - mean_absolute_percentage_error: 21.1328
# Epoch 256/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0995 - mean_absolute_error: 0.0995 - mean_squared_error: 0.0451 - mean_absolute_percentage_error: 21.3174
# Epoch 257/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0966 - mean_absolute_error: 0.0966 - mean_squared_error: 0.0445 - mean_absolute_percentage_error: 20.6247
# Epoch 258/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1017 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0459 - mean_absolute_percentage_error: 21.1862
# Epoch 259/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0985 - mean_absolute_error: 0.0985 - mean_squared_error: 0.0450 - mean_absolute_percentage_error: 21.1484
# Epoch 260/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1000 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0457 - mean_absolute_percentage_error: 21.7591
# Epoch 261/1500
# ...
# Epoch 1415/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0680 - mean_absolute_error: 0.0680 - mean_squared_error: 0.0348 - mean_absolute_percentage_error: 16.9211
# Epoch 1416/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0351 - mean_absolute_percentage_error: 14.9525
# Epoch 1417/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0686 - mean_squared_error: 0.0385 - mean_absolute_percentage_error: 15.7846
# Epoch 1418/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - mean_squared_error: 0.0343 - mean_absolute_percentage_error: 14.3150
# Epoch 1419/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0664 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0339 - mean_absolute_percentage_error: 15.4258
# Epoch 1420/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.
1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - mean_squared_error: 0.0335 - mean_absolute_percentage_error: 13.7051
# Epoch 1446/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0360 - mean_absolute_percentage_error: 15.2190
# Epoch 1447/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0654 - mean_absolute_error: 0.0654 - mean_squared_error: 0.0335 - mean_absolute_percentage_error: 14.3679
# Epoch 1448/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0327 - mean_absolute_percentage_error: 14.4763
# Epoch 1449/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0673 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0354 - mean_absolute_percentage_error: 15.3867
# Epoch 1450/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0675 - mean_absolute_error: 0.0675 - mean_squared_error: 0.0361 - mean_absolute_percentage_error: 15.1840
# Epoch 1451/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0658 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0329 - mean_absolute_percentage_error: 14.2054
# Epoch 1452/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0363 - mean_absolute_percentage_error: 14.8270
# Epoch 1453/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0659 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0342 - mean_absolute_percentage_error: 15.1926
# Epoch 1454/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0686 - mean_squared_error: 0.0357 - mean_absolute_percentage_error: 14.9253
# Epoch 1455/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0639 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0322 - mean_absolute_percentage_error: 14.8034
# Epoch 1456/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0322 - mean_absolute_percentage_error: 14.2782
# Epoch 1457/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0654 - mean_absolute_error: 0.0654 - mean_squared_error: 0.0347 - mean_absolute_percentage_error: 13.6046
# Epoch 1458/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0676 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0355 - mean_absolute_percentage_error: 14.1864
# Epoch 1459/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - mean_squared_error: 0.0346 - mean_absolute_percentage_error: 14.5841
# Epoch 1460/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0662 - mean_absolute_error: 0.0662 - mean_squared_error: 0.0351 - mean_absolute_percentage_error: 14.0728
# Epoch 1461/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0676 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0359 - mean_absolute_percentage_error: 14.9733
# Epoch 1462/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0686 - mean_squared_error: 0.0350 - mean_absolute_percentage_error: 15.5307
# Epoch 1463/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0369 - mean_absolute_percentage_error: 15.6838
# Epoch 1464/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0330 - mean_absolute_percentage_error: 14.1639
# Epoch 1465/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0326 - mean_absolute_percentage_error: 14.5859
# Epoch 1466/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0355 - mean_absolute_percentage_error: 14.6985
# Epoch 1467/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0645 - mean_absolute_error: 0.0645 - mean_squared_error: 0.0315 - mean_absolute_percentage_error: 14.0572
# Epoch 1468/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0344 - mean_absolute_percentage_error: 14.2710
# Epoch 1469/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0659 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0340 - mean_absolute_percentage_error: 14.1227
# Epoch 1470/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0649 - mean_absolute_error: 0.0649 - mean_squared_error: 0.0338 - mean_absolute_percentage_error: 14.5540
# Epoch 1471/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0331 - mean_absolute_percentage_error: 14.4267
# Epoch 1472/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0329 - mean_absolute_percentage_error: 13.5006
# Epoch 1473/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0657 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0320 - mean_absolute_percentage_error: 14.5095
# Epoch 1474/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0672 - mean_absolute_error: 0.0672 - mean_squared_error: 0.0328 - mean_absolute_percentage_error: 14.7375
# Epoch 1475/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0680 - mean_absolute_error: 0.0680 - mean_squared_error: 0.0358 - mean_absolute_percentage_error: 14.7574
# Epoch 1476/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0330 - mean_absolute_percentage_error: 14.2955
# Epoch 1477/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0659 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0343 - mean_absolute_percentage_error: 14.3420
# Epoch 1478/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0323 - mean_absolute_percentage_error: 14.4235
# Epoch 1479/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0664 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0353 - mean_absolute_percentage_error: 14.8216
# Epoch 1480/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0346 - mean_absolute_percentage_error: 14.7642
# Epoch 1481/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0343 - mean_absolute_percentage_error: 15.2565
# Epoch 1482/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0672 - mean_absolute_error: 0.0672 - mean_squared_error: 0.0340 - mean_absolute_percentage_error: 14.9464
# Epoch 1483/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0655 - mean_absolute_error: 0.0655 - mean_squared_error: 0.0348 - mean_absolute_percentage_error: 14.7279
# Epoch 1484/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0362 - mean_absolute_percentage_error: 14.8461
# Epoch 1485/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0348 - mean_absolute_percentage_error: 14.3616
# Epoch 1486/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0659 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0354 - mean_absolute_percentage_error: 14.0792
# Epoch 1487/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0342 - mean_absolute_percentage_error: 14.1131
# Epoch 1488/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0663 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0336 - mean_absolute_percentage_error: 15.5718
# Epoch 1489/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0643 - mean_absolute_error: 0.0643 - mean_squared_error: 0.0340 - mean_absolute_percentage_error: 13.7243
# Epoch 1490/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0638 - mean_absolute_error: 0.0638 - mean_squared_error: 0.0323 - mean_absolute_percentage_error: 14.5801
# Epoch 1491/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0347 - mean_absolute_percentage_error: 14.3355
# Epoch 1492/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0669 - mean_absolute_error: 0.0669 - mean_squared_error: 0.0359 - mean_absolute_percentage_error: 15.0869
# Epoch 1493/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0658 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0348 - mean_absolute_percentage_error: 13.8761
# Epoch 1494/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0330 - mean_absolute_percentage_error: 14.7849
# Epoch 1495/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0649 - mean_absolute_error: 0.0649 - mean_squared_error: 0.0332 - mean_absolute_percentage_error: 14.7528
# Epoch 1496/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0357 - mean_absolute_percentage_error: 14.2025
# Epoch 1497/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0345 - mean_absolute_percentage_error: 14.7818
# Epoch 1498/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0324 - mean_absolute_percentage_error: 13.7263
# Epoch 1499/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0354 - mean_absolute_percentage_error: 15.4503
# Epoch 1500/1500
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0657 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0356 - mean_absolute_percentage_error: 14.5834

# %% [markdown]
# - cek hasil gridsearchCV

# %%
# summarize results
print("Best parameters: %f using %s\n" % (grid_search.best_score_, grid_search.best_params_))
# Out:
# Best parameters: -0.191126 using {'batch_size': 8, 'epochs': 1500, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}

# %%
# show the results
result = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["score"])],axis=1)

# %%
# show the results
result = result.sort_values(by="score", ascending=False)
result
# Out:
#      batch_size  epochs model__activation  model__dropout_rate  \
# 209           8    1500               elu                 0.15
# 374          32    1500               elu                 0.20
# 205           8    1500               elu                 0.10
# 364          32    1500               elu                 0.10
# 378          32    1500               elu                 0.25
# ..          ...     ...               ...                  ...
# 241          16    1500              relu                 0.05
# 148           4    1500          softplus                 0.15
# 236           8    1500          softplus                 0.25
# 321          32    1500              relu                 0.05
# 280          16    1500               elu                 0.05
#
#     model__optimizer     score
# 209           adamax -0.191126
# 374          rmsprop -0.192135
# 205           adamax -0.192331
# 364             adam -0.192870
# 378          rmsprop -0.193945
# ..               ...       ...
# 241           adamax -0.448161
# 148             adam -0.454063
# 236             adam -0.460484
# 321           adamax -0.501466
# 280             adam -0.620030
#
# [400 rows x 6 columns]

# %%
# # write csv form dataframe
# csv_file = '/content/drive/MyDrive/BOPTN_2024/M6_hasil_gridsearch.csv'

csv_file = 'M6_hasil_gridsearch.csv'
result.to_csv(csv_file, index=False)

# %%
# # Specify the text file name
# csv_file = '/content/drive/MyDrive/BOPTN_2024/M6_best_param.csv'
csv_file = "M6_best_param.csv"

# create dataframe from best_param
df = pd.DataFrame([grid_search.best_params_])

# write csv form dataframe
df.to_csv(csv_file, index=False)

# %% [markdown]
# ### 6. Evaluasi Model

# %%
# Set akhir waktu komputasi
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 06:35:24.76
