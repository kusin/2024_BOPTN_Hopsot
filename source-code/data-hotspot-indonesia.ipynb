# %% [markdown]
# ## Data MODIS Hotspot Indonesia 2001 - 2023

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd

# pustaka untuk visualisasi data
import matplotlib.pyplot as plt

# %% [markdown]
# - Load Dataset

# %%
df_hotspot_1 = pd.read_csv("D:/Dataset/dataset-firms-nasa/modis 2001 - 2023 part 1.csv", parse_dates=["acq_date"])
df_hotspot_1
# Out:
#          latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0         -4.0082   121.7859       312.0   2.3    1.5 2001-01-01       258
# 1         -8.1135   112.9281       359.1   1.1    1.0 2001-01-01       259
# 2         -8.4164   117.5434       320.0   1.3    1.1 2001-01-01       259
# 3         -8.1127   112.9221       309.8   1.0    1.0 2001-01-01      1516
# 4         -6.9726   107.6152       314.3   1.4    1.2 2001-01-02       342
# ...           ...        ...         ...   ...    ...        ...       ...
# 1439134   -6.2324   138.9063       306.6   1.5    1.2 2023-01-30       415
# 1439135   -2.1614   115.5855       311.5   1.1    1.1 2023-01-30       555
# 1439136   -2.1628   115.5756       312.3   1.1    1.1 2023-01-30       555
# 1439137    2.2506   117.3318       309.2   1.0    1.0 2023-01-30       556
# 1439138   -2.4454   133.1386       320.6   1.1    1.0 2023-01-31       458
#
# ...

# %%
df_hotspot_2 = pd.read_csv("D:/Dataset/dataset-firms-nasa/modis 2001 - 2023 part 2.csv", parse_dates=["acq_date"])
df_hotspot_2
# Out:
#        latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0       2.64276   98.00831      312.11  1.60   1.25 2023-02-01       359
# 1      -2.58475  121.38049      328.51  1.00   1.00 2023-02-01       542
# 2      -2.00711  121.42736      316.05  1.01   1.00 2023-02-01       542
# 3      -2.57582  121.37917      331.30  1.00   1.00 2023-02-01       542
# 4       1.66861  101.42554      310.51  3.03   1.66 2023-02-02       624
# ...         ...        ...         ...   ...    ...        ...       ...
# 51607  -3.87266  122.39165      309.55  1.02   1.01 2023-12-31      1352
# 51608  -3.90569  122.42116      315.82  1.02   1.01 2023-12-31      1352
# 51609   0.55819  123.95555      306.46  1.33   1.14 2023-12-31      1354
# 51610  -2.57470  121.38992      301.92  1.94   1.36 2023-12-31      1815
# 51611   0.69314  117.55779      308.17  1.03   1.02 2023-12-31      1815
#
#       satellite instrument  confidence version  bright_t31    frp daynight
# ...

# %% [markdown]
# - Concate Data

# %%
frames = [df_hotspot_1, df_hotspot_2]

# %%
df_hotspot = pd.concat(frames, axis=0)
df_hotspot
# Out:
#        latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0      -4.00820  121.78590      312.00  2.30   1.50 2001-01-01       258
# 1      -8.11350  112.92810      359.10  1.10   1.00 2001-01-01       259
# 2      -8.41640  117.54340      320.00  1.30   1.10 2001-01-01       259
# 3      -8.11270  112.92210      309.80  1.00   1.00 2001-01-01      1516
# 4      -6.97260  107.61520      314.30  1.40   1.20 2001-01-02       342
# ...         ...        ...         ...   ...    ...        ...       ...
# 51607  -3.87266  122.39165      309.55  1.02   1.01 2023-12-31      1352
# 51608  -3.90569  122.42116      315.82  1.02   1.01 2023-12-31      1352
# 51609   0.55819  123.95555      306.46  1.33   1.14 2023-12-31      1354
# 51610  -2.57470  121.38992      301.92  1.94   1.36 2023-12-31      1815
# 51611   0.69314  117.55779      308.17  1.03   1.02 2023-12-31      1815
#
#       satellite instrument  confidence version  bright_t31    frp daynight  \
# ...

# %% [markdown]
# - Export Data

# %%
# df_hotspot.to_csv("D:/Dataset/dataset-firms-nasa/MODIS 2023.csv", index=False)

# %% [markdown]
# ### PraProses Data Hotspot MODIS 2001 - 2023

# %% [markdown]
# - Load Data

# %%
df_hotspot = pd.read_csv("D:/Dataset/dataset-firms-nasa/MODIS Indonesia 2023.csv", low_memory=False, parse_dates=["acq_date"])
df_hotspot
# Out:
#          latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0        -4.00820  121.78590      312.00  2.30   1.50 2001-01-01       258
# 1        -8.11350  112.92810      359.10  1.10   1.00 2001-01-01       259
# 2        -8.41640  117.54340      320.00  1.30   1.10 2001-01-01       259
# 3        -8.11270  112.92210      309.80  1.00   1.00 2001-01-01      1516
# 4        -6.97260  107.61520      314.30  1.40   1.20 2001-01-02       342
# ...           ...        ...         ...   ...    ...        ...       ...
# 1490746  -3.87266  122.39165      309.55  1.02   1.01 2023-12-31      1352
# 1490747  -3.90569  122.42116      315.82  1.02   1.01 2023-12-31      1352
# 1490748   0.55819  123.95555      306.46  1.33   1.14 2023-12-31      1354
# 1490749  -2.57470  121.38992      301.92  1.94   1.36 2023-12-31      1815
# 1490750   0.69314  117.55779      308.17  1.03   1.02 2023-12-31      1815
#
# ...

# %%
df_hotspot_harian = df_hotspot.groupby(['acq_date']).size().reset_index(name='hotspot')

# %%
print(df_hotspot_harian)
# Out:
#        acq_date  hotspot
# 0    2001-01-01        4
# 1    2001-01-02        1
# 2    2001-01-03        2
# 3    2001-01-04        1
# 4    2001-01-05        1
# ...         ...      ...
# 8301 2023-12-27       33
# 8302 2023-12-28       33
# 8303 2023-12-29       44
# 8304 2023-12-30       17
# 8305 2023-12-31       25
#
# [8306 rows x 2 columns]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(df_hotspot_harian["acq_date"], df_hotspot_harian["hotspot"], color="tab:blue", label="Hotspot di Indonesia 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
df_hotspot_bulanan = df_hotspot.resample('M', on='acq_date').size().reset_index(name='hotspot')

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(df_hotspot_bulanan["acq_date"], df_hotspot_bulanan["hotspot"], color="tab:blue", label="Hotspot di Indonesia 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()
