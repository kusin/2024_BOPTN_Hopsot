# %% [markdown]
# ## Akuisisi Data

# %% [markdown]
# ### 1. Deklarasi Pustaka

# %%
# pustaka manipulasi data array
import numpy as np
from numpy import concatenate

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame

# pustaka tanggal
from datetime import datetime
from matplotlib import pyplot as plt

# %% [markdown]
# ### 2. Deklarasi Function

# %%
# define function
def plot_time_series(x, y, label, title):
    
    # membuat frame
    fig, ax = plt.subplots(figsize = (10,5))
    
    # membuat time series plot
    ax.plot(x, y, color="tab:blue", label=label, linewidth=2.5)
    
    # membuat label-label
    ax.set_title(title, fontsize=14)
    ax.set_xlabel("", fontsize=12)
    ax.set_ylabel("", fontsize=12)
    ax.legend(loc="best")
    ax.grid(True)
    
    # menampilkan plot
    plt.show()

# %% [markdown]
# ### 3. Hotspot Sumatera Selatan

# %% [markdown]
# - Loada dataset

# %%
# load dataset
df_hotspot_1 = pd.read_csv("dataset/hotspot_sumsel_harian_2001_2022.csv", parse_dates=["acq_date"])

# %%
df_hotspot_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157946 entries, 0 to 157945
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    157946 non-null  float64
#  1   longitude   157946 non-null  float64
#  2   brightness  157946 non-null  float64
#  3   scan        157946 non-null  float64
#  4   track       157946 non-null  float64
#  5   acq_date    157946 non-null  datetime64[ns]
#  6   acq_time    157946 non-null  int64
#  7   satellite   157946 non-null  object
#  8   instrument  157946 non-null  object
#  9   confidence  157946 non-null  int64
#  10  version     157946 non-null  float64
#  11  bright_t31  157946 non-null  float64
#  12  frp         157946 non-null  float64
#  13  daynight    157946 non-null  object
#  14  type        157946 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(3)
# memory usage: 18.1+ MB

# %%
# load dataset
df_hotspot_2 = pd.read_csv("dataset/hotspot_sumsel_harian_2023.csv", parse_dates=["acq_date"])

# %%
df_hotspot_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6280 entries, 0 to 6279
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    6280 non-null   float64
#  1   longitude   6280 non-null   float64
#  2   brightness  6280 non-null   float64
#  3   scan        6280 non-null   float64
#  4   track       6280 non-null   float64
#  5   acq_date    6280 non-null   datetime64[ns]
#  6   acq_time    6280 non-null   int64
#  7   satellite   6280 non-null   object
#  8   instrument  6280 non-null   object
#  9   confidence  6280 non-null   int64
#  10  version     6280 non-null   object
#  11  bright_t31  6280 non-null   float64
#  12  frp         6280 non-null   float64
#  13  daynight    6280 non-null   object
#  14  field_15    3 non-null      float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(4)
# memory usage: 736.1+ KB

# %%
df_hotspot = pd.concat([df_hotspot_1, df_hotspot_2])

# %%
df_hotspot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164226 entries, 0 to 6279
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    164226 non-null  float64
#  1   longitude   164226 non-null  float64
#  2   brightness  164226 non-null  float64
#  3   scan        164226 non-null  float64
#  4   track       164226 non-null  float64
#  5   acq_date    164226 non-null  datetime64[ns]
#  6   acq_time    164226 non-null  int64
#  7   satellite   164226 non-null  object
#  8   instrument  164226 non-null  object
#  9   confidence  164226 non-null  int64
#  10  version     164226 non-null  object
#  11  bright_t31  164226 non-null  float64
#  12  frp         164226 non-null  float64
#  13  daynight    164226 non-null  object
#  14  type        157946 non-null  float64
#  15  field_15    3 non-null       float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(4)
# memory usage: 21.3+ MB

# %%
df_hotspot
# Out:
#       latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0     -2.82010  104.07160      307.40  1.90   1.30 2001-01-14       405
# 1     -2.82250  104.08820      313.20  1.90   1.30 2001-01-14       405
# 2     -2.82770  104.08090      313.90  1.90   1.30 2001-01-14       405
# 3     -2.82460  104.07820      302.30  1.80   1.30 2001-02-10      1607
# 4     -2.82160  104.08290      306.10  1.20   1.10 2001-02-23      1536
# ...        ...        ...         ...   ...    ...        ...       ...
# 6275  -4.46693  104.21229      317.57  1.06   1.03 2023-11-06       707
# 6276  -4.70200  104.09773      353.79  1.18   1.08 2023-11-08       652
# 6277  -4.70346  104.08731      351.47  1.18   1.08 2023-11-08       652
# 6278  -4.61046  104.29850      319.77  1.15   1.07 2023-11-08       652
# 6279  -4.53613  104.23169      318.50  1.01   1.00 2023-11-13       705
#
#      satellite instrument  confidence version  bright_t31    frp daynight  \
# 0        Terra      MODIS          41    6.03      288.70   7.60        D
# 1        Terra      MODIS          68    6.03      290.70  17.70        D
# 2        Terra      MODIS          68    6.03      290.80  19.40        D
# 3        Terra      MODIS          48    6.03      279.10  11.80        N
# 4        Terra      MODIS          67    6.03      290.80   7.30        N
# ...        ...        ...         ...     ...         ...    ...      ...
# 6275      Aqua      MODIS          40  6.1NRT      297.65   7.32        D
# 6276      Aqua      MODIS          96  6.1NRT      301.75  80.91        D
# 6277      Aqua      MODIS          95  6.1NRT      301.78  74.63        D
# 6278      Aqua      MODIS          54  6.1NRT      300.49  10.87        D
# 6279      Aqua      MODIS          68  6.1NRT      299.24   6.57        D
#
#       type  field_15
# 0      2.0       NaN
# 1      2.0       NaN
# 2      2.0       NaN
# 3      2.0       NaN
# 4      2.0       NaN
# ...    ...       ...
# 6275   NaN       NaN
# 6276   NaN       NaN
# 6277   NaN       NaN
# 6278   NaN       NaN
# 6279   NaN       NaN
#
# [164226 rows x 16 columns]

# %%
# # set index 
# df_hotspot = df_hotspot.set_index("acq_date")

# %% [markdown]
# - Aggregasi dataset

# %%
# Agregasi data harian menjadi bulanan dengan menghitung jumlah hotspot per bulan
df_hotspot_bulanan = df_hotspot.resample('M', on='acq_date').size().reset_index(name='hotspot')

# %%
df_hotspot_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 4.4 KB

# %%
# df_hotspot_bulanan.to_csv("dataset/hotspot_sumsel_bulanan_2001_2023.csv", index=False)

# %% [markdown]
# - Visualisasi dataset

# %%
plot_time_series(df_hotspot_bulanan["acq_date"], df_hotspot_bulanan["hotspot"], "Hotspot Sumatera Selatan", "")

# %% [markdown]
# ### 4. Index SOI

# %%
soi = pd.read_excel("dataset/dataset_enso.xlsx", sheet_name="SOI Results")

# %%
soi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      276 non-null    datetime64[ns]
#  1   anomali   276 non-null    float64
#  2   standard  276 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 6.6 KB

# %%
plot_time_series(soi["date"], soi["anomali"], "Index SOI tahun 2001 - 2023", "")

# %%
plot_time_series(soi["date"], soi["standard"], "Index SOI tahun 2001 - 2023", "")

# %% [markdown]
# ### 5. SST Nina 3.4

# %%
sst = pd.read_excel("dataset/dataset_enso.xlsx", sheet_name="SST Results")

# %%
sst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      276 non-null    datetime64[ns]
#  1   anomali   276 non-null    float64
#  2   standard  276 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 6.6 KB

# %%
plot_time_series(sst["date"], sst["anomali"], "SST Nina 3.4 tahun 2001 - 2023", "")

# %%
plot_time_series(sst["date"], sst["standard"], "SST Nina 3.4 tahun 2001 - 2023", "")

# %% [markdown]
# ### 5. ONI Index

# %%
oni = pd.read_excel("dataset/dataset_enso.xlsx", sheet_name="ONI Results")

# %%
plot_time_series(oni["date"], oni["anomali"], "ONI Index tahun 2001 - 2023", "")

# %%
plot_time_series(oni["date"], oni["standard"], "ONI Index tahun 2001 - 2023", "")

# %% [markdown]
# ### Final Dataset

# %%
# Data hotspot
hotspot = df_hotspot_bulanan

# Data ENSO
# -----------------
soi_anom = soi[["anomali"]]
soi_std = soi[["standard"]]

sst_anom = sst[["anomali"]]
sst_std = sst[["standard"]]

oni_anom = oni[["anomali"]]
oni_std = oni[["standard"]]

# Data Iklim
# -----------------
radiasi = ""
curah_hujan = ""
suhu_udara = ""
kelembaban_udara = ""
kecepatan_angin = ""

# %%
dataset = pd.concat([hotspot, soi_anom, soi_std, sst_anom, sst_std, oni_anom, oni_std], axis=1)
dataset.columns = ["acq_date", "hotspot", "soi_anom", "soi_std", "sst_anom", "sst_std", "oni_anom", "oni_std"]

# %%
dataset
# Out:
#       acq_date  hotspot  soi_anom  soi_std  sst_anom  sst_std  oni_anom  \
# 0   2001-01-31        3       1.6      1.0     -0.76    25.81     -0.68
# 1   2001-02-28        5       2.8      1.7     -0.56    26.18     -0.52
# 2   2001-03-31       10       1.5      0.9     -0.37    26.86     -0.44
# 3   2001-04-30       20       0.3      0.2     -0.56    27.24     -0.34
# 4   2001-05-31       39      -0.8     -0.5     -0.46    27.42     -0.25
# ..         ...      ...       ...      ...       ...      ...       ...
# 271 2023-08-31      186      -1.4     -0.8      1.30    28.20      1.32
# 272 2023-09-30     2247      -2.1     -1.3      1.53    28.29      1.56
# 273 2023-10-31     3200      -0.8     -0.5      1.59    28.36      1.78
# 274 2023-11-30      390      -1.3     -0.8      1.90    28.72      1.92
# 275 2023-12-31       42      -0.4     -0.2      1.99    28.64      1.97
#
#      oni_std
# 0      25.88
# 1      26.26
# 2      26.76
# 3      27.25
# 4      27.49
# ..       ...
# 271    28.28
# 272    28.32
# 273    28.49
# 274    28.60
# 275    28.59
#
# [276 rows x 8 columns]

# %%
# dataset.to_csv("dataset/dataset_boptn.csv", index=False)
