# %% [markdown]
# ## Percobaan 2 - Model Prediksi Titik Panas di Sumatera Selatan 2001 - 2023

# %% [markdown]
# - Jika dipengaruhi oleh enso

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

import random as rm
import time as tm

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# Setting seed
rm.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# Setting Algorithm
algorithm = "LSTM-RNN"

# %%
# # Setting Algorithm
# algorithm = "GRU-RNN"

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
dataset = pd.read_csv("dataset/dataset_enso.csv", parse_dates=["acq_date"])

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
#  2   sst_std   276 non-null    float64
#  3   sst_anom  276 non-null    float64
#  4   oni_std   276 non-null    float64
#  5   oni_anom  276 non-null    float64
#  6   soi_std   276 non-null    float64
#  7   soi_anom  276 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
print(dataset.head())
# Out:
#     acq_date  hotspot  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom
# 0 2001-01-31        3    25.81     -0.76    25.88     -0.68      1.0       1.6
# 1 2001-02-28        5    26.18     -0.56    26.26     -0.52      1.7       2.8
# 2 2001-03-31       10    26.86     -0.37    26.76     -0.44      0.9       1.5
# 3 2001-04-30       20    27.24     -0.56    27.25     -0.34      0.2       0.3
# 4 2001-05-31       39    27.42     -0.46    27.49     -0.25     -0.5      -0.8

# %% [markdown]
# ### 2. Praproses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# jika hotspot dipengaruhi oleh enso
data = dataset[["hotspot", "sst_std", "sst_anom", "oni_std", "oni_anom", "soi_std", "soi_anom"]]
data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3.  , 25.81, -0.76, 25.88, -0.68,  1.  ,  1.6 ],
#        [ 5.  , 26.18, -0.56, 26.26, -0.52,  1.7 ,  2.8 ],
#        [10.  , 26.86, -0.37, 26.76, -0.44,  0.9 ,  1.5 ],
#        [20.  , 27.24, -0.56, 27.25, -0.34,  0.2 ,  0.3 ],
#        [39.  , 27.42, -0.46, 27.49, -0.25, -0.5 , -0.8 ]])

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 7)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 7)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled[:,:1]), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
train_data.shape
# Out:
# (216, 7)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],4)
# Out:
# array([[-0.999 , -0.0066,  0.0487,  0.1221,  0.1168,  0.0333,  0.02  ],
#        [-0.9993,  0.081 ,  0.0673,  0.216 ,  0.1028, -0.4333, -0.42  ],
#        [-0.9979,  0.4179,  0.1879,  0.4131,  0.0981, -0.0667, -0.06  ],
#        [-0.9975,  0.558 ,  0.0719,  0.5681,  0.0748,  0.0667,  0.08  ],
#        [-0.99  ,  0.6018,  0.0858,  0.5822,  0.0187, -0.1   , -0.1   ]])

# %%
test_data.shape
# Out:
# (60, 7)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data[:,:1], color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data[:,:1], color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    
    # return value
    return agg

# %% [markdown]
# - hasil supervised learning data train

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train_data, 1, 1)

# %%
# drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_train.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (215, 7) (215,)

# %% [markdown]
# - hasil supervised learning data test

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test_data, 1, 1)

# %%
# drop columns we don't want to predict
reframed_test.drop(reframed_test.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (59, 7) (59,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  215 non-null    float64
#  1   var2(t-1)  215 non-null    float64
#  2   var3(t-1)  215 non-null    float64
#  3   var4(t-1)  215 non-null    float64
#  4   var5(t-1)  215 non-null    float64
#  5   var6(t-1)  215 non-null    float64
#  6   var7(t-1)  215 non-null    float64
#  7   var1(t)    215 non-null    float64
# dtypes: float64(8)
# memory usage: 15.1 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  59 non-null     float64
#  1   var2(t-1)  59 non-null     float64
#  2   var3(t-1)  59 non-null     float64
#  3   var4(t-1)  59 non-null     float64
#  4   var5(t-1)  59 non-null     float64
#  5   var6(t-1)  59 non-null     float64
#  6   var7(t-1)  59 non-null     float64
#  7   var1(t)    59 non-null     float64
# dtypes: float64(8)
# memory usage: 4.1 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (215, 1, 7) (215,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (59, 1, 7) (59,)

# %% [markdown]
# ### 5. Model Prediksi Titik Panas

# %%
# call function
from class_base_model import lstm_algorithm
from class_base_model import gru_algorithm

# set parameter
activation = "relu"
dropout_rate = 0.25
optimizer = "rmsprop"

# check algorithm
if algorithm == "algorithm":
    # call model LSTM-RNN
    model = lstm_algorithm(trainX, activation, dropout_rate, optimizer)
else:
    # call model GRU-RNN
    model = gru_algorithm(trainX, activation, dropout_rate, optimizer)

# %%
# fit network
history = model.fit(
    trainX, trainY, batch_size=28, epochs=1500,
    validation_data=(testX, testY), verbose=1, shuffle=False, use_multiprocessing=True
)
# Out:
# Epoch 1/1500
# 8/8 [==============================] - 20s 335ms/step - loss: 0.8878 - mean_absolute_error: 0.8878 - mean_squared_error: 0.8128 - mean_absolute_percentage_error: 95.7331 - val_loss: 0.8649 - val_mean_absolute_error: 0.8649 - val_mean_squared_error: 0.7622 - val_mean_absolute_percentage_error: 90.2599
# Epoch 2/1500
# 8/8 [==============================] - 0s 35ms/step - loss: 0.8135 - mean_absolute_error: 0.8135 - mean_squared_error: 0.6859 - mean_absolute_percentage_error: 88.0332 - val_loss: 0.7866 - val_mean_absolute_error: 0.7866 - val_mean_squared_error: 0.6318 - val_mean_absolute_percentage_error: 81.9494
# Epoch 3/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7284 - mean_absolute_error: 0.7284 - mean_squared_error: 0.5536 - mean_absolute_percentage_error: 79.2411 - val_loss: 0.6851 - val_mean_absolute_error: 0.6851 - val_mean_squared_error: 0.4817 - val_mean_absolute_percentage_error: 71.2400
# Epoch 4/1500
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6372 - mean_absolute_error: 0.6372 - mean_squared_error: 0.4342 - mean_absolute_percentage_error: 70.3652 - val_loss: 0.5529 - val_mean_absolute_error: 0.5529 - val_mean_squared_error: 0.3196 - val_mean_absolute_percentage_error: 57.3340
# Epoch 5/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5033 - mean_absolute_error: 0.5033 - mean_squared_error: 0.2941 - mean_absolute_percentage_error: 56.1907 - val_loss: 0.3898 - val_mean_absolute_error: 0.3898 - val_mean_squared_error: 0.1713 - val_mean_absolute_percentage_error: 40.5036
# Epoch 6/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3671 - mean_absolute_error: 0.3671 - mean_squared_error: 0.1784 - mean_absolute_percentage_error: 43.3807 - val_loss: 0.2361 - val_mean_absolute_error: 0.2361 - val_mean_squared_error: 0.0810 - val_mean_absolute_percentage_error: 24.9329
# Epoch 7/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2853 - mean_absolute_error: 0.2853 - mean_squared_error: 0.1199 - mean_absolute_percentage_error: 35.8128 - val_loss: 0.1712 - val_mean_absolute_error: 0.1712 - val_mean_squared_error: 0.0469 - val_mean_absolute_percentage_error: 18.3142
# Epoch 8/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2587 - mean_absolute_error: 0.2587 - mean_squared_error: 0.1088 - mean_absolute_percentage_error: 35.3235 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410 - val_mean_squared_error: 0.0308 - val_mean_absolute_percentage_error: 15.3536
# Epoch 9/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - mean_squared_error: 0.0952 - mean_absolute_percentage_error: 31.3389 - val_loss: 0.1185 - val_mean_absolute_error: 0.1185 - val_mean_squared_error: 0.0225 - val_mean_absolute_percentage_error: 13.2261
# Epoch 10/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2351 - mean_absolute_error: 0.2351 - mean_squared_error: 0.0998 - mean_absolute_percentage_error: 32.2567 - val_loss: 0.1049 - val_mean_absolute_error: 0.1049 - val_mean_squared_error: 0.0176 - val_mean_absolute_percentage_error: 12.0031
# Epoch 11/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2252 - mean_absolute_error: 0.2252 - mean_squared_error: 0.0982 - mean_absolute_percentage_error: 30.7138 - val_loss: 0.1221 - val_mean_absolute_error: 0.1221 - val_mean_squared_error: 0.0202 - val_mean_absolute_percentage_error: 13.7152
# Epoch 12/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2152 - mean_absolute_error: 0.2152 - mean_squared_error: 0.0956 - mean_absolute_percentage_error: 32.1488 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358 - val_mean_squared_error: 0.0219 - val_mean_absolute_percentage_error: 15.1203
# Epoch 13/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2046 - mean_absolute_error: 0.2046 - mean_squared_error: 0.0805 - mean_absolute_percentage_error: 30.9883 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 8.7213
# Epoch 14/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2072 - mean_absolute_error: 0.2072 - mean_squared_error: 0.0825 - mean_absolute_percentage_error: 32.2215 - val_loss: 0.0854 - val_mean_absolute_error: 0.0854 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.4089
# Epoch 15/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2143 - mean_absolute_error: 0.2143 - mean_squared_error: 0.0912 - mean_absolute_percentage_error: 32.1659 - val_loss: 0.1060 - val_mean_absolute_error: 0.1060 - val_mean_squared_error: 0.0147 - val_mean_absolute_percentage_error: 12.3922
# Epoch 16/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1902 - mean_absolute_error: 0.1902 - mean_squared_error: 0.0818 - mean_absolute_percentage_error: 29.9303 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368 - val_mean_squared_error: 0.0212 - val_mean_absolute_percentage_error: 15.3376
# Epoch 17/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2020 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0801 - mean_absolute_percentage_error: 29.9813 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000 - val_mean_squared_error: 0.0135 - val_mean_absolute_percentage_error: 11.8935
# Epoch 18/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1935 - mean_absolute_error: 0.1935 - mean_squared_error: 0.0786 - mean_absolute_percentage_error: 28.5364 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 8.2744
# Epoch 19/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2033 - mean_absolute_error: 0.2033 - mean_squared_error: 0.0856 - mean_absolute_percentage_error: 30.7032 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 8.0024
# Epoch 20/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1845 - mean_absolute_error: 0.1845 - mean_squared_error: 0.0799 - mean_absolute_percentage_error: 30.7819 - val_loss: 0.1173 - val_mean_absolute_error: 0.1173 - val_mean_squared_error: 0.0164 - val_mean_absolute_percentage_error: 13.6068
# Epoch 21/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1910 - mean_absolute_error: 0.1910 - mean_squared_error: 0.0816 - mean_absolute_percentage_error: 30.5208 - val_loss: 0.0751 - val_mean_absolute_error: 0.0751 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 9.6585
# Epoch 22/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1928 - mean_absolute_error: 0.1928 - mean_squared_error: 0.0821 - mean_absolute_percentage_error: 31.3626 - val_loss: 0.0760 - val_mean_absolute_error: 0.0760 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 9.7363
# Epoch 23/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1782 - mean_absolute_error: 0.1782 - mean_squared_error: 0.0744 - mean_absolute_percentage_error: 29.9078 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 8.1082
# Epoch 24/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1807 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0726 - mean_absolute_percentage_error: 28.3926 - val_loss: 0.1069 - val_mean_absolute_error: 0.1069 - val_mean_squared_error: 0.0146 - val_mean_absolute_percentage_error: 12.7113
# Epoch 25/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - mean_squared_error: 0.0705 - mean_absolute_percentage_error: 28.3217 - val_loss: 0.0818 - val_mean_absolute_error: 0.0818 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 10.3681
# Epoch 26/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1780 - mean_absolute_error: 0.1780 - mean_squared_error: 0.0747 - mean_absolute_percentage_error: 30.2169 - val_loss: 0.0877 - val_mean_absolute_error: 0.0877 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.9336
# Epoch 27/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - mean_squared_error: 0.0730 - mean_absolute_percentage_error: 27.3104 - val_loss: 0.0447 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0091 - val_mean_absolute_percentage_error: 6.8292
# Epoch 28/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1796 - mean_absolute_error: 0.1796 - mean_squared_error: 0.0703 - mean_absolute_percentage_error: 29.3411 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 8.1254
# Epoch 29/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1678 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0639 - mean_absolute_percentage_error: 25.9285 - val_loss: 0.0794 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 10.1590
# Epoch 30/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1774 - mean_absolute_error: 0.1774 - mean_squared_error: 0.0746 - mean_absolute_percentage_error: 28.0156 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942 - val_mean_squared_error: 0.0127 - val_mean_absolute_percentage_error: 11.4525
# Epoch 31/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1587 - mean_absolute_error: 0.1587 - mean_squared_error: 0.0643 - mean_absolute_percentage_error: 25.3369 - val_loss: 0.1225 - val_mean_absolute_error: 0.1225 - val_mean_squared_error: 0.0177 - val_mean_absolute_percentage_error: 14.1477
# Epoch 32/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1799 - mean_absolute_error: 0.1799 - mean_squared_error: 0.0730 - mean_absolute_percentage_error: 30.2482 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 7.4915
# Epoch 33/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1688 - mean_absolute_error: 0.1688 - mean_squared_error: 0.0675 - mean_absolute_percentage_error: 27.6892 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 8.6237
# Epoch 34/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1596 - mean_absolute_error: 0.1596 - mean_squared_error: 0.0636 - mean_absolute_percentage_error: 26.3424 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 8.0006
# Epoch 35/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1666 - mean_absolute_error: 0.1666 - mean_squared_error: 0.0626 - mean_absolute_percentage_error: 27.6322 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 7.3875
# Epoch 36/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1725 - mean_absolute_error: 0.1725 - mean_squared_error: 0.0650 - mean_absolute_percentage_error: 28.2258 - val_loss: 0.0809 - val_mean_absolute_error: 0.0809 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 10.3309
# Epoch 37/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1642 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0684 - mean_absolute_percentage_error: 28.2183 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.4939
# Epoch 38/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1775 - mean_absolute_error: 0.1775 - mean_squared_error: 0.0714 - mean_absolute_percentage_error: 29.5805 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 7.9687
# Epoch 39/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1738 - mean_absolute_error: 0.1738 - mean_squared_error: 0.0689 - mean_absolute_percentage_error: 28.5197 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 10.2994
# Epoch 40/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - mean_squared_error: 0.0685 - mean_absolute_percentage_error: 27.4260 - val_loss: 0.1025 - val_mean_absolute_error: 0.1025 - val_mean_squared_error: 0.0140 - val_mean_absolute_percentage_error: 12.3353
# Epoch 41/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1718 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0705 - mean_absolute_percentage_error: 28.3951 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.6861
# Epoch 42/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1729 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0676 - mean_absolute_percentage_error: 28.8889 - val_loss: 0.1126 - val_mean_absolute_error: 0.1126 - val_mean_squared_error: 0.0159 - val_mean_absolute_percentage_error: 13.2742
# Epoch 43/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1636 - mean_absolute_error: 0.1636 - mean_squared_error: 0.0609 - mean_absolute_percentage_error: 26.4814 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.7529
# Epoch 44/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0670 - mean_absolute_percentage_error: 27.5093 - val_loss: 0.1181 - val_mean_absolute_error: 0.1181 - val_mean_squared_error: 0.0168 - val_mean_absolute_percentage_error: 13.8235
# Epoch 45/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1720 - mean_absolute_error: 0.1720 - mean_squared_error: 0.0687 - mean_absolute_percentage_error: 29.2955 - val_loss: 0.0459 - val_mean_absolute_error: 0.0459 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.0957
# Epoch 46/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1619 - mean_absolute_error: 0.1619 - mean_squared_error: 0.0631 - mean_absolute_percentage_error: 27.4743 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 7.4428
# Epoch 47/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - mean_squared_error: 0.0642 - mean_absolute_percentage_error: 26.5576 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 6.9746
# Epoch 48/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1626 - mean_absolute_error: 0.1626 - mean_squared_error: 0.0696 - mean_absolute_percentage_error: 28.8802 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 7.5642
# Epoch 49/1500
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1740 - mean_absolute_error: 0.1740 - mean_squared_error: 0.0722 - mean_absolute_percentage_error: 28.2990 - val_loss: 0.0979 - val_mean_absolute_error: 0.0979 - val_mean_squared_error: 0.0135 - val_mean_absolute_percentage_error: 11.9379
# Epoch 50/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1722 - mean_absolute_error: 0.1722 - mean_squared_error: 0.0714 - mean_absolute_percentage_error: 28.1916 - val_loss: 0.0782 - val_mean_absolute_error: 0.0782 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 10.1286
# Epoch 51/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1604 - mean_absolute_error: 0.1604 - mean_squared_error: 0.0655 - mean_absolute_percentage_error: 27.5051 - val_loss: 0.0429 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 6.7825
# Epoch 52/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1514 - mean_absolute_error: 0.1514 - mean_squared_error: 0.0614 - mean_absolute_percentage_error: 26.5820 - val_loss: 0.0767 - val_mean_absolute_error: 0.0767 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 9.9797
# Epoch 53/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1718 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0730 - mean_absolute_percentage_error: 28.7787 - val_loss: 0.0775 - val_mean_absolute_error: 0.0775 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 10.0049
# Epoch 54/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1702 - mean_absolute_error: 0.1702 - mean_squared_error: 0.0679 - mean_absolute_percentage_error: 27.3317 - val_loss: 0.1173 - val_mean_absolute_error: 0.1173 - val_mean_squared_error: 0.0167 - val_mean_absolute_percentage_error: 13.7658
# Epoch 55/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1575 - mean_absolute_error: 0.1575 - mean_squared_error: 0.0688 - mean_absolute_percentage_error: 27.0422 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 6.8881
# Epoch 56/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1573 - mean_absolute_error: 0.1573 - mean_squared_error: 0.0628 - mean_absolute_percentage_error: 27.4713 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002 - val_mean_squared_error: 0.0138 - val_mean_absolute_percentage_error: 12.1461
# Epoch 57/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1612 - mean_absolute_error: 0.1612 - mean_squared_error: 0.0662 - mean_absolute_percentage_error: 26.6637 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 10.3389
# Epoch 58/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - mean_squared_error: 0.0632 - mean_absolute_percentage_error: 26.8427 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 7.0049
# Epoch 59/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1616 - mean_absolute_error: 0.1616 - mean_squared_error: 0.0658 - mean_absolute_percentage_error: 28.5127 - val_loss: 0.0847 - val_mean_absolute_error: 0.0847 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 10.7269
# Epoch 60/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1602 - mean_absolute_error: 0.1602 - mean_squared_error: 0.0691 - mean_absolute_percentage_error: 28.2684 - val_loss: 0.1043 - val_mean_absolute_error: 0.1043 - val_mean_squared_error: 0.0144 - val_mean_absolute_percentage_error: 12.5592
# Epoch 61/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1568 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0652 - mean_absolute_percentage_error: 26.9922 - val_loss: 0.1066 - val_mean_absolute_error: 0.1066 - val_mean_squared_error: 0.0149 - val_mean_absolute_percentage_error: 12.7810
# Epoch 62/1500
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1579 - mean_absolute_error: 0.1579 - mean_squared_error: 0.0645 - mean_absolute_percentage_error: 26.9299 - val_loss: 0.0669 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.0586
# Epoch 63/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1538 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0655 - mean_absolute_percentage_error: 27.5228 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.8815
# Epoch 64/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - mean_squared_error: 0.0620 - mean_absolute_percentage_error: 26.6533 - val_loss: 0.0881 - val_mean_absolute_error: 0.0881 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 11.0878
# Epoch 65/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1506 - mean_absolute_error: 0.1506 - mean_squared_error: 0.0612 - mean_absolute_percentage_error: 25.7296 - val_loss: 0.0968 - val_mean_absolute_error: 0.0968 - val_mean_squared_error: 0.0134 - val_mean_absolute_percentage_error: 11.8569
# Epoch 66/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1631 - mean_absolute_error: 0.1631 - mean_squared_error: 0.0682 - mean_absolute_percentage_error: 28.8850 - val_loss: 0.0671 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.0688
# Epoch 67/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1541 - mean_absolute_error: 0.1541 - mean_squared_error: 0.0648 - mean_absolute_percentage_error: 27.0786 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 7.4483
# Epoch 68/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1571 - mean_absolute_error: 0.1571 - mean_squared_error: 0.0633 - mean_absolute_percentage_error: 27.9347 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.1654
# Epoch 69/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1468 - mean_absolute_error: 0.1468 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 25.6672 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 9.4579
# Epoch 70/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1587 - mean_absolute_error: 0.1587 - mean_squared_error: 0.0656 - mean_absolute_percentage_error: 27.9573 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.1253
# Epoch 71/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - mean_squared_error: 0.0611 - mean_absolute_percentage_error: 26.0304 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.5419
# Epoch 72/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1541 - mean_absolute_error: 0.1541 - mean_squared_error: 0.0657 - mean_absolute_percentage_error: 26.4730 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.1482
# Epoch 73/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1523 - mean_absolute_error: 0.1523 - mean_squared_error: 0.0650 - mean_absolute_percentage_error: 26.9183 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.2757
# Epoch 74/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - mean_squared_error: 0.0592 - mean_absolute_percentage_error: 27.6944 - val_loss: 0.0672 - val_mean_absolute_error: 0.0672 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.1053
# Epoch 75/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1556 - mean_absolute_error: 0.1556 - mean_squared_error: 0.0670 - mean_absolute_percentage_error: 28.1815 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953 - val_mean_squared_error: 0.0137 - val_mean_absolute_percentage_error: 11.8345
# Epoch 76/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - mean_squared_error: 0.0626 - mean_absolute_percentage_error: 28.1765 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.8517
# Epoch 77/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1428 - mean_absolute_error: 0.1428 - mean_squared_error: 0.0629 - mean_absolute_percentage_error: 25.8974 - val_loss: 0.0385 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.5017
# Epoch 78/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - mean_squared_error: 0.0612 - mean_absolute_percentage_error: 26.7945 - val_loss: 0.0807 - val_mean_absolute_error: 0.0807 - val_mean_squared_error: 0.0115 - val_mean_absolute_percentage_error: 10.3644
# Epoch 79/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0624 - mean_absolute_percentage_error: 25.7085 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 7.3672
# Epoch 80/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1483 - mean_absolute_error: 0.1483 - mean_squared_error: 0.0624 - mean_absolute_percentage_error: 27.2905 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.4071
# Epoch 81/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1483 - mean_absolute_error: 0.1483 - mean_squared_error: 0.0630 - mean_absolute_percentage_error: 26.6147 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 7.1561
# Epoch 82/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1512 - mean_absolute_error: 0.1512 - mean_squared_error: 0.0609 - mean_absolute_percentage_error: 26.9191 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 7.3814
# Epoch 83/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1546 - mean_absolute_error: 0.1546 - mean_squared_error: 0.0662 - mean_absolute_percentage_error: 28.7300 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.7070
# Epoch 84/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0652 - mean_absolute_percentage_error: 27.7090 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 9.5929
# Epoch 85/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - mean_squared_error: 0.0645 - mean_absolute_percentage_error: 27.0291 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.2301
# Epoch 86/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1434 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0618 - mean_absolute_percentage_error: 26.1675 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 8.4403
# Epoch 87/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1462 - mean_absolute_error: 0.1462 - mean_squared_error: 0.0593 - mean_absolute_percentage_error: 25.5374 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.9061
# Epoch 88/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1456 - mean_absolute_error: 0.1456 - mean_squared_error: 0.0615 - mean_absolute_percentage_error: 25.7822 - val_loss: 0.0834 - val_mean_absolute_error: 0.0834 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.6571
# Epoch 89/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - mean_squared_error: 0.0606 - mean_absolute_percentage_error: 25.8974 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 8.0272
# Epoch 90/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0616 - mean_absolute_percentage_error: 25.6728 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 9.9174
# Epoch 91/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1386 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0576 - mean_absolute_percentage_error: 26.0273 - val_loss: 0.0831 - val_mean_absolute_error: 0.0831 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.6215
# Epoch 92/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0589 - mean_absolute_percentage_error: 24.9125 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 7.2668
# Epoch 93/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 25.3548 - val_loss: 0.0816 - val_mean_absolute_error: 0.0816 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.5072
# Epoch 94/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1419 - mean_absolute_error: 0.1419 - mean_squared_error: 0.0615 - mean_absolute_percentage_error: 26.6386 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.1051
# Epoch 95/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0558 - mean_absolute_percentage_error: 24.3073 - val_loss: 0.0881 - val_mean_absolute_error: 0.0881 - val_mean_squared_error: 0.0125 - val_mean_absolute_percentage_error: 11.1174
# Epoch 96/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - mean_squared_error: 0.0613 - mean_absolute_percentage_error: 25.1698 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 9.1116
# Epoch 97/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1416 - mean_absolute_error: 0.1416 - mean_squared_error: 0.0586 - mean_absolute_percentage_error: 25.3707 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.9029
# Epoch 98/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 25.6672 - val_loss: 0.0444 - val_mean_absolute_error: 0.0444 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.0701
# Epoch 99/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1321 - mean_absolute_error: 0.1321 - mean_squared_error: 0.0586 - mean_absolute_percentage_error: 23.9856 - val_loss: 0.0776 - val_mean_absolute_error: 0.0776 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 10.0559
# Epoch 100/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1404 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0616 - mean_absolute_percentage_error: 25.9984 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.8195
# Epoch 101/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1429 - mean_absolute_error: 0.1429 - mean_squared_error: 0.0605 - mean_absolute_percentage_error: 26.6307 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 9.2591
# Epoch 102/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - mean_squared_error: 0.0622 - mean_absolute_percentage_error: 26.7276 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.4069
# Epoch 103/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1418 - mean_absolute_error: 0.1418 - mean_squared_error: 0.0646 - mean_absolute_percentage_error: 27.0867 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 9.6016
# Epoch 104/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1388 - mean_absolute_error: 0.1388 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 25.1075 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 9.5564
# Epoch 105/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1380 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0598 - mean_absolute_percentage_error: 25.8695 - val_loss: 0.0809 - val_mean_absolute_error: 0.0809 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.4912
# Epoch 106/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1323 - mean_absolute_error: 0.1323 - mean_squared_error: 0.0599 - mean_absolute_percentage_error: 24.9919 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.3587
# Epoch 107/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1368 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0600 - mean_absolute_percentage_error: 25.4228 - val_loss: 0.0797 - val_mean_absolute_error: 0.0797 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.4189
# Epoch 108/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1377 - mean_absolute_error: 0.1377 - mean_squared_error: 0.0621 - mean_absolute_percentage_error: 26.1265 - val_loss: 0.0794 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.3971
# Epoch 109/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0624 - mean_absolute_percentage_error: 25.4195 - val_loss: 0.0435 - val_mean_absolute_error: 0.0435 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 7.0863
# Epoch 110/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1333 - mean_absolute_error: 0.1333 - mean_squared_error: 0.0610 - mean_absolute_percentage_error: 24.6622 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.7495
# Epoch 111/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0581 - mean_absolute_percentage_error: 24.7748 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 9.4871
# Epoch 112/1500
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1264 - mean_absolute_error: 0.1264 - mean_squared_error: 0.0575 - mean_absolute_percentage_error: 24.6307 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 8.3474
# Epoch 113/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1398 - mean_absolute_error: 0.1398 - mean_squared_error: 0.0626 - mean_absolute_percentage_error: 25.9262 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 7.5089
# Epoch 114/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1328 - mean_absolute_error: 0.1328 - mean_squared_error: 0.0620 - mean_absolute_percentage_error: 25.8283 - val_loss: 0.0836 - val_mean_absolute_error: 0.0836 - val_mean_squared_error: 0.0122 - val_mean_absolute_percentage_error: 10.7415
# Epoch 115/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1265 - mean_absolute_error: 0.1265 - mean_squared_error: 0.0570 - mean_absolute_percentage_error: 25.0438 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 7.4542
# Epoch 116/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1223 - mean_absolute_error: 0.1223 - mean_squared_error: 0.0581 - mean_absolute_percentage_error: 24.5947 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.0356
# Epoch 117/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 24.4013 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 7.9292
# Epoch 118/1500
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1219 - mean_absolute_error: 0.1219 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 23.3583 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.2419
# Epoch 119/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1224 - mean_absolute_error: 0.1224 - mean_squared_error: 0.0561 - mean_absolute_percentage_error: 24.6758 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 7.5629
# Epoch 120/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1251 - mean_absolute_error: 0.1251 - mean_squared_error: 0.0584 - mean_absolute_percentage_error: 24.6632 - val_loss: 0.0776 - val_mean_absolute_error: 0.0776 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.2212
# Epoch 121/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1203 - mean_absolute_error: 0.1203 - mean_squared_error: 0.0567 - mean_absolute_percentage_error: 24.3947 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 8.8313
# Epoch 122/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 23.7349 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.0409
# Epoch 123/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 23.0194 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 9.0137
# Epoch 124/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1226 - mean_absolute_error: 0.1226 - mean_squared_error: 0.0579 - mean_absolute_percentage_error: 24.5511 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.8016
# Epoch 125/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - mean_squared_error: 0.0620 - mean_absolute_percentage_error: 26.1519 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 6.9654
# Epoch 126/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1249 - mean_absolute_error: 0.1249 - mean_squared_error: 0.0586 - mean_absolute_percentage_error: 24.4531 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.3566
# Epoch 127/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1198 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 23.1404 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.4115
# Epoch 128/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1192 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0555 - mean_absolute_percentage_error: 23.3677 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.5498
# Epoch 129/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0555 - mean_absolute_percentage_error: 23.5995 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.2869
# Epoch 130/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1253 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0569 - mean_absolute_percentage_error: 24.9755 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 8.9778
# Epoch 131/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0562 - mean_absolute_percentage_error: 24.4672 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.3833
# Epoch 132/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0592 - mean_absolute_percentage_error: 24.4454 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 7.8714
# Epoch 133/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0575 - mean_absolute_percentage_error: 24.2307 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 10.0654
# Epoch 134/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1268 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0582 - mean_absolute_percentage_error: 24.6281 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 8.8999
# Epoch 135/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1132 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 22.6768 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.4781
# Epoch 136/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1194 - mean_absolute_error: 0.1194 - mean_squared_error: 0.0567 - mean_absolute_percentage_error: 24.2336 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 9.2703
# Epoch 137/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1248 - mean_absolute_error: 0.1248 - mean_squared_error: 0.0601 - mean_absolute_percentage_error: 25.0844 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.1885
# Epoch 138/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1192 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0546 - mean_absolute_percentage_error: 24.0376 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 7.3166
# Epoch 139/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1194 - mean_absolute_error: 0.1194 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 23.5870 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 8.4743
# Epoch 140/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1217 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 23.7276 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 7.8548
# Epoch 141/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1193 - mean_absolute_error: 0.1193 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 23.6637 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 7.8824
# Epoch 142/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0556 - mean_absolute_percentage_error: 24.2085 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 7.1170
# Epoch 143/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1199 - mean_absolute_error: 0.1199 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 24.0374 - val_loss: 0.0810 - val_mean_absolute_error: 0.0810 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.5303
# Epoch 144/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1187 - mean_absolute_error: 0.1187 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 24.5581 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.1958
# Epoch 145/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1168 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0571 - mean_absolute_percentage_error: 24.3087 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 8.7321
# Epoch 146/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1150 - mean_absolute_error: 0.1150 - mean_squared_error: 0.0576 - mean_absolute_percentage_error: 23.7559 - val_loss: 0.0819 - val_mean_absolute_error: 0.0819 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 10.6867
# Epoch 147/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0574 - mean_absolute_percentage_error: 24.0774 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 8.4891
# Epoch 148/1500
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1145 - mean_absolute_error: 0.1145 - mean_squared_error: 0.0530 - mean_absolute_percentage_error: 23.3166 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 8.5783
# Epoch 149/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1155 - mean_absolute_error: 0.1155 - mean_squared_error: 0.0552 - mean_absolute_percentage_error: 23.7699 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 8.1351
# Epoch 150/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1209 - mean_absolute_error: 0.1209 - mean_squared_error: 0.0571 - mean_absolute_percentage_error: 24.3768 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 8.3549
# Epoch 151/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - mean_squared_error: 0.0556 - mean_absolute_percentage_error: 24.2643 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 7.5689
# Epoch 152/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1123 - mean_absolute_error: 0.1123 - mean_squared_error: 0.0558 - mean_absolute_percentage_error: 23.8044 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.5752
# Epoch 153/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1136 - mean_absolute_error: 0.1136 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 23.8332 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 7.9027
# ...
# Epoch 1451/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0271 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0073 - mean_absolute_percentage_error: 4.8223 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 5.9893
# Epoch 1452/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0351 - mean_absolute_error: 0.0351 - mean_squared_error: 0.0101 - mean_absolute_percentage_error: 10.4438 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 5.5048
# Epoch 1453/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0368 - mean_absolute_error: 0.0368 - mean_squared_error: 0.0111 - mean_absolute_percentage_error: 9.9460 - val_loss: 0.0283 - val_mean_absolute_error: 0.0283 - val_mean_squared_error: 0.0088 - val_mean_absolute_percentage_error: 5.1166
# Epoch 1454/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0080 - mean_absolute_percentage_error: 7.6748 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0090 - val_mean_absolute_percentage_error: 4.9426
# Epoch 1455/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0380 - mean_absolute_error: 0.0380 - mean_squared_error: 0.0108 - mean_absolute_percentage_error: 10.2631 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 5.2962
# Epoch 1456/1500
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0388 - mean_absolute_error: 0.0388 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 7.1385 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 5.3886
# Epoch 1457/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0387 - mean_absolute_error: 0.0387 - mean_squared_error: 0.0100 - mean_absolute_percentage_error: 9.0927 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.9922
# Epoch 1458/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0350 - mean_absolute_error: 0.0350 - mean_squared_error: 0.0099 - mean_absolute_percentage_error: 11.2342 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 6.1655
# Epoch 1459/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0402 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0149 - mean_absolute_percentage_error: 6.9270 - val_loss: 0.0344 - val_mean_absolute_error: 0.0344 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 6.2506
# Epoch 1460/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0311 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0067 - mean_absolute_percentage_error: 5.8500 - val_loss: 0.0345 - val_mean_absolute_error: 0.0345 - val_mean_squared_error: 0.0125 - val_mean_absolute_percentage_error: 6.4172
# Epoch 1461/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0202 - mean_absolute_percentage_error: 13.2967 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 5.7014
# Epoch 1462/1500
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0390 - mean_absolute_error: 0.0390 - mean_squared_error: 0.0102 - mean_absolute_percentage_error: 7.8709 - val_loss: 0.0340 - val_mean_absolute_error: 0.0340 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 6.2751
# Epoch 1463/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0304 - mean_absolute_percentage_error: 12.5397 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349 - val_mean_squared_error: 0.0121 - val_mean_absolute_percentage_error: 6.4205
# Epoch 1464/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0341 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0066 - mean_absolute_percentage_error: 6.7270 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 5.4821
# Epoch 1465/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0332 - mean_absolute_error: 0.0332 - mean_squared_error: 0.0117 - mean_absolute_percentage_error: 8.5957 - val_loss: 0.0308 - val_mean_absolute_error: 0.0308 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 5.5931
# Epoch 1466/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0337 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0073 - mean_absolute_percentage_error: 6.5394 - val_loss: 0.0312 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 5.7491
# Epoch 1467/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0348 - mean_absolute_error: 0.0348 - mean_squared_error: 0.0068 - mean_absolute_percentage_error: 9.1910 - val_loss: 0.0332 - val_mean_absolute_error: 0.0332 - val_mean_squared_error: 0.0110 - val_mean_absolute_percentage_error: 6.1097
# Epoch 1468/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0330 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0065 - mean_absolute_percentage_error: 7.8881 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 5.5053
# Epoch 1469/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 11.1632 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 6.0286
# Epoch 1470/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0098 - mean_absolute_percentage_error: 10.2835 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 5.3317
# Epoch 1471/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0391 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 12.7518 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 5.4088
# Epoch 1472/1500
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0314 - mean_absolute_error: 0.0314 - mean_squared_error: 0.0080 - mean_absolute_percentage_error: 5.5182 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.1293
# Epoch 1473/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0134 - mean_absolute_percentage_error: 11.7363 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.1532
# Epoch 1474/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0388 - mean_absolute_error: 0.0388 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 13.7640 - val_loss: 0.0325 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 5.9686
# Epoch 1475/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0351 - mean_absolute_error: 0.0351 - mean_squared_error: 0.0087 - mean_absolute_percentage_error: 11.7304 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.0356
# Epoch 1476/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0328 - mean_absolute_error: 0.0328 - mean_squared_error: 0.0068 - mean_absolute_percentage_error: 6.4920 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0112 - val_mean_absolute_percentage_error: 6.1345
# Epoch 1477/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0337 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0085 - mean_absolute_percentage_error: 5.7618 - val_loss: 0.0313 - val_mean_absolute_error: 0.0313 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 5.7572
# Epoch 1478/1500
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0387 - mean_absolute_error: 0.0387 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 8.3425 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 5.5257
# Epoch 1479/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0403 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0245 - mean_absolute_percentage_error: 11.2384 - val_loss: 0.0309 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 5.4741
# Epoch 1480/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0342 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 6.1518 - val_loss: 0.0316 - val_mean_absolute_error: 0.0316 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 5.7430
# Epoch 1481/1500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0389 - mean_absolute_error: 0.0389 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 7.4981 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 5.3843
# Epoch 1482/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0299 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0057 - mean_absolute_percentage_error: 8.0784 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.2320
# Epoch 1483/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0355 - mean_absolute_error: 0.0355 - mean_squared_error: 0.0078 - mean_absolute_percentage_error: 6.5579 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0089 - val_mean_absolute_percentage_error: 5.0916
# Epoch 1484/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0356 - mean_absolute_error: 0.0356 - mean_squared_error: 0.0103 - mean_absolute_percentage_error: 9.7185 - val_loss: 0.0331 - val_mean_absolute_error: 0.0331 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 6.0437
# Epoch 1485/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0169 - mean_absolute_percentage_error: 13.5675 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0090 - val_mean_absolute_percentage_error: 5.2183
# Epoch 1486/1500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0292 - mean_absolute_error: 0.0292 - mean_squared_error: 0.0042 - mean_absolute_percentage_error: 7.2801 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 5.5118
# Epoch 1487/1500
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0388 - mean_absolute_error: 0.0388 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 6.0431 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0085 - val_mean_absolute_percentage_error: 4.8333
# Epoch 1488/1500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0323 - mean_absolute_error: 0.0323 - mean_squared_error: 0.0058 - mean_absolute_percentage_error: 5.2034 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.2421
# Epoch 1489/1500
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0306 - mean_absolute_error: 0.0306 - mean_squared_error: 0.0062 - mean_absolute_percentage_error: 5.9921 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 5.5754
# Epoch 1490/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0356 - mean_absolute_error: 0.0356 - mean_squared_error: 0.0153 - mean_absolute_percentage_error: 5.4679 - val_loss: 0.0316 - val_mean_absolute_error: 0.0316 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 5.7405
# Epoch 1491/1500
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0187 - mean_absolute_percentage_error: 11.6728 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0093 - val_mean_absolute_percentage_error: 5.4294
# Epoch 1492/1500
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0345 - mean_absolute_error: 0.0345 - mean_squared_error: 0.0084 - mean_absolute_percentage_error: 5.8207 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 0.0090 - val_mean_absolute_percentage_error: 5.2495
# Epoch 1493/1500
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0357 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0131 - mean_absolute_percentage_error: 9.8556 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.9169
# Epoch 1494/1500
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0070 - mean_absolute_percentage_error: 5.4472 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.9114
# Epoch 1495/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0349 - mean_absolute_error: 0.0349 - mean_squared_error: 0.0082 - mean_absolute_percentage_error: 11.6368 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 6.0179
# Epoch 1496/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0325 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 4.8370 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 5.4375
# Epoch 1497/1500
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0321 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0059 - mean_absolute_percentage_error: 8.4496 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 5.4775
# Epoch 1498/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0327 - mean_absolute_error: 0.0327 - mean_squared_error: 0.0076 - mean_absolute_percentage_error: 6.2292 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 5.2073
# Epoch 1499/1500
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0304 - mean_absolute_error: 0.0304 - mean_squared_error: 0.0056 - mean_absolute_percentage_error: 7.5678 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0094 - val_mean_absolute_percentage_error: 5.1496
# Epoch 1500/1500
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0205 - mean_absolute_percentage_error: 11.1392 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0087 - val_mean_absolute_percentage_error: 5.2184

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 20)             1140
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 1, 20)             1920
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 20)                1920
#  onal)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 5001 (19.54 KB)
# Trainable params: 5001 (19.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=1.5)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=1.5)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.9977615  -0.9947256  -0.9909304  -0.9875316  -0.9866618  -0.98188543
#  -0.9467837  -0.9772324  -0.635231   -0.52330524 -0.98722696 -0.99541867
#  -0.9978546  -0.99394006 -0.98830897 -0.9800036  -0.9832776  -0.9848353
#  -0.9572565  -0.9931583  -0.9945303  -0.9956905  -0.99638027 -0.9934076
#  -0.9936892  -0.99455    -0.98887235 -0.98041874 -0.98696005 -0.9778428
#  -0.99120885 -0.9922815  -0.9945124  -0.9949886  -0.994886   -0.99590534
#  -0.99716365 -0.99478143 -0.9926721  -0.9925685  -0.99037087 -0.9928897
#  -0.98343307 -0.9935004  -0.9935635  -0.99311477 -0.99445516 -0.99350166
#  -0.99637645 -0.99470127 -0.97760177 -0.97687143 -0.99084616 -0.9884149
#  -0.98922354 -0.9921125  -0.65440464 -0.9206469  -0.9931819 ]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0281 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0053 - mean_absolute_percentage_error: 6.2116
# [0.028142817318439484,
#  0.028142817318439484,
#  0.0053430222906172276,
#  6.2116193771362305]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0298 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0087 - mean_absolute_percentage_error: 5.2184
# [0.029835691675543785,
#  0.029835691675543785,
#  0.008732806891202927,
#  5.2184367179870605]

# %% [markdown]
# - MAE

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE: %.4f' % mae)
# Out:
# Test MAE: 0.0298

# %% [markdown]
# - MSE

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0087

# %% [markdown]
# - MAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions)
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 0.0522

# %% [markdown]
# - korelasi dan signifikansi

# %%
hasil = np.stack((testY,predictions.reshape(-1)),axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999307 -0.997761
# 1    -0.997922 -0.994726
# 2    -0.997506 -0.990930
# 3    -0.990024 -0.987532
# 4    -0.994319 -0.986662

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.6627 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi 
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:04:55.79

# %% [markdown]
# ### 8. Visualisasi Hasil Prediksi

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], testY, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], predictions, color="tab:red", label="hasil prediksi", linewidth=2.5)

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)
plt.show()
