# %% [markdown]
# ## Percobaan 2 - Model Prediksi Titik Panas di Sumatera Selatan 2001 - 2023

# %% [markdown]
# - Jika dipengaruhi oleh enso

# %%
# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

import random as rm
import time as tm

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# Setting seed
rm.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# Setting Algorithm
algorithm = "LSTM-RNN"

# %%
# # Setting Algorithm
# algorithm = "GRU-RNN"

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
dataset = pd.read_csv("dataset/dataset_enso.csv", parse_dates=["acq_date"])

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
#  2   sst_std   276 non-null    float64
#  3   sst_anom  276 non-null    float64
#  4   oni_std   276 non-null    float64
#  5   oni_anom  276 non-null    float64
#  6   soi_std   276 non-null    float64
#  7   soi_anom  276 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
print(dataset.head())
# Out:
#     acq_date  hotspot  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom
# 0 2001-01-31        3    25.81     -0.76    25.88     -0.68      1.0       1.6
# 1 2001-02-28        5    26.18     -0.56    26.26     -0.52      1.7       2.8
# 2 2001-03-31       10    26.86     -0.37    26.76     -0.44      0.9       1.5
# 3 2001-04-30       20    27.24     -0.56    27.25     -0.34      0.2       0.3
# 4 2001-05-31       39    27.42     -0.46    27.49     -0.25     -0.5      -0.8

# %% [markdown]
# ### 2. Praproses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# jika hotspot dipengaruhi oleh enso
data = dataset[["hotspot", "sst_std", "sst_anom", "oni_std", "oni_anom", "soi_std", "soi_anom"]]
data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3.  , 25.81, -0.76, 25.88, -0.68,  1.  ,  1.6 ],
#        [ 5.  , 26.18, -0.56, 26.26, -0.52,  1.7 ,  2.8 ],
#        [10.  , 26.86, -0.37, 26.76, -0.44,  0.9 ,  1.5 ],
#        [20.  , 27.24, -0.56, 27.25, -0.34,  0.2 ,  0.3 ],
#        [39.  , 27.42, -0.46, 27.49, -0.25, -0.5 , -0.8 ]])

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 7)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 7)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled[:,:1]), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],4)
# Out:
# array([[-1.    , -0.6324, -0.6148, -0.5869, -0.5514,  0.3667,  0.36  ],
#        [-0.9997, -0.4705, -0.522 , -0.4085, -0.4766,  0.6   ,  0.6   ],
#        [-0.999 , -0.1729, -0.4339, -0.1737, -0.4393,  0.3333,  0.34  ],
#        [-0.9976, -0.0066, -0.522 ,  0.0563, -0.3925,  0.1   ,  0.1   ],
#        [-0.995 ,  0.0722, -0.4756,  0.169 , -0.3505, -0.1333, -0.12  ]])

# %%
train_data.shape
# Out:
# (216, 7)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],4)
# Out:
# array([[-0.999 , -0.0066,  0.0487,  0.1221,  0.1168,  0.0333,  0.02  ],
#        [-0.9993,  0.081 ,  0.0673,  0.216 ,  0.1028, -0.4333, -0.42  ],
#        [-0.9979,  0.4179,  0.1879,  0.4131,  0.0981, -0.0667, -0.06  ],
#        [-0.9975,  0.558 ,  0.0719,  0.5681,  0.0748,  0.0667,  0.08  ],
#        [-0.99  ,  0.6018,  0.0858,  0.5822,  0.0187, -0.1   , -0.1   ]])

# %%
test_data.shape
# Out:
# (60, 7)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data[:,:1], color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data[:,:1], color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    
    # return value
    return agg

# %% [markdown]
# - hasil supervised learning data train

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train_data, 1, 1)

# %%
# drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_train.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (215, 7) (215,)

# %% [markdown]
# - hasil supervised learning data test

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test_data, 1, 1)

# %%
# drop columns we don't want to predict
reframed_test.drop(reframed_test.columns[[8,9,10,11,12,13]], axis=1, inplace=True)

# %%
reframed_test.head(5)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (59, 7) (59,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  215 non-null    float64
#  1   var2(t-1)  215 non-null    float64
#  2   var3(t-1)  215 non-null    float64
#  3   var4(t-1)  215 non-null    float64
#  4   var5(t-1)  215 non-null    float64
#  5   var6(t-1)  215 non-null    float64
#  6   var7(t-1)  215 non-null    float64
#  7   var1(t)    215 non-null    float64
# dtypes: float64(8)
# memory usage: 15.1 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -1.000000  -0.632385  -0.614849  -0.586854  -0.551402   0.366667
# 2  -0.999723  -0.470460  -0.522042  -0.408451  -0.476636   0.600000
# 3  -0.999030  -0.172867  -0.433875  -0.173709  -0.439252   0.333333
# 4  -0.997644  -0.006565  -0.522042   0.056338  -0.392523   0.100000
# 5  -0.995012   0.072210  -0.475638   0.169014  -0.350467  -0.133333
#
#    var7(t-1)   var1(t)
# 1       0.36 -0.999723
# 2       0.60 -0.999030
# 3       0.34 -0.997644
# 4       0.10 -0.995012
# 5      -0.12 -0.999307

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  59 non-null     float64
#  1   var2(t-1)  59 non-null     float64
#  2   var3(t-1)  59 non-null     float64
#  3   var4(t-1)  59 non-null     float64
#  4   var5(t-1)  59 non-null     float64
#  5   var6(t-1)  59 non-null     float64
#  6   var7(t-1)  59 non-null     float64
#  7   var1(t)    59 non-null     float64
# dtypes: float64(8)
# memory usage: 4.1 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1  -0.999030  -0.006565   0.048724   0.122066   0.116822   0.033333
# 2  -0.999307   0.080963   0.067285   0.215962   0.102804  -0.433333
# 3  -0.997922   0.417943   0.187935   0.413146   0.098131  -0.066667
# 4  -0.997506   0.557987   0.071926   0.568075   0.074766   0.066667
# 5  -0.990024   0.601751   0.085847   0.582160   0.018692  -0.100000
#
#    var7(t-1)   var1(t)
# 1       0.02 -0.999307
# 2      -0.42 -0.997922
# 3      -0.06 -0.997506
# 4       0.08 -0.990024
# 5      -0.10 -0.994319

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (215, 1, 7) (215,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (59, 1, 7) (59,)

# %% [markdown]
# ### 5. Model Prediksi Titik Panas

# %%
# call function
from class_base_model import lstm_algorithm
from class_base_model import gru_algorithm

# set parameter
activation = "relu"
dropout_rate = 0.1
optimizer = "rmsprop"

# check algorithm
if algorithm == "algorithm":
    # call model LSTM-RNN
    model = lstm_algorithm(trainX, activation, dropout_rate, optimizer)
else:
    # call model GRU-RNN
    model = gru_algorithm(trainX, activation, dropout_rate, optimizer)

# %%
# fit network
history = model.fit(
    trainX, trainY, batch_size=16, epochs=1500,
    validation_data=(testX, testY), verbose=1, shuffle=False, use_multiprocessing=True
)
# Out:
# Epoch 1/1500
# 14/14 [==============================] - 15s 123ms/step - loss: 0.8652 - mean_absolute_error: 0.8652 - mean_squared_error: 0.7731 - mean_absolute_percentage_error: 93.3639 - val_loss: 0.8187 - val_mean_absolute_error: 0.8187 - val_mean_squared_error: 0.6838 - val_mean_absolute_percentage_error: 85.3390
# Epoch 2/1500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.7438 - mean_absolute_error: 0.7438 - mean_squared_error: 0.5766 - mean_absolute_percentage_error: 80.7337 - val_loss: 0.6611 - val_mean_absolute_error: 0.6611 - val_mean_squared_error: 0.4492 - val_mean_absolute_percentage_error: 68.6744
# Epoch 3/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5544 - mean_absolute_error: 0.5544 - mean_squared_error: 0.3361 - mean_absolute_percentage_error: 61.6476 - val_loss: 0.4088 - val_mean_absolute_error: 0.4088 - val_mean_squared_error: 0.1829 - val_mean_absolute_percentage_error: 42.3785
# Epoch 4/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3389 - mean_absolute_error: 0.3389 - mean_squared_error: 0.1567 - mean_absolute_percentage_error: 41.1471 - val_loss: 0.1710 - val_mean_absolute_error: 0.1710 - val_mean_squared_error: 0.0463 - val_mean_absolute_percentage_error: 18.3313
# Epoch 5/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2102 - mean_absolute_error: 0.2102 - mean_squared_error: 0.0801 - mean_absolute_percentage_error: 28.7737 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355 - val_mean_squared_error: 0.0254 - val_mean_absolute_percentage_error: 15.0708
# Epoch 6/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1784 - mean_absolute_error: 0.1784 - mean_squared_error: 0.0699 - mean_absolute_percentage_error: 27.9547 - val_loss: 0.1018 - val_mean_absolute_error: 0.1018 - val_mean_squared_error: 0.0162 - val_mean_absolute_percentage_error: 12.0565
# Epoch 7/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1553 - mean_absolute_error: 0.1553 - mean_squared_error: 0.0600 - mean_absolute_percentage_error: 25.4276 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 9.1229
# Epoch 8/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - mean_squared_error: 0.0642 - mean_absolute_percentage_error: 25.4924 - val_loss: 0.0622 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0092 - val_mean_absolute_percentage_error: 8.2082
# Epoch 9/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 23.8719 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962 - val_mean_squared_error: 0.0128 - val_mean_absolute_percentage_error: 11.5060
# Epoch 10/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0567 - mean_absolute_percentage_error: 23.5198 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 9.0670
# Epoch 11/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1393 - mean_absolute_error: 0.1393 - mean_squared_error: 0.0616 - mean_absolute_percentage_error: 24.4768 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0091 - val_mean_absolute_percentage_error: 7.7289
# Epoch 12/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 23.3094 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0131 - val_mean_absolute_percentage_error: 11.6345
# Epoch 13/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0580 - mean_absolute_percentage_error: 24.7068 - val_loss: 0.0818 - val_mean_absolute_error: 0.0818 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 10.3385
# Epoch 14/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1434 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0635 - mean_absolute_percentage_error: 25.0892 - val_loss: 0.0862 - val_mean_absolute_error: 0.0862 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 10.7131
# Epoch 15/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1426 - mean_absolute_error: 0.1426 - mean_squared_error: 0.0611 - mean_absolute_percentage_error: 24.4673 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 9.1502
# Epoch 16/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - mean_squared_error: 0.0587 - mean_absolute_percentage_error: 24.4827 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.4659
# Epoch 17/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1245 - mean_absolute_error: 0.1245 - mean_squared_error: 0.0547 - mean_absolute_percentage_error: 23.7736 - val_loss: 0.0913 - val_mean_absolute_error: 0.0913 - val_mean_squared_error: 0.0125 - val_mean_absolute_percentage_error: 11.2819
# Epoch 18/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1420 - mean_absolute_error: 0.1420 - mean_squared_error: 0.0629 - mean_absolute_percentage_error: 25.3692 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.9792
# Epoch 19/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1420 - mean_absolute_error: 0.1420 - mean_squared_error: 0.0598 - mean_absolute_percentage_error: 24.9712 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909 - val_mean_squared_error: 0.0124 - val_mean_absolute_percentage_error: 11.2180
# Epoch 20/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0578 - mean_absolute_percentage_error: 24.0318 - val_loss: 0.0748 - val_mean_absolute_error: 0.0748 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.7258
# Epoch 21/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1434 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0626 - mean_absolute_percentage_error: 25.2601 - val_loss: 0.1016 - val_mean_absolute_error: 0.1016 - val_mean_squared_error: 0.0141 - val_mean_absolute_percentage_error: 12.2978
# Epoch 22/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1350 - mean_absolute_error: 0.1350 - mean_squared_error: 0.0563 - mean_absolute_percentage_error: 24.2760 - val_loss: 0.0436 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 6.7706
# Epoch 23/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 23.0961 - val_loss: 0.1040 - val_mean_absolute_error: 0.1040 - val_mean_squared_error: 0.0142 - val_mean_absolute_percentage_error: 12.3960
# Epoch 24/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1228 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0526 - mean_absolute_percentage_error: 22.9048 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.7915
# Epoch 25/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 22.5961 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962 - val_mean_squared_error: 0.0130 - val_mean_absolute_percentage_error: 11.7251
# Epoch 26/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0569 - mean_absolute_percentage_error: 23.9843 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 7.8709
# Epoch 27/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1336 - mean_absolute_error: 0.1336 - mean_squared_error: 0.0575 - mean_absolute_percentage_error: 24.4226 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 7.3024
# Epoch 28/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1336 - mean_absolute_error: 0.1336 - mean_squared_error: 0.0585 - mean_absolute_percentage_error: 24.7732 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - val_mean_squared_error: 0.0095 - val_mean_absolute_percentage_error: 7.3162
# Epoch 29/1500
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1350 - mean_absolute_error: 0.1350 - mean_squared_error: 0.0571 - mean_absolute_percentage_error: 25.3372 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 9.4551
# Epoch 30/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - mean_squared_error: 0.0560 - mean_absolute_percentage_error: 24.0159 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 9.0830
# Epoch 31/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 24.1720 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 9.2972
# Epoch 32/1500
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0589 - mean_absolute_percentage_error: 25.2564 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 6.6188
# Epoch 33/1500
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1240 - mean_absolute_error: 0.1240 - mean_squared_error: 0.0579 - mean_absolute_percentage_error: 24.0687 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 6.8629
# Epoch 34/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1317 - mean_absolute_error: 0.1317 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 24.4840 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.4384
# Epoch 35/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1249 - mean_absolute_error: 0.1249 - mean_squared_error: 0.0528 - mean_absolute_percentage_error: 22.8814 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 8.0468
# Epoch 36/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1213 - mean_absolute_error: 0.1213 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 23.6592 - val_loss: 0.0656 - val_mean_absolute_error: 0.0656 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.8572
# Epoch 37/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1218 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 23.2292 - val_loss: 0.1097 - val_mean_absolute_error: 0.1097 - val_mean_squared_error: 0.0156 - val_mean_absolute_percentage_error: 13.1179
# Epoch 38/1500
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1413 - mean_absolute_error: 0.1413 - mean_squared_error: 0.0626 - mean_absolute_percentage_error: 25.9585 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.7831
# Epoch 39/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1172 - mean_absolute_error: 0.1172 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 22.2814 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.9397
# Epoch 40/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0580 - mean_absolute_percentage_error: 23.7050 - val_loss: 0.1074 - val_mean_absolute_error: 0.1074 - val_mean_squared_error: 0.0150 - val_mean_absolute_percentage_error: 12.8517
# Epoch 41/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0559 - mean_absolute_percentage_error: 23.7187 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 8.0395
# Epoch 42/1500
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1199 - mean_absolute_error: 0.1199 - mean_squared_error: 0.0520 - mean_absolute_percentage_error: 22.1447 - val_loss: 0.0843 - val_mean_absolute_error: 0.0843 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 10.6118
# Epoch 43/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0480 - mean_absolute_percentage_error: 21.3507 - val_loss: 0.0437 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 7.0003
# Epoch 44/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1173 - mean_absolute_error: 0.1173 - mean_squared_error: 0.0547 - mean_absolute_percentage_error: 22.8313 - val_loss: 0.0837 - val_mean_absolute_error: 0.0837 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.6608
# Epoch 45/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0606 - mean_absolute_percentage_error: 25.8198 - val_loss: 0.0808 - val_mean_absolute_error: 0.0808 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 10.3405
# Epoch 46/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1291 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0579 - mean_absolute_percentage_error: 24.1506 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 11.7126
# Epoch 47/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1285 - mean_absolute_error: 0.1285 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 23.7020 - val_loss: 0.0737 - val_mean_absolute_error: 0.0737 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 9.6813
# Epoch 48/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1326 - mean_absolute_error: 0.1326 - mean_squared_error: 0.0573 - mean_absolute_percentage_error: 24.9654 - val_loss: 0.0785 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0114 - val_mean_absolute_percentage_error: 10.1587
# Epoch 49/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1211 - mean_absolute_error: 0.1211 - mean_squared_error: 0.0530 - mean_absolute_percentage_error: 22.9848 - val_loss: 0.0403 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 6.6323
# Epoch 50/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - mean_squared_error: 0.0508 - mean_absolute_percentage_error: 22.7508 - val_loss: 0.0977 - val_mean_absolute_error: 0.0977 - val_mean_squared_error: 0.0136 - val_mean_absolute_percentage_error: 11.9890
# Epoch 51/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0529 - mean_absolute_percentage_error: 23.2565 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 6.5490
# Epoch 52/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1214 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0546 - mean_absolute_percentage_error: 23.1524 - val_loss: 0.0848 - val_mean_absolute_error: 0.0848 - val_mean_squared_error: 0.0119 - val_mean_absolute_percentage_error: 10.6996
# Epoch 53/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1333 - mean_absolute_error: 0.1333 - mean_squared_error: 0.0539 - mean_absolute_percentage_error: 24.0571 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.0199
# Epoch 54/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1245 - mean_absolute_error: 0.1245 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 23.2985 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 6.9129
# Epoch 55/1500
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1182 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0502 - mean_absolute_percentage_error: 22.4174 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.5186
# Epoch 56/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1215 - mean_absolute_error: 0.1215 - mean_squared_error: 0.0536 - mean_absolute_percentage_error: 23.2879 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 8.8871
# Epoch 57/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - mean_squared_error: 0.0551 - mean_absolute_percentage_error: 24.1536 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.0404
# Epoch 58/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 22.5518 - val_loss: 0.1023 - val_mean_absolute_error: 0.1023 - val_mean_squared_error: 0.0143 - val_mean_absolute_percentage_error: 12.4256
# Epoch 59/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1222 - mean_absolute_error: 0.1222 - mean_squared_error: 0.0523 - mean_absolute_percentage_error: 23.4934 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001 - val_mean_squared_error: 0.0141 - val_mean_absolute_percentage_error: 12.2241
# Epoch 60/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1300 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0560 - mean_absolute_percentage_error: 23.6161 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.1129
# Epoch 61/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1187 - mean_absolute_error: 0.1187 - mean_squared_error: 0.0519 - mean_absolute_percentage_error: 22.7249 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 8.2125
# Epoch 62/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1216 - mean_absolute_error: 0.1216 - mean_squared_error: 0.0570 - mean_absolute_percentage_error: 24.1657 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.5286
# Epoch 63/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1227 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0531 - mean_absolute_percentage_error: 23.3128 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.6316
# Epoch 64/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0523 - mean_absolute_percentage_error: 23.4625 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.4651
# Epoch 65/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1219 - mean_absolute_error: 0.1219 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 24.1868 - val_loss: 0.0866 - val_mean_absolute_error: 0.0866 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.9000
# Epoch 66/1500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0576 - mean_absolute_percentage_error: 24.2619 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 7.8570
# Epoch 67/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1253 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 24.4107 - val_loss: 0.0771 - val_mean_absolute_error: 0.0771 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 10.0458
# Epoch 68/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0510 - mean_absolute_percentage_error: 23.2267 - val_loss: 0.0443 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 6.9194
# Epoch 69/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1258 - mean_absolute_error: 0.1258 - mean_squared_error: 0.0543 - mean_absolute_percentage_error: 23.8504 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.5536
# Epoch 70/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1261 - mean_absolute_error: 0.1261 - mean_squared_error: 0.0554 - mean_absolute_percentage_error: 24.3338 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 7.4377
# Epoch 71/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1188 - mean_absolute_error: 0.1188 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 23.0013 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.4633
# Epoch 72/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 23.2250 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.2662
# Epoch 73/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1229 - mean_absolute_error: 0.1229 - mean_squared_error: 0.0553 - mean_absolute_percentage_error: 23.7822 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 9.4428
# Epoch 74/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1240 - mean_absolute_error: 0.1240 - mean_squared_error: 0.0553 - mean_absolute_percentage_error: 24.1532 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 6.6887
# Epoch 75/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1246 - mean_absolute_error: 0.1246 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 24.4512 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.4805
# Epoch 76/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1200 - mean_absolute_error: 0.1200 - mean_squared_error: 0.0536 - mean_absolute_percentage_error: 22.5597 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 6.5507
# Epoch 77/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1142 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0511 - mean_absolute_percentage_error: 23.0594 - val_loss: 0.0826 - val_mean_absolute_error: 0.0826 - val_mean_squared_error: 0.0118 - val_mean_absolute_percentage_error: 10.5810
# Epoch 78/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1242 - mean_absolute_error: 0.1242 - mean_squared_error: 0.0564 - mean_absolute_percentage_error: 24.0005 - val_loss: 0.1015 - val_mean_absolute_error: 0.1015 - val_mean_squared_error: 0.0140 - val_mean_absolute_percentage_error: 12.3176
# Epoch 79/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0531 - mean_absolute_percentage_error: 23.0709 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.1787
# Epoch 80/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1132 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0528 - mean_absolute_percentage_error: 22.7333 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.3460
# Epoch 81/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1133 - mean_absolute_error: 0.1133 - mean_squared_error: 0.0508 - mean_absolute_percentage_error: 23.2788 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924 - val_mean_squared_error: 0.0128 - val_mean_absolute_percentage_error: 11.4650
# Epoch 82/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0559 - mean_absolute_percentage_error: 24.1771 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923 - val_mean_squared_error: 0.0128 - val_mean_absolute_percentage_error: 11.4433
# Epoch 83/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1126 - mean_absolute_error: 0.1126 - mean_squared_error: 0.0552 - mean_absolute_percentage_error: 23.1370 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 10.5126
# Epoch 84/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1191 - mean_absolute_error: 0.1191 - mean_squared_error: 0.0558 - mean_absolute_percentage_error: 23.4169 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 6.5707
# Epoch 85/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0534 - mean_absolute_percentage_error: 23.5087 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 8.5929
# Epoch 86/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1180 - mean_absolute_error: 0.1180 - mean_squared_error: 0.0520 - mean_absolute_percentage_error: 22.8347 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - val_mean_squared_error: 0.0096 - val_mean_absolute_percentage_error: 7.2998
# Epoch 87/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1142 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 23.5820 - val_loss: 0.0435 - val_mean_absolute_error: 0.0435 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.9290
# Epoch 88/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1114 - mean_absolute_error: 0.1114 - mean_squared_error: 0.0529 - mean_absolute_percentage_error: 22.7067 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 6.7568
# Epoch 89/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 23.6895 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.6731
# Epoch 90/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1207 - mean_absolute_error: 0.1207 - mean_squared_error: 0.0573 - mean_absolute_percentage_error: 24.4673 - val_loss: 0.0388 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.5561
# Epoch 91/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1160 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0528 - mean_absolute_percentage_error: 23.8941 - val_loss: 0.0688 - val_mean_absolute_error: 0.0688 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 9.3164
# Epoch 92/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1129 - mean_absolute_error: 0.1129 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 23.0823 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 7.3329
# Epoch 93/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1109 - mean_absolute_error: 0.1109 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 23.0045 - val_loss: 0.1020 - val_mean_absolute_error: 0.1020 - val_mean_squared_error: 0.0143 - val_mean_absolute_percentage_error: 12.4304
# Epoch 94/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1182 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 23.3961 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.2077
# Epoch 95/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1210 - mean_absolute_error: 0.1210 - mean_squared_error: 0.0562 - mean_absolute_percentage_error: 23.7369 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.7814
# Epoch 96/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1207 - mean_absolute_error: 0.1207 - mean_squared_error: 0.0574 - mean_absolute_percentage_error: 23.7200 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.0435
# Epoch 97/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1120 - mean_absolute_error: 0.1120 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 23.3760 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.0911
# Epoch 98/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1096 - mean_absolute_error: 0.1096 - mean_squared_error: 0.0539 - mean_absolute_percentage_error: 22.7522 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 9.3114
# Epoch 99/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 23.6389 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 11.7160
# Epoch 100/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1140 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0550 - mean_absolute_percentage_error: 22.9005 - val_loss: 0.0819 - val_mean_absolute_error: 0.0819 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 10.5252
# Epoch 101/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1227 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 24.3580 - val_loss: 0.0459 - val_mean_absolute_error: 0.0459 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 7.1155
# Epoch 102/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1075 - mean_absolute_error: 0.1075 - mean_squared_error: 0.0534 - mean_absolute_percentage_error: 22.6539 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.4403
# Epoch 103/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1173 - mean_absolute_error: 0.1173 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 23.6852 - val_loss: 0.0668 - val_mean_absolute_error: 0.0668 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 9.1395
# Epoch 104/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1103 - mean_absolute_error: 0.1103 - mean_squared_error: 0.0538 - mean_absolute_percentage_error: 22.8062 - val_loss: 0.0844 - val_mean_absolute_error: 0.0844 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.7539
# Epoch 105/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1145 - mean_absolute_error: 0.1145 - mean_squared_error: 0.0564 - mean_absolute_percentage_error: 23.7487 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740 - val_mean_squared_error: 0.0113 - val_mean_absolute_percentage_error: 9.8318
# Epoch 106/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1056 - mean_absolute_error: 0.1056 - mean_squared_error: 0.0526 - mean_absolute_percentage_error: 22.6876 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 8.0292
# Epoch 107/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1028 - mean_absolute_error: 0.1028 - mean_squared_error: 0.0507 - mean_absolute_percentage_error: 21.0491 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 7.6615
# Epoch 108/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 23.5072 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.0044
# Epoch 109/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1103 - mean_absolute_error: 0.1103 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 22.7498 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0117 - val_mean_absolute_percentage_error: 7.8185
# Epoch 110/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1079 - mean_absolute_error: 0.1079 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 22.5111 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.2239
# Epoch 111/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1085 - mean_absolute_error: 0.1085 - mean_squared_error: 0.0529 - mean_absolute_percentage_error: 23.2555 - val_loss: 0.0670 - val_mean_absolute_error: 0.0670 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 9.1218
# Epoch 112/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1128 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 23.5400 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939 - val_mean_squared_error: 0.0132 - val_mean_absolute_percentage_error: 11.6812
# Epoch 113/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1047 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0506 - mean_absolute_percentage_error: 21.2593 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.1983
# Epoch 114/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1074 - mean_absolute_error: 0.1074 - mean_squared_error: 0.0542 - mean_absolute_percentage_error: 22.8816 - val_loss: 0.0462 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.1987
# Epoch 115/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1082 - mean_absolute_error: 0.1082 - mean_squared_error: 0.0542 - mean_absolute_percentage_error: 23.0062 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 7.6176
# Epoch 116/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1073 - mean_absolute_error: 0.1073 - mean_squared_error: 0.0523 - mean_absolute_percentage_error: 22.6839 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.6690
# Epoch 117/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1115 - mean_absolute_error: 0.1115 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 22.3591 - val_loss: 0.0626 - val_mean_absolute_error: 0.0626 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.7214
# Epoch 118/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1065 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0519 - mean_absolute_percentage_error: 22.0145 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 6.8215
# Epoch 119/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1081 - mean_absolute_error: 0.1081 - mean_squared_error: 0.0532 - mean_absolute_percentage_error: 22.7587 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 8.4414
# Epoch 120/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1094 - mean_absolute_error: 0.1094 - mean_squared_error: 0.0524 - mean_absolute_percentage_error: 23.0236 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.7529
# Epoch 121/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1049 - mean_absolute_error: 0.1049 - mean_squared_error: 0.0524 - mean_absolute_percentage_error: 22.6321 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.3137
# Epoch 122/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1079 - mean_absolute_error: 0.1079 - mean_squared_error: 0.0535 - mean_absolute_percentage_error: 22.9505 - val_loss: 0.0786 - val_mean_absolute_error: 0.0786 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 10.2343
# Epoch 123/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1143 - mean_absolute_error: 0.1143 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 23.4038 - val_loss: 0.0645 - val_mean_absolute_error: 0.0645 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 8.8711
# Epoch 124/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1107 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 22.8574 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 7.2438
# Epoch 125/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1120 - mean_absolute_error: 0.1120 - mean_squared_error: 0.0559 - mean_absolute_percentage_error: 23.5381 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 6.7107
# Epoch 126/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1000 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0509 - mean_absolute_percentage_error: 21.5569 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - val_mean_squared_error: 0.0098 - val_mean_absolute_percentage_error: 7.5743
# Epoch 127/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1073 - mean_absolute_error: 0.1073 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 22.8233 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.4915
# Epoch 128/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1068 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 22.3215 - val_loss: 0.0765 - val_mean_absolute_error: 0.0765 - val_mean_squared_error: 0.0111 - val_mean_absolute_percentage_error: 9.9790
# Epoch 129/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1047 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0507 - mean_absolute_percentage_error: 22.0087 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.5372
# Epoch 130/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1061 - mean_absolute_error: 0.1061 - mean_squared_error: 0.0527 - mean_absolute_percentage_error: 21.9138 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.0741
# Epoch 131/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1118 - mean_absolute_error: 0.1118 - mean_squared_error: 0.0552 - mean_absolute_percentage_error: 23.0679 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.5776
# Epoch 132/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1065 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0533 - mean_absolute_percentage_error: 22.8320 - val_loss: 0.0437 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 7.0421
# Epoch 133/1500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1095 - mean_absolute_error: 0.1095 - mean_squared_error: 0.0543 - mean_absolute_percentage_error: 22.8354 - val_loss: 0.0420 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 6.7872
# Epoch 134/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1071 - mean_absolute_error: 0.1071 - mean_squared_error: 0.0521 - mean_absolute_percentage_error: 22.3622 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.6679
# Epoch 135/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1098 - mean_absolute_error: 0.1098 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 23.1772 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 8.5988
# Epoch 136/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1095 - mean_absolute_error: 0.1095 - mean_squared_error: 0.0534 - mean_absolute_percentage_error: 22.5595 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 8.0513
# Epoch 137/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1041 - mean_absolute_error: 0.1041 - mean_squared_error: 0.0522 - mean_absolute_percentage_error: 22.3850 - val_loss: 0.0440 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0097 - val_mean_absolute_percentage_error: 6.9210
# Epoch 138/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1044 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0523 - mean_absolute_percentage_error: 22.4998 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.2805
# Epoch 139/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1017 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0515 - mean_absolute_percentage_error: 21.8127 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.9739
# Epoch 140/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1064 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0512 - mean_absolute_percentage_error: 21.9521 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.8044
# Epoch 141/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1019 - mean_absolute_error: 0.1019 - mean_squared_error: 0.0536 - mean_absolute_percentage_error: 22.2183 - val_loss: 0.0449 - val_mean_absolute_error: 0.0449 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 7.0891
# Epoch 142/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1058 - mean_absolute_error: 0.1058 - mean_squared_error: 0.0518 - mean_absolute_percentage_error: 22.8662 - val_loss: 0.0611 - val_mean_absolute_error: 0.0611 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.5853
# Epoch 143/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1012 - mean_absolute_error: 0.1012 - mean_squared_error: 0.0500 - mean_absolute_percentage_error: 21.8026 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 7.1591
# Epoch 144/1500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1059 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 22.9330 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 7.5344
# Epoch 145/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 22.7451 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832 - val_mean_squared_error: 0.0120 - val_mean_absolute_percentage_error: 10.6392
# Epoch 146/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1076 - mean_absolute_error: 0.1076 - mean_squared_error: 0.0525 - mean_absolute_percentage_error: 22.7829 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 7.3022
# Epoch 147/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0997 - mean_absolute_error: 0.0997 - mean_squared_error: 0.0515 - mean_absolute_percentage_error: 21.9873 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 8.4393
# Epoch 148/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - mean_squared_error: 0.0517 - mean_absolute_percentage_error: 21.7202 - val_loss: 0.0433 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 7.0293
# Epoch 149/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1023 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0544 - mean_absolute_percentage_error: 22.5698 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.7005
# Epoch 150/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1058 - mean_absolute_error: 0.1058 - mean_squared_error: 0.0525 - mean_absolute_percentage_error: 22.6414 - val_loss: 0.0448 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0116 - val_mean_absolute_percentage_error: 7.2880
# Epoch 151/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - mean_squared_error: 0.0539 - mean_absolute_percentage_error: 21.9085 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.7449
# Epoch 152/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1027 - mean_absolute_error: 0.1027 - mean_squared_error: 0.0536 - mean_absolute_percentage_error: 22.7282 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 6.6888
# Epoch 153/1500
# ...
# Epoch 1451/1500
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0296 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0056 - mean_absolute_percentage_error: 9.1358 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 4.9675
# Epoch 1452/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0258 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0033 - mean_absolute_percentage_error: 4.5620 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 5.5284
# Epoch 1453/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0281 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0091 - mean_absolute_percentage_error: 4.7646 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 5.3735
# Epoch 1454/1500
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0260 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0040 - mean_absolute_percentage_error: 4.6998 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 5.1590
# Epoch 1455/1500
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 8.3856 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 5.0550
# Epoch 1456/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0264 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0055 - mean_absolute_percentage_error: 4.3128 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.1016
# Epoch 1457/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0054 - mean_absolute_percentage_error: 4.5333 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0166
# Epoch 1458/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0283 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0047 - mean_absolute_percentage_error: 7.3790 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.1990
# Epoch 1459/1500
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - mean_squared_error: 0.0035 - mean_absolute_percentage_error: 4.0863 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.2450
# Epoch 1460/1500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - mean_squared_error: 0.0028 - mean_absolute_percentage_error: 4.6625 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.1073
# Epoch 1461/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0029 - mean_absolute_percentage_error: 4.0202 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 4.9148
# Epoch 1462/1500
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0273 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0080 - mean_absolute_percentage_error: 11.8849 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 4.9917
# Epoch 1463/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0268 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0046 - mean_absolute_percentage_error: 3.9834 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 5.3354
# Epoch 1464/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0288 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0109 - mean_absolute_percentage_error: 5.7480 - val_loss: 0.0304 - val_mean_absolute_error: 0.0304 - val_mean_squared_error: 0.0109 - val_mean_absolute_percentage_error: 5.5864
# Epoch 1465/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0272 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0042 - mean_absolute_percentage_error: 5.5879 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.3966
# Epoch 1466/1500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0285 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0083 - mean_absolute_percentage_error: 9.7022 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.1650
# Epoch 1467/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - mean_squared_error: 0.0041 - mean_absolute_percentage_error: 7.6289 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.0996
# Epoch 1468/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0265 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0041 - mean_absolute_percentage_error: 5.6819 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.4533
# Epoch 1469/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0271 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0056 - mean_absolute_percentage_error: 6.3328 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.2444
# Epoch 1470/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0247 - mean_absolute_error: 0.0247 - mean_squared_error: 0.0030 - mean_absolute_percentage_error: 3.9506 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0168
# Epoch 1471/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0235 - mean_absolute_error: 0.0235 - mean_squared_error: 0.0038 - mean_absolute_percentage_error: 4.3577 - val_loss: 0.0305 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.4480
# Epoch 1472/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0218 - mean_absolute_error: 0.0218 - mean_squared_error: 0.0022 - mean_absolute_percentage_error: 3.9186 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.3941
# Epoch 1473/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - mean_squared_error: 0.0026 - mean_absolute_percentage_error: 4.3288 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.4126
# Epoch 1474/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0324 - mean_absolute_error: 0.0324 - mean_squared_error: 0.0086 - mean_absolute_percentage_error: 8.6558 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0103 - val_mean_absolute_percentage_error: 5.1366
# Epoch 1475/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0254 - mean_absolute_error: 0.0254 - mean_squared_error: 0.0048 - mean_absolute_percentage_error: 5.7432 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.4222
# Epoch 1476/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0250 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0036 - mean_absolute_percentage_error: 4.2199 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.4675
# Epoch 1477/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0298 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 4.9695 - val_loss: 0.0265 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 4.8716
# Epoch 1478/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0269 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0039 - mean_absolute_percentage_error: 5.0294 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.0093
# Epoch 1479/1500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0259 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0066 - mean_absolute_percentage_error: 3.9373 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.4203
# Epoch 1480/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0230 - mean_absolute_error: 0.0230 - mean_squared_error: 0.0035 - mean_absolute_percentage_error: 4.0203 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.5023
# Epoch 1481/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0044 - mean_absolute_percentage_error: 4.6955 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.4780
# Epoch 1482/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - mean_squared_error: 0.0021 - mean_absolute_percentage_error: 3.4364 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.4576
# Epoch 1483/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0230 - mean_squared_error: 0.0035 - mean_absolute_percentage_error: 4.2018 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0102 - val_mean_absolute_percentage_error: 5.2379
# Epoch 1484/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0259 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0032 - mean_absolute_percentage_error: 4.0063 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0467
# Epoch 1485/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0251 - mean_absolute_error: 0.0251 - mean_squared_error: 0.0048 - mean_absolute_percentage_error: 7.9302 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.7250
# Epoch 1486/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_absolute_error: 0.0229 - mean_squared_error: 0.0028 - mean_absolute_percentage_error: 5.1104 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0573
# Epoch 1487/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - mean_squared_error: 0.0030 - mean_absolute_percentage_error: 4.0512 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0100 - val_mean_absolute_percentage_error: 5.0707
# Epoch 1488/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0271 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0052 - mean_absolute_percentage_error: 4.9234 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.1837
# Epoch 1489/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0269 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0039 - mean_absolute_percentage_error: 4.8218 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 5.1911
# Epoch 1490/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - mean_squared_error: 0.0019 - mean_absolute_percentage_error: 3.2137 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 4.9919
# Epoch 1491/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0247 - mean_absolute_error: 0.0247 - mean_squared_error: 0.0064 - mean_absolute_percentage_error: 3.3172 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0712
# Epoch 1492/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - mean_squared_error: 0.0026 - mean_absolute_percentage_error: 3.4159 - val_loss: 0.0292 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0106 - val_mean_absolute_percentage_error: 5.3573
# Epoch 1493/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0234 - mean_absolute_error: 0.0234 - mean_squared_error: 0.0030 - mean_absolute_percentage_error: 3.7089 - val_loss: 0.0282 - val_mean_absolute_error: 0.0282 - val_mean_squared_error: 0.0099 - val_mean_absolute_percentage_error: 5.0110
# Epoch 1494/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0283 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0068 - mean_absolute_percentage_error: 5.2649 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0101 - val_mean_absolute_percentage_error: 5.1295
# Epoch 1495/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0298 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0048 - mean_absolute_percentage_error: 5.7474 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.2891
# Epoch 1496/1500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0250 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0049 - mean_absolute_percentage_error: 5.4524 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0107 - val_mean_absolute_percentage_error: 5.5279
# Epoch 1497/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0282 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0062 - mean_absolute_percentage_error: 4.4183 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0105 - val_mean_absolute_percentage_error: 5.2941
# Epoch 1498/1500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0307 - mean_absolute_error: 0.0307 - mean_squared_error: 0.0077 - mean_absolute_percentage_error: 5.9777 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0380
# Epoch 1499/1500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0302 - mean_absolute_error: 0.0302 - mean_squared_error: 0.0068 - mean_absolute_percentage_error: 5.9455 - val_loss: 0.0283 - val_mean_absolute_error: 0.0283 - val_mean_squared_error: 0.0104 - val_mean_absolute_percentage_error: 5.0756
# Epoch 1500/1500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0218 - mean_absolute_error: 0.0218 - mean_squared_error: 0.0026 - mean_absolute_percentage_error: 4.5488 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0108 - val_mean_absolute_percentage_error: 5.5280

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 20)             1140
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 1, 20)             1920
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 20)                1920
#  onal)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 5001 (19.54 KB)
# Trainable params: 5001 (19.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=1.5)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=1.5)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.99869037 -0.9933947  -0.99078166 -0.956008   -0.9886201  -0.979476
#  -0.812855   -0.9875809  -0.4007349  -0.7232964  -0.98689294 -0.9953296
#  -0.998948   -0.9966839  -0.90595615 -0.98665303 -0.987847   -0.9876099
#  -0.98907906 -0.99559194 -0.9972188  -0.99899226 -0.9987131  -0.9955413
#  -0.9959479  -0.99614835 -0.99099314 -0.9880386  -0.98737735 -0.9869334
#  -0.9929886  -0.9945565  -0.99725145 -0.9968716  -0.99670005 -0.99693686
#  -0.99907595 -0.99707097 -0.9956031  -0.99426675 -0.99369085 -0.9934992
#  -0.99168706 -0.9957525  -0.99533314 -0.995483   -0.997607   -0.99606633
#  -0.99876493 -0.9972743  -0.9894782  -0.98685354 -0.9957514  -0.987392
#  -0.99045855 -0.9946042  -0.98717815 -0.82926136 -0.9953528 ]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0210 - mean_absolute_error: 0.0210 - mean_squared_error: 0.0022 - mean_absolute_percentage_error: 3.9952
# [0.021013621240854263,
#  0.021013621240854263,
#  0.002208032412454486,
#  3.9952495098114014]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0320 - mean_absolute_error: 0.0320 - mean_squared_error: 0.0108 - mean_absolute_percentage_error: 5.5280
# [0.031965892761945724,
#  0.031965892761945724,
#  0.010823245160281658,
#  5.52797794342041]

# %% [markdown]
# - MAE

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE: %.4f' % mae)
# Out:
# Test MAE: 0.0320

# %% [markdown]
# - MSE

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0108

# %% [markdown]
# - MAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions)
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 0.0553

# %% [markdown]
# - korelasi dan signifikansi

# %%
hasil = np.stack((testY,predictions.reshape(-1)),axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999307 -0.998690
# 1    -0.997922 -0.993395
# 2    -0.997506 -0.990782
# 3    -0.990024 -0.956008
# 4    -0.994319 -0.988620

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.5712 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi 
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:04:04.92

# %% [markdown]
# ### 8. Visualisasi Hasil Prediksi

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testY, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(x, predictions, color="tab:red", label="hasil prediksi", linewidth=2.5)

# membuat label-label
# ax.set_title("Hotspot Sumsel Sensor MODIS 2018-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()
