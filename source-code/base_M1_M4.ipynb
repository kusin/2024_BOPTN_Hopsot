# %% [markdown]
# ## M1 dan M4 - Model Prediksi Titik Panas di Sumatera Selatan 2001-2023

# %%
# pustaka generate number
import random as rm
import time as tm

# pustaka manipulasi data array
import numpy as np

# pustaka manipulasi data frame
import pandas as pd

# pustaka untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# library algorithm lstm-rnn with keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# pustaka untuk  evaluasi model prediksi
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Config Models

# %%
# Setting seed
rm.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
# # Setting Algorithm
# algorithm = "LSTM-RNN"

# %%
# Setting Algorithm
algorithm = "GRU-RNN"

# %%
# set parameter
batch_size=4
epochs=1500
activation = "selu"
dropout_rate = 0.25
optimizer = "sgd"

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# Set waktu komputasi
start = tm.time()

# %%
# load dataset
dataset = pd.read_csv("dataset/dataset_hotspot.csv", parse_dates=["acq_date"])

# %%
# cek informasi dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   hotspot   276 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 4.4 KB

# %%
print(dataset)
# Out:
#       acq_date  hotspot
# 0   2001-01-31        3
# 1   2001-02-28        5
# 2   2001-03-31       10
# 3   2001-04-30       20
# 4   2001-05-31       39
# ..         ...      ...
# 271 2023-08-31      186
# 272 2023-09-30     2247
# 273 2023-10-31     3200
# 274 2023-11-30      390
# 275 2023-12-31       42
#
# [276 rows x 2 columns]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], dataset["hotspot"], color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 2. PraProses Data

# %% [markdown]
# - Seleksi Fitur

# %%
# hanya memperhatikan aspek hotspot
data = dataset.filter(["hotspot"])
data = data.values

# %%
# hasil seleksi fitur
np.round(data[:5],7)
# Out:
# array([[ 3],
#        [ 5],
#        [10],
#        [20],
#        [39]], dtype=int64)

# %%
# cek dimensi normalisasi
data.shape
# Out:
# (276, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(np.array(data))

# %%
# show data train
np.round(scaled[:5],7)
# Out:
# array([[0.       ],
#        [0.0001386],
#        [0.000485 ],
#        [0.0011778],
#        [0.0024941]])

# %%
# cek dimensi normalisasi
scaled.shape
# Out:
# (276, 1)

# %% [markdown]
# - Hasil PraProses Data

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["acq_date"], np.array(scaled), color="tab:blue", label="Hotspot di Sumatera Selatan 2001 - 2023", linewidth=2.5)

# membuat label-label
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="upper left")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 3. Pembagian Data

# %%
# Data latih th 2001 - 2018 = 216 baris
# Data uji th 2019 - 2023 = 60 baris

# %%
# # split data train and test
# train_data, test_data = train_test_split(scaled, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
train_size = 216

# set loc data train
train_data = scaled[0:train_size,:]

# show data train
np.round(train_data[:5],7)
# Out:
# array([[0.       ],
#        [0.0001386],
#        [0.000485 ],
#        [0.0011778],
#        [0.0024941]])

# %%
train_data.shape
# Out:
# (216, 1)

# %%
# data test
test_size = 60

# set loc data test
test_data = scaled[train_size:len(scaled),:]

# show data test
np.round(test_data[:5],7)
# Out:
# array([[0.000485 ],
#        [0.0003464],
#        [0.0010392],
#        [0.0012471],
#        [0.0049882]])

# %%
test_data.shape
# Out:
# (60, 1)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:len(train_data),0], train_data, color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data):len(dataset),0], test_data, color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 4. Supervised Learning

# %%
# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# set time series lag
look_back = 1

# %%
# Proses supervised learning
x_train, y_train = create_dataset(look_back, train_data)
print(x_train.shape, y_train.shape)
# Out:
# (215, 1) (215,)

# %%
# Proses supervised learning
x_test, y_test = create_dataset(look_back, test_data)
print(x_test.shape, y_test.shape)
# Out:
# (59, 1) (59,)

# %% [markdown]
# - hasil supervised learning

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
# cek dimensi data
print(x_train.shape, x_test.shape)
# Out:
# (215, 1, 1) (59, 1, 1)

# %% [markdown]
# ### 5. Model Prediksi Titik Panas

# %%
# call function
from class_base_model import lstm_algorithm
from class_base_model import gru_algorithm

# check algorithm
if algorithm == "algorithm":
    # call model LSTM-RNN
    model = lstm_algorithm(x_train, activation, dropout_rate, optimizer)
else:
    # call model GRU-RNN
    model = gru_algorithm(x_train, activation, dropout_rate, optimizer)

# fit network
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), verbose=1, shuffle=False, use_multiprocessing=False)
# Out:
# Epoch 1/1500
# 54/54 [==============================] - 11s 25ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0200 - mean_absolute_percentage_error: 10740.1357 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0043 - val_mean_absolute_percentage_error: 219128.5781
# Epoch 2/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0532 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0188 - mean_absolute_percentage_error: 61199.6992 - val_loss: 0.0249 - val_mean_absolute_error: 0.0249 - val_mean_squared_error: 0.0042 - val_mean_absolute_percentage_error: 157225.2656
# Epoch 3/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0522 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0178 - mean_absolute_percentage_error: 51599.3906 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0042 - val_mean_absolute_percentage_error: 126941.0234
# Epoch 4/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0520 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0188 - mean_absolute_percentage_error: 38250.5977 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0039 - val_mean_absolute_percentage_error: 269796.2188
# Epoch 5/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0171 - mean_absolute_percentage_error: 40770.2500 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 0.0039 - val_mean_absolute_percentage_error: 152461.3906
# Epoch 6/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0504 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0179 - mean_absolute_percentage_error: 19176.9375 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 0.0042 - val_mean_absolute_percentage_error: 10969.9873
# Epoch 7/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0501 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0171 - mean_absolute_percentage_error: 29469.5469 - val_loss: 0.0243 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0038 - val_mean_absolute_percentage_error: 170273.3281
# Epoch 8/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0483 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0159 - mean_absolute_percentage_error: 47725.3906 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0037 - val_mean_absolute_percentage_error: 159693.7656
# Epoch 9/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0502 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0172 - mean_absolute_percentage_error: 38630.8789 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 0.0036 - val_mean_absolute_percentage_error: 122963.7734
# Epoch 10/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0486 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0153 - mean_absolute_percentage_error: 83832.2422 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 0.0037 - val_mean_absolute_percentage_error: 92317.7969
# Epoch 11/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0482 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0161 - mean_absolute_percentage_error: 12184.6689 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 0.0036 - val_mean_absolute_percentage_error: 102358.8672
# Epoch 12/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0483 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0163 - mean_absolute_percentage_error: 38370.8711 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 0.0038 - val_mean_absolute_percentage_error: 46696.2305
# Epoch 13/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0484 - mean_absolute_error: 0.0484 - mean_squared_error: 0.0158 - mean_absolute_percentage_error: 57477.4141 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 0.0039 - val_mean_absolute_percentage_error: 32530.9023
# Epoch 14/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0479 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0161 - mean_absolute_percentage_error: 9007.5918 - val_loss: 0.0253 - val_mean_absolute_error: 0.0253 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 210265.5938
# Epoch 15/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0152 - mean_absolute_percentage_error: 35436.5820 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 164979.9375
# Epoch 16/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0477 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0155 - mean_absolute_percentage_error: 14748.0508 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0034 - val_mean_absolute_percentage_error: 159181.5156
# Epoch 17/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0145 - mean_absolute_percentage_error: 39281.8008 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0038 - val_mean_absolute_percentage_error: 70727.6172
# Epoch 18/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0472 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0150 - mean_absolute_percentage_error: 32199.4902 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 0.0034 - val_mean_absolute_percentage_error: 135130.3438
# Epoch 19/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0169 - mean_absolute_percentage_error: 8650.7930 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 0.0034 - val_mean_absolute_percentage_error: 109676.1953
# Epoch 20/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0152 - mean_absolute_percentage_error: 24019.0020 - val_loss: 0.0199 - val_mean_absolute_error: 0.0199 - val_mean_squared_error: 0.0034 - val_mean_absolute_percentage_error: 88557.7031
# Epoch 21/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0482 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0149 - mean_absolute_percentage_error: 24939.9629 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 0.0035 - val_mean_absolute_percentage_error: 6173.2148
# Epoch 22/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0144 - mean_absolute_percentage_error: 27521.6875 - val_loss: 0.0250 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0032 - val_mean_absolute_percentage_error: 209957.0000
# Epoch 23/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0138 - mean_absolute_percentage_error: 27021.6348 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 81648.1562
# Epoch 24/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 5407.8535 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 49811.4141
# Epoch 25/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0141 - mean_absolute_percentage_error: 7663.2227 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 0.0035 - val_mean_absolute_percentage_error: 35204.4023
# Epoch 26/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0141 - mean_absolute_percentage_error: 56477.2109 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 37824.9922
# Epoch 27/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0142 - mean_absolute_percentage_error: 4989.5952 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 120142.5703
# Epoch 28/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0141 - mean_absolute_percentage_error: 72036.8203 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 0.0032 - val_mean_absolute_percentage_error: 34345.8516
# Epoch 29/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0472 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0157 - mean_absolute_percentage_error: 48929.7227 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 132477.0781
# Epoch 30/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 41598.4141 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 149473.8281
# Epoch 31/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0144 - mean_absolute_percentage_error: 8320.8779 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0035 - val_mean_absolute_percentage_error: 76360.9062
# Epoch 32/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 28447.9668 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 0.0034 - val_mean_absolute_percentage_error: 51033.3477
# Epoch 33/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 41001.1875 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 134912.0625
# Epoch 34/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0142 - mean_absolute_percentage_error: 35660.2422 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 83991.4688
# Epoch 35/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0470 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0147 - mean_absolute_percentage_error: 81140.6250 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 187986.6406
# Epoch 36/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0144 - mean_absolute_percentage_error: 80053.3594 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 200225.4062
# Epoch 37/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 33368.4414 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 126247.8672
# Epoch 38/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0144 - mean_absolute_percentage_error: 1894.4443 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 55457.3594
# Epoch 39/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0470 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 28401.3750 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0032 - val_mean_absolute_percentage_error: 37674.2344
# Epoch 40/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0136 - mean_absolute_percentage_error: 41837.7305 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 37110.6719
# Epoch 41/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0147 - mean_absolute_percentage_error: 40755.1172 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 73448.6641
# Epoch 42/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0144 - mean_absolute_percentage_error: 44942.6016 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 55624.8867
# Epoch 43/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0127 - mean_absolute_percentage_error: 37958.0664 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 41675.5352
# Epoch 44/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0131 - mean_absolute_percentage_error: 13717.1660 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 27815.1406
# Epoch 45/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0132 - mean_absolute_percentage_error: 31750.8574 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 158511.6250
# Epoch 46/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0455 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0135 - mean_absolute_percentage_error: 14320.1533 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 59727.3516
# Epoch 47/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0132 - mean_absolute_percentage_error: 10235.2129 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 147255.5938
# Epoch 48/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 9065.2520 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 67399.5156
# Epoch 49/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0132 - mean_absolute_percentage_error: 9435.6816 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 90092.2422
# Epoch 50/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0140 - mean_absolute_percentage_error: 5056.5952 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 93866.1719
# Epoch 51/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0137 - mean_absolute_percentage_error: 63210.1953 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 60753.3633
# Epoch 52/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0135 - mean_absolute_percentage_error: 48133.3477 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 103071.3672
# Epoch 53/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 34040.0586 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 172005.2656
# Epoch 54/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0128 - mean_absolute_percentage_error: 22744.1621 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 184851.0469
# Epoch 55/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 17311.3418 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 100824.4062
# Epoch 56/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 36944.8398 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 154331.4375
# Epoch 57/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 31660.3203 - val_loss: 0.0191 - val_mean_absolute_error: 0.0191 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 9683.2227
# Epoch 58/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0138 - mean_absolute_percentage_error: 11272.9746 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 175607.7188
# Epoch 59/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0455 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 10487.5732 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 128438.9375
# Epoch 60/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0146 - mean_absolute_percentage_error: 62079.8828 - val_loss: 0.0241 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 204313.9219
# Epoch 61/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 7622.1992 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 0.0032 - val_mean_absolute_percentage_error: 14547.9209
# Epoch 62/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0145 - mean_absolute_percentage_error: 32860.2773 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 74915.7344
# Epoch 63/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0130 - mean_absolute_percentage_error: 28918.1113 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 0.0032 - val_mean_absolute_percentage_error: 54207.2539
# Epoch 64/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0142 - mean_absolute_percentage_error: 13440.5439 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 138567.0000
# Epoch 65/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0470 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0143 - mean_absolute_percentage_error: 32514.9961 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 164301.7812
# Epoch 66/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0131 - mean_absolute_percentage_error: 33593.6719 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 59757.4180
# Epoch 67/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 41761.2617 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 29522.8711
# Epoch 68/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0132 - mean_absolute_percentage_error: 59189.7578 - val_loss: 0.0200 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 112101.8594
# Epoch 69/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0132 - mean_absolute_percentage_error: 22600.9648 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 103378.4453
# Epoch 70/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0127 - mean_absolute_percentage_error: 44652.9531 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 202201.8750
# Epoch 71/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0126 - mean_absolute_percentage_error: 47413.1367 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0033 - val_mean_absolute_percentage_error: 106637.8906
# Epoch 72/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0142 - mean_absolute_percentage_error: 45742.7891 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 133255.8125
# Epoch 73/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0128 - mean_absolute_percentage_error: 4970.7632 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 59049.4414
# Epoch 74/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 15893.2646 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 54442.0977
# Epoch 75/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0125 - mean_absolute_percentage_error: 27020.9961 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 9515.9150
# Epoch 76/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0136 - mean_absolute_percentage_error: 13915.8818 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 6574.4536
# Epoch 77/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0130 - mean_absolute_percentage_error: 14740.8662 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 147204.1719
# Epoch 78/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0130 - mean_absolute_percentage_error: 20735.1445 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 8449.0293
# Epoch 79/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0130 - mean_absolute_percentage_error: 32917.9375 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 64177.0859
# Epoch 80/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0136 - mean_absolute_percentage_error: 20815.9355 - val_loss: 0.0264 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 259326.6094
# Epoch 81/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 2102.5022 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 132735.7812
# Epoch 82/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0447 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 16372.0342 - val_loss: 0.0246 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 221904.7188
# Epoch 83/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0148 - mean_absolute_percentage_error: 7045.8535 - val_loss: 0.0177 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 50416.6523
# Epoch 84/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0436 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 13170.1162 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 93036.8438
# Epoch 85/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0141 - mean_absolute_percentage_error: 44318.9922 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 31027.5000
# Epoch 86/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0126 - mean_absolute_percentage_error: 46849.1875 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 133304.4375
# Epoch 87/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 30115.9238 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 163455.1094
# Epoch 88/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 5276.1133 - val_loss: 0.0249 - val_mean_absolute_error: 0.0249 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 226834.1719
# Epoch 89/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 33574.5078 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 63033.2500
# Epoch 90/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0138 - mean_absolute_percentage_error: 18490.5684 - val_loss: 0.0177 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 34662.9062
# Epoch 91/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0123 - mean_absolute_percentage_error: 34246.8945 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 21908.8730
# Epoch 92/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 68580.6016 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 55613.9375
# Epoch 93/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0134 - mean_absolute_percentage_error: 19751.7715 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 189637.7344
# Epoch 94/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0126 - mean_absolute_percentage_error: 57698.9180 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 81042.6562
# Epoch 95/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0466 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0136 - mean_absolute_percentage_error: 3841.5332 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 8834.3340
# Epoch 96/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0128 - mean_absolute_percentage_error: 11692.7012 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 114633.1406
# Epoch 97/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 55827.2539 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 49290.1445
# Epoch 98/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 41179.1445 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 23260.5820
# Epoch 99/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0468 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 17790.4258 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 72104.5859
# Epoch 100/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 2623.4585 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 181521.4531
# Epoch 101/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0134 - mean_absolute_percentage_error: 12706.7744 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 67516.3359
# Epoch 102/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0473 - mean_absolute_error: 0.0473 - mean_squared_error: 0.0140 - mean_absolute_percentage_error: 17861.3555 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 25812.5254
# Epoch 103/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 41216.6055 - val_loss: 0.0256 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 242890.4844
# Epoch 104/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 33269.2461 - val_loss: 0.0200 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 29210.9609
# Epoch 105/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 18087.4258 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 62783.4141
# Epoch 106/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 31454.8730 - val_loss: 0.0200 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 120269.8984
# Epoch 107/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0126 - mean_absolute_percentage_error: 5868.9639 - val_loss: 0.0241 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 213542.1250
# Epoch 108/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 27291.9473 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 59675.5938
# Epoch 109/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0127 - mean_absolute_percentage_error: 32756.0156 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 115468.7969
# Epoch 110/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 78606.2812 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 63319.8398
# Epoch 111/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 10627.2217 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 0.0030 - val_mean_absolute_percentage_error: 53219.8633
# Epoch 112/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0129 - mean_absolute_percentage_error: 63311.5273 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 70923.7734
# Epoch 113/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0139 - mean_absolute_percentage_error: 47052.3008 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 148774.7656
# Epoch 114/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 20542.5977 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 187580.4844
# Epoch 115/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0126 - mean_absolute_percentage_error: 5021.9971 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 66231.5000
# Epoch 116/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 22324.7695 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 66132.1172
# Epoch 117/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 44074.7031 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 31187.4941
# Epoch 118/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 9032.5342 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 90969.0859
# Epoch 119/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 42676.3398 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 50083.4375
# Epoch 120/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0134 - mean_absolute_percentage_error: 13838.1016 - val_loss: 0.0174 - val_mean_absolute_error: 0.0174 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 41549.4688
# Epoch 121/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 39146.9961 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 118849.7188
# Epoch 122/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0428 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0117 - mean_absolute_percentage_error: 48381.7812 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 53559.5078
# Epoch 123/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0135 - mean_absolute_percentage_error: 18316.5879 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 52413.2578
# Epoch 124/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0128 - mean_absolute_percentage_error: 22762.3887 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 126215.5547
# Epoch 125/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0439 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 46348.9492 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 61134.0820
# Epoch 126/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0127 - mean_absolute_percentage_error: 43230.5898 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 107175.7891
# Epoch 127/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 37012.1289 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 140565.5312
# Epoch 128/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0133 - mean_absolute_percentage_error: 12788.9922 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 84723.8438
# Epoch 129/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0123 - mean_absolute_percentage_error: 25834.3203 - val_loss: 0.0199 - val_mean_absolute_error: 0.0199 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 122058.9766
# Epoch 130/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0127 - mean_absolute_percentage_error: 14267.8574 - val_loss: 0.0174 - val_mean_absolute_error: 0.0174 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 46228.8906
# Epoch 131/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 10102.0127 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 155024.4062
# Epoch 132/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0128 - mean_absolute_percentage_error: 28644.7910 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0031 - val_mean_absolute_percentage_error: 97003.7031
# Epoch 133/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 38555.2266 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 127712.8594
# Epoch 134/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 10453.7510 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 51415.3281
# Epoch 135/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 1849.4587 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 53596.6992
# Epoch 136/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0123 - mean_absolute_percentage_error: 17926.0625 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 207722.2500
# Epoch 137/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0117 - mean_absolute_percentage_error: 25274.0781 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 74253.0000
# Epoch 138/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 9280.9746 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 116325.4609
# Epoch 139/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0455 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 51776.6328 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 31608.3281
# Epoch 140/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0436 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 36418.6797 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 180952.4531
# Epoch 141/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0125 - mean_absolute_percentage_error: 3949.6614 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 9847.1152
# Epoch 142/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0130 - mean_absolute_percentage_error: 36637.4844 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 96487.4688
# Epoch 143/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 9307.7051 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 105651.5156
# Epoch 144/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 3485.6157 - val_loss: 0.0203 - val_mean_absolute_error: 0.0203 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 130618.1406
# Epoch 145/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 4380.4756 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 57357.9023
# Epoch 146/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 20877.2598 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0028 - val_mean_absolute_percentage_error: 2061.8914
# Epoch 147/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 13362.7109 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 83346.8594
# Epoch 148/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0455 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0136 - mean_absolute_percentage_error: 22690.6504 - val_loss: 0.0174 - val_mean_absolute_error: 0.0174 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 45175.0859
# Epoch 149/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0447 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 8555.0068 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 0.0029 - val_mean_absolute_percentage_error: 27203.0918
# Epoch 150/1500
# ...
# Epoch 1452/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 10516.5996 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 94714.3984
# Epoch 1453/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 3021.4373 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 28092.9062
# Epoch 1454/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 17688.5703 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 23379.1836
# Epoch 1455/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 22966.4023 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 76840.8750
# Epoch 1456/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0111 - mean_absolute_percentage_error: 21067.9141 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 17116.8691
# Epoch 1457/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0415 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 19917.1855 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 19773.2109
# Epoch 1458/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 20870.9902 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 5359.2935
# Epoch 1459/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 29952.1875 - val_loss: 0.0169 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 52653.7812
# Epoch 1460/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 15203.6748 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 66137.2812
# Epoch 1461/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 9906.2910 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 36930.5430
# Epoch 1462/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0122 - mean_absolute_percentage_error: 11940.0801 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 40878.3398
# Epoch 1463/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 7871.8159 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 32770.5117
# Epoch 1464/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 12758.3662 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 44270.3398
# Epoch 1465/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 13825.1777 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 51251.5586
# Epoch 1466/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0425 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0124 - mean_absolute_percentage_error: 11737.1777 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 82435.8594
# Epoch 1467/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 3121.3518 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 15394.9072
# Epoch 1468/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 7859.8618 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 104378.3359
# Epoch 1469/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 15060.7129 - val_loss: 0.0172 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 64677.9727
# Epoch 1470/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0409 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 13192.0596 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 45255.8789
# Epoch 1471/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0401 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0107 - mean_absolute_percentage_error: 4628.9741 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 41689.3867
# Epoch 1472/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0410 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0112 - mean_absolute_percentage_error: 10578.4619 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 35771.3516
# Epoch 1473/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 5122.4805 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 35763.5430
# Epoch 1474/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0111 - mean_absolute_percentage_error: 4775.0986 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 90058.2031
# Epoch 1475/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0108 - mean_absolute_percentage_error: 3280.9141 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 4855.3774
# Epoch 1476/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 3409.5518 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 13089.7295
# Epoch 1477/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0111 - mean_absolute_percentage_error: 7721.6216 - val_loss: 0.0189 - val_mean_absolute_error: 0.0189 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 106601.1172
# Epoch 1478/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0123 - mean_absolute_percentage_error: 16410.3477 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 144175.3281
# Epoch 1479/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 10974.3311 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 76494.6172
# Epoch 1480/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0411 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 7269.8379 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 26163.1777
# Epoch 1481/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 7883.0215 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 108518.7969
# Epoch 1482/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0417 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0117 - mean_absolute_percentage_error: 17135.1328 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 133785.3125
# Epoch 1483/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 21082.5293 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 150110.5156
# Epoch 1484/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 9129.5742 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 34815.9492
# Epoch 1485/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 1759.7623 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 98034.4062
# Epoch 1486/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 24197.4414 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 26994.5762
# Epoch 1487/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 15888.5059 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 40515.1797
# Epoch 1488/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0120 - mean_absolute_percentage_error: 8662.1758 - val_loss: 0.0203 - val_mean_absolute_error: 0.0203 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 56174.4414
# Epoch 1489/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0117 - mean_absolute_percentage_error: 13460.5176 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 43437.7930
# Epoch 1490/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0118 - mean_absolute_percentage_error: 10605.9658 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 87949.3828
# Epoch 1491/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0119 - mean_absolute_percentage_error: 23842.4434 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 25409.3066
# Epoch 1492/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0109 - mean_absolute_percentage_error: 4362.6826 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 23135.0723
# Epoch 1493/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0106 - mean_absolute_percentage_error: 2614.4666 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 26233.6309
# Epoch 1494/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0121 - mean_absolute_percentage_error: 18108.3750 - val_loss: 0.0168 - val_mean_absolute_error: 0.0168 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 16860.2148
# Epoch 1495/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0108 - mean_absolute_percentage_error: 20408.2910 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 0.0027 - val_mean_absolute_percentage_error: 83514.2656
# Epoch 1496/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0116 - mean_absolute_percentage_error: 1024.5466 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 915.0521
# Epoch 1497/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0114 - mean_absolute_percentage_error: 18364.6172 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 9404.6123
# Epoch 1498/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0113 - mean_absolute_percentage_error: 13148.2441 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185 - val_mean_squared_error: 0.0026 - val_mean_absolute_percentage_error: 22323.8164
# Epoch 1499/1500
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 20833.6211 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 0.0024 - val_mean_absolute_percentage_error: 117881.3281
# Epoch 1500/1500
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 15281.8984 - val_loss: 0.0168 - val_mean_absolute_error: 0.0168 - val_mean_squared_error: 0.0025 - val_mean_absolute_percentage_error: 14754.5820

# %%
# show plot loss function
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="loss", linewidth=2)
ax.plot(history.history['val_loss'], color="tab:orange", label="val_loss", linewidth=2)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(x_test, verbose=0)
print(predictions[:, 0])
# Out:
# [0.00084994 0.00082184 0.0009623  0.00100445 0.00190852 0.00133159
#  0.00306682 0.02945727 0.12255636 0.11733097 0.05974451 0.00134659
#  0.00108872 0.00104658 0.00157057 0.00158811 0.00108872 0.00104658
#  0.00111681 0.00168825 0.00111681 0.00127163 0.00113085 0.00082184
#  0.00079375 0.00079375 0.00092017 0.00162667 0.00153551 0.00162667
#  0.00323324 0.00236815 0.00218859 0.00143653 0.0009904  0.00103254
#  0.00079375 0.00087804 0.00128663 0.00090612 0.00131661 0.00113085
#  0.00166773 0.0020719  0.00127163 0.00092017 0.00084994 0.00086398
#  0.00075161 0.00086398 0.00087804 0.00120109 0.00139157 0.00142154
#  0.00151846 0.00572111 0.07496759 0.09987386 0.01374107]

# %% [markdown]
# ### 6. Evaluasi Model

# %%
mae = mean_absolute_error(y_test, predictions) * 100
print('Test MAE : %.4f' % mae)
# Out:
# Test MAE : 1.6822

# %%
mse = mean_squared_error(y_test, predictions) * 100
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.2512

# %%
mape = mean_absolute_percentage_error(y_test, predictions) * 100
print('Test MAPE: %.2f' % mape)
# Out:
# Test MAPE: 6594981429914.17

# %%
hasil = np.stack((y_test.reshape(-1), predictions.reshape(-1)), axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0     0.000346  0.000850
# 1     0.001039  0.000822
# 2     0.001247  0.000962
# 3     0.004988  0.001004
# 4     0.002841  0.001909

# %%
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.6515 dengan signifikansi 0.0000

# %% [markdown]
# - Kompleksitas waktu

# %%
# Set akhir waktu komputasi 
end = tm.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:06:33.19

# %% [markdown]
# ### 7. Visualisasi Data

# %%
if algorithm == "LSTM-RNN":
    title = "Model Stacked-Bidirectional LSTM-RNN"
else:
    title = "Model Stacked-Bidirectional GRU-RNN"

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.iloc[len(train_data)+1:len(dataset),0], predictions, color="tab:red", label="hasil prediksi", linewidth=2.5)

# membuat label-label
ax.set_title(title, fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
ax.legend(loc="best")
ax.grid(True)
plt.show()

# %% [markdown]
# ### 8. Hasil Prediksi Titik Panas

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
x = pd.DataFrame(np.array(dataset.iloc[train_size+1:len(dataset),0]), columns=['Date'])
y = pd.DataFrame(testActual, columns=['Data Aktual'])
z = pd.DataFrame(testPredictions, columns=['Data Prediksi'])

# %%
hasil_prediksi = pd.concat([x, y, z], axis=1)

# %%
hasil_prediksi = np.round(hasil_prediksi, 0)

# %%
if algorithm == "LSTM-RNN":
    hasil_prediksi.to_csv("hasil_prediksi_m1.csv", index=False)
else:
    hasil_prediksi.to_csv("hasil_prediksi_m4.csv", index=False)

# %%
fix, ax = plt.subplots(figsize=(10,5))

ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Aktual"], color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(hasil_prediksi["Date"], hasil_prediksi["Data Prediksi"], color="tab:red", label="prediction data", linewidth=2.5)

# Mengatur format tanggal ke format tahun
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# membuat label-label
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
hasil_prediksi
# Out:
#          Date  Data Aktual  Data Prediksi
# 0  2019-02-28          8.0           15.0
# 1  2019-03-31         18.0           15.0
# 2  2019-04-30         21.0           17.0
# 3  2019-05-31         75.0           17.0
# 4  2019-06-30         44.0           31.0
# 5  2019-07-31        116.0           22.0
# 6  2019-08-31        817.0           47.0
# 7  2019-09-30       4223.0          428.0
# 8  2019-10-31       3976.0         1772.0
# 9  2019-11-30       1736.0         1697.0
# 10 2019-12-31         45.0          865.0
# 11 2020-01-31         27.0           22.0
# 12 2020-02-29         24.0           19.0
# 13 2020-03-31         59.0           18.0
# 14 2020-04-30         60.0           26.0
# 15 2020-05-31         27.0           26.0
# 16 2020-06-30         24.0           19.0
# 17 2020-07-31         29.0           18.0
# 18 2020-08-31         65.0           19.0
# 19 2020-09-30         29.0           27.0
# 20 2020-10-31         40.0           19.0
# 21 2020-11-30         30.0           21.0
# 22 2020-12-31          8.0           19.0
# 23 2021-01-31          6.0           15.0
# 24 2021-02-28          6.0           14.0
# 25 2021-03-31         15.0           14.0
# 26 2021-04-30         62.0           16.0
# 27 2021-05-31         57.0           26.0
# 28 2021-06-30         62.0           25.0
# 29 2021-07-31        121.0           26.0
# 30 2021-08-31         94.0           50.0
# 31 2021-09-30         87.0           37.0
# 32 2021-10-31         51.0           35.0
# 33 2021-11-30         20.0           24.0
# 34 2021-12-31         23.0           17.0
# 35 2022-01-31          6.0           18.0
# 36 2022-02-28         12.0           14.0
# 37 2022-03-31         41.0           16.0
# 38 2022-04-30         14.0           22.0
# 39 2022-05-31         43.0           16.0
# 40 2022-06-30         30.0           22.0
# 41 2022-07-31         64.0           19.0
# 42 2022-08-31         82.0           27.0
# 43 2022-09-30         40.0           33.0
# 44 2022-10-31         15.0           21.0
# 45 2022-11-30         10.0           16.0
# 46 2022-12-31         11.0           15.0
# 47 2023-01-31          3.0           15.0
# 48 2023-02-28         11.0           14.0
# 49 2023-03-31         12.0           15.0
# 50 2023-04-30         35.0           16.0
# 51 2023-05-31         48.0           20.0
# 52 2023-06-30         50.0           23.0
# 53 2023-07-31         56.0           24.0
# 54 2023-08-31        186.0           25.0
# 55 2023-09-30       2247.0           86.0
# 56 2023-10-31       3200.0         1085.0
# 57 2023-11-30        390.0         1445.0
# 58 2023-12-31         42.0          201.0
